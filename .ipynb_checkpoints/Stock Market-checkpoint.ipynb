# %%
import pandas, openpyxl, requests, bs4, pyodbc


class ReadData:

    def __init__(self):
        pass

    def rExcel(self):
        excelFilePath: str = r"C:\Users\DELL\Desktop\Market watch.xlsm"
        df = pandas.read_excel(excelFilePath, sheet_name='KK')
        return df

    
    def rCurrentStockPriceInfoWeb(self):
        hdr = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.56"}
        URL_lst = ["https://www.financialexpress.com/market/stock-market/nse-top-gainers/","https://www.financialexpress.com/market/stock-market/nse-top-losers/"]
        df = []
        for url in URL_lst:
            resp = requests.get(url, headers=hdr)
            soup = bs4.BeautifulSoup(resp.text, 'html.parser')
            table = soup.find(id='modality')
            for tr in table.find_all('tr'):
                lst = []
                for td in tr.find_all('td'):
                    lst.append(td.text)
                df.append(lst)
        return df

    def rCurrentStockVolDelInfoWeb(self):
        hdr = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.56"}
        URL_lst = ["https://www.financialexpress.com/market/stock-market/nse-low-delivery/"]
        df = []
        for url in URL_lst:
            resp = requests.get(url, headers=hdr)
            soup = bs4.BeautifulSoup(resp.text, 'html.parser')
            table = soup.find(id='modality')
            for tr in table.find_all('tr'):
                lst = []
                for td in tr.find_all('td'):
                    lst.append(td.text)
                df.append(lst)
        return df
d=ReadData().rCurrentStockPriceInfoWeb()
d
# Out:
# [[],
#  ['Guj. Apollo Inds', '220.85', '191.80', '15.15', '29.05', '283.60'],
#  ['Sundaram Multi Pap', '2.40', '2.15', '11.63', '0.25', '1917.63'],
#  ['Medplus Health Servi', '718.80', '648.65', '10.81', '70.15', '517.82'],
#  ['Everest Kanto Cylind', '84.60', '76.80', '10.16', '7.80', '1468.93'],
#  ['Jain Irrigation Sys', '31.60', '28.70', '10.10', '2.90', '22345.20'],
#  ['DCM', '78.10', '71.00', '10.00', '7.10', '67.87'],
#  ['Zee Entertainment', '206.70', '189.05', '9.34', '17.65', '22589.25'],
#  ['Shekhawati Poly-Yarn', '0.60', '0.55', '9.09', '0.05', '41.59'],
#  ['Hikal', '311.25', '286.05', '8.81', '25.20', '3306.19'],
#  ['Imagicaaworld Enter', '48.70', '45.25', '7.62', '3.45', '2851.66'],
#  ['Network 18 Media Inv', '54.70', '50.95', '7.36', '3.75', '5701.93'],
#  ['BEML', '1242.40', '1158.40', '7.25', '84.00', '550.82'],
#  ['GTL Infrastructure', '0.75', '0.70', '7.14', '0.05', '11260.78'],
#  ['Anik Industries', '30.05', '28.05', '7.13', '2.00', '44.35'],
#  ['Gayatri Highways', '0.80', '0.75', '6.67', '0.05', '90.92'],
#  ['ICICI Prudential', '409.65', '384.05', '6.67', '25.60', '9510.15'],
#  ['DCM Financial Serv.', '4.05', '3.80', '6.58', '0.25', '23.10'],
#  ['TV18 Broadcast', '30.45', '28.65', '6.28', '1.80', '18981.13'],
#  ['Paras Petrofils', '0.85', '0.80', '6.25', '0.05', '40.15'],
#  ['B.L. Kashyap and Son', '29.80', '28.05', '6.24', '1.75', '662.74'],
#  ['BPCL', '350.90', '330.30', '6.24', '20.60', '18287.31'],
#  ['HPCL', '244.50', '230.35', '6.14', '14.15', '16745.56'],
#  ['Unichem Lab', '292.85', '275.95', '6.12', '16.90', '274.84'],
#  ['Optiemus Infracom', '234.75', '222.05', '5.72', '12.70', '194.82'],
#  ['Aptech', '339.80', '321.70', '5.63', '18.10', '242.13'],
#  ['Mahindra EPC Irrigat', '94.15', '89.35', '5.37', '4.80', '47.19'],
#  ['Siti Networks', '1.00', '0.95', '5.26', '0.05', '4149.09'],
#  ['Medico Remedies', '76.70', '73.03', '5.03', '3.67', '676.68'],
#  ['Rollatainers', '1.05', '1.00', '5.00', '0.05', '467.68'],
#  ['Regency Ceramics', '21.00', '20.00', '5.00', '1.00', '0.90'],
#  ['Vinny Overseas', '10.50', '10.00', '5.00', '0.50', '1776.95'],
#  ['Zee Media Corpn.', '9.45', '9.00', '5.00', '0.45', '2700.77'],
#  ['Adani Green Energy', '777.40', '740.40', '5.00', '37.00', '3038.75'],
#  ['Flexituff Ventures', '28.40', '27.05', '4.99', '1.35', '50.59'],
#  ['Bombay Super Hybrid', '265.25', '252.65', '4.99', '12.60', '24.43'],
#  ['Reliance Capital', '9.50', '9.05', '4.97', '0.45', '985.94'],
#  ['W.S. Industries', '20.10', '19.15', '4.96', '0.95', '0.17'],
#  ['ABM International', '61.50', '58.60', '4.95', '2.90', '1.49'],
#  ['Binani Inds', '25.45', '24.25', '4.95', '1.20', '6.30'],
#  ['Adani Transmission', '973.70', '928.35', '4.89', '45.35', '3151.99'],
#  ['Soma Textiles', '37.65', '35.90', '4.87', '1.75', '231.32'],
#  ['TD Power Systems', '148.90', '142.00', '4.86', '6.90', '917.64'],
#  ['Kshitij Polyline', '25.90', '24.70', '4.86', '1.20', '1618.89'],
#  ['Motor & General Fin', '28.15', '26.85', '4.84', '1.30', '8.30'],
#  ['Supreme Infra. India', '21.75', '20.75', '4.82', '1.00', '35.98'],
#  ['Sintex Plastics Tech', '2.20', '2.10', '4.76', '0.10', '1416.80'],
#  ['Vipul', '12.10', '11.55', '4.76', '0.55', '7.27'],
#  ['Atlanta', '12.10', '11.55', '4.76', '0.55', '3.71'],
#  ['Walchandnagar Inds', '56.20', '53.65', '4.75', '2.55', '137.52'],
#  ['Man Industries', '89.30', '85.40', '4.57', '3.90', '1250.83'],
#  ['Godha Cabcon&Insulat', '1.15', '1.10', '4.55', '0.05', '1973.06'],
#  ['Zomato', '53.05', '50.75', '4.53', '2.30', '61237.06'],
#  ['Shree Ram Proteins', '50.95', '48.75', '4.51', '2.20', '163.94'],
#  ['GI Engineering Soln.', '5.80', '5.55', '4.50', '0.25', '0.13'],
#  ['Infomedia Press', '4.70', '4.50', '4.44', '0.20', '10.30'],
#  ['Adroit Infotech', '21.65', '20.75', '4.34', '0.90', '23.84'],
#  ['Nucleus Software Exp', '593.85', '569.55', '4.27', '24.30', '241.48'],
#  ['DLF', '360.05', '345.45', '4.23', '14.60', '5412.09'],
#  ['Nahar Poly Films', '249.75', '239.95', '4.08', '9.80', '353.53'],
#  ['India Motor Parts', '699.05', '671.65', '4.08', '27.40', '6.44'],
#  ['NK Industries', '41.15', '39.55', '4.05', '1.60', '1.71'],
#  ['E2E Networks', '169.55', '163.00', '4.02', '6.55', '34.55'],
#  ['JK Lakshmi Cement', '688.75', '662.30', '3.99', '26.45', '371.41'],
#  ['Shivam Autotech', '23.80', '22.90', '3.93', '0.90', '198.79'],
#  ['KBC Global', '2.65', '2.55', '3.92', '0.10', '3643.37'],
#  ['Zee Learn', '4.00', '3.85', '3.90', '0.15', '1722.60'],
#  ['Vardhman Special', '367.75', '354.20', '3.83', '13.55', '193.78'],
#  ['SpiceJet', '33.95', '32.70', '3.82', '1.25', '3692.94'],
#  ['Norben Tea & Exports', '8.15', '7.85', '3.82', '0.30', '0.10'],
#  ['Wendt India', '8386.05', '8077.50', '3.82', '308.55', '0.67'],
#  ['Ambuja Cement', '378.80', '365.15', '3.74', '13.65', '17263.26'],
#  ['Dynacons Sys & Sol', '331.25', '319.40', '3.71', '11.85', '26.21'],
#  ['Cerebra Integ. Tech', '9.80', '9.45', '3.70', '0.35', '515.52'],
#  ['Best Agrolife', '1088.00', '1049.25', '3.69', '38.75', '71.45'],
#  ['Ramky Infrastructure', '277.00', '267.15', '3.69', '9.85', '134.24'],
#  ['Thirumalai Chemicals', '179.05', '172.85', '3.59', '6.20', '240.54'],
#  ['Indo Tech Transform.', '172.85', '166.90', '3.57', '5.95', '8.52'],
#  ['MEP Infrastructure', '14.55', '14.05', '3.56', '0.50', '1558.13'],
#  ['SMS Lifesciences', '529.75', '511.70', '3.53', '18.05', '0.44'],
#  ['Century Textile &Ind', '652.55', '630.45', '3.51', '22.10', '388.43'],
#  ['Techno Electric &Eng', '335.30', '324.00', '3.49', '11.30', '312.09'],
#  ['Sumitomo Chemical India', '450.55', '435.40', '3.48', '15.15', '304.33'],
#  ['Aksh Optifibre', '8.95', '8.65', '3.47', '0.30', '212.65'],
#  ['Shakti Pumps (I)', '423.70', '409.50', '3.47', '14.20', '83.02'],
#  ['Arvind Fashions', '282.70', '273.30', '3.44', '9.40', '473.19'],
#  ['Shivalik Bimetal', '408.95', '395.80', '3.32', '13.15', '76.22'],
#  ['Hindustan Zinc', '304.85', '295.10', '3.30', '9.75', '1996.71'],
#  ['Thermax', '2253.65', '2181.90', '3.29', '71.75', '62.52'],
#  ['Pansari Developers', '91.10', '88.20', '3.29', '2.90', '1.23'],
#  ['Bedmutha Industries', '50.30', '48.70', '3.29', '1.60', '6.35'],
#  ['Entertain. Network', '119.90', '116.10', '3.27', '3.80', '26.94'],
#  ['Faze Three', '289.20', '280.05', '3.27', '9.15', '11.20'],
#  ['Aurobindo Pharma', '473.25', '458.35', '3.25', '14.90', '3721.23'],
#  ['MT Educare', '4.80', '4.65', '3.23', '0.15', '24.50'],
#  ['National Steel &Agro', '3.25', '3.15', '3.17', '0.10', '11.41'],
#  ['Veranda Learning Sln', '188.65', '182.85', '3.17', '5.80', '51.45'],
#  ['TIL', '154.90', '150.20', '3.13', '4.70', '7.53'],
#  ['Patel Engineering', '14.90', '14.45', '3.11', '0.45', '6507.87'],
#  ['PB Fintech', '581.80', '564.25', '3.11', '17.55', '3083.12'],
#  ['AGI Greenpac', '356.50', '345.85', '3.08', '10.65', '335.91'],
#  ['Gandhi Spl. Tubes', '504.20', '489.60', '2.98', '14.60', '4.52'],
#  ['Tilaknagar Inds', '103.70', '100.70', '2.98', '3.00', '254.44'],
#  ['Star Health and Allied', '542.70', '527.05', '2.97', '15.65', '1721.38'],
#  ['Mangalore Chem &Fert', '96.90', '94.15', '2.92', '2.75', '682.63'],
#  ['Art Nirman', '58.80', '57.15', '2.89', '1.65', '114.43'],
#  ['Sun TV Network', '435.05', '422.85', '2.89', '12.20', '639.96'],
#  ['Sri Havisha Hospital', '1.80', '1.75', '2.86', '0.05', '14.89'],
#  ['Piramal Enterprises', '691.90', '672.70', '2.85', '19.20', '3742.67'],
#  ['Wonder Electricals', '215.05', '209.20', '2.80', '5.85', '1.13'],
#  ['Anmol India', '180.15', '175.25', '2.80', '4.90', '51.12'],
#  ['Godrej Consumer Prod', '932.35', '907.40', '2.75', '24.95', '1306.26'],
#  ['SILGO Retail', '18.70', '18.20', '2.75', '0.50', '13.78'],
#  ['North Eastern Carry.', '15.10', '14.70', '2.72', '0.40', '197.14'],
#  ['Apex Frozen Foods', '213.30', '207.65', '2.72', '5.65', '53.99'],
#  ['NACL Industries', '85.25', '83.00', '2.71', '2.25', '276.69'],
#  ['Grauer & Weil (I)', '102.35', '99.65', '2.71', '2.70', '420.16'],
#  ['Axiscades Tech.', '287.25', '279.80', '2.66', '7.45', '60.38'],
#  ['PVR', '1588.15', '1547.05', '2.66', '41.10', '417.05'],
#  ['Ethos Ltd.', '987.80', '962.70', '2.61', '25.10', '40.19'],
#  ['Gillanders Arbuthnot', '62.00', '60.45', '2.56', '1.55', '10.37'],
#  ['Asian Hotels (North)', '72.15', '70.35', '2.56', '1.80', '12.98'],
#  ['Nahar Ind.Enterprise', '96.45', '94.05', '2.55', '2.40', '66.40'],
#  ['Indus Towers', '153.20', '149.40', '2.54', '3.80', '4269.55'],
#  ['Nestle', '18450.65', '17993.35', '2.54', '457.30', '83.04'],
#  ['Delta Corp', '192.50', '187.75', '2.53', '4.75', '2589.07'],
#  ['Ingersoll Rand', '2431.30', '2371.45', '2.52', '59.85', '16.78'],
#  ['Balaxi Pharma.', '539.20', '526.00', '2.51', '13.20', '1.53'],
#  ['Wonderla Holidays', '422.85', '412.55', '2.50', '10.30', '156.19'],
#  ['Ashiana Housing', '144.75', '141.25', '2.48', '3.50', '36.08'],
#  ['Den Networks', '29.00', '28.30', '2.47', '0.70', '896.60'],
#  ['Ircon International', '54.25', '52.95', '2.46', '1.30', '3750.11'],
#  ['Raj TV Network', '39.70', '38.75', '2.45', '0.95', '12.59'],
#  ['Alkem Laboratories', '3155.05', '3079.85', '2.44', '75.20', '73.46'],
#  ['Hariom Pipe Inds.', '458.15', '447.30', '2.43', '10.85', '174.87'],
#  ['Dabur India', '534.50', '521.85', '2.42', '12.65', '2094.72'],
#  ['Jindal Worldwide', '300.60', '293.50', '2.42', '7.10', '90.05'],
#  ['Omax Autos', '47.05', '45.95', '2.39', '1.10', '45.66'],
#  ['Manappuram Finance', '112.65', '110.05', '2.36', '2.60', '6356.19'],
#  ['Pearl Global Inds.', '413.75', '404.25', '2.35', '9.50', '7.29'],
#  ['Indian Terrain Fash.', '48.15', '47.05', '2.34', '1.10', '213.75'],
#  ['Asian Paints', '2893.25', '2827.40', '2.33', '65.85', '1755.49'],
#  ['Lloyds Steels', '19.85', '19.40', '2.32', '0.45', '4281.90'],
#  ['Paisalo Digital', '57.35', '56.05', '2.32', '1.30', '429.39'],
#  ['Sikko Industries', '86.85', '84.90', '2.30', '1.95', '26.95'],
#  ['Bank Of India', '71.40', '69.80', '2.29', '1.60', '17883.91'],
#  ['CEAT', '1427.75', '1396.15', '2.26', '31.60', '115.51'],
#  ['Lovable Lingerie', '104.45', '102.15', '2.25', '2.30', '30.50'],
#  ['Balkrishna Paper', '31.85', '31.15', '2.25', '0.70', '5.50'],
#  ['Sheetal Cool Prod', '556.60', '544.40', '2.24', '12.20', '77.12'],
#  ['Hindustan Unilever', '2459.35', '2406.10', '2.21', '53.25', '1628.04'],
#  ['Sundram Fasteners', '981.15', '960.00', '2.20', '21.15', '354.90'],
#  ['Styrenix Performance', '837.35', '819.55', '2.17', '17.80', '202.12'],
#  ['Rico Auto Inds', '68.70', '67.25', '2.16', '1.45', '443.25'],
#  ['VRL Logistics', '628.25', '615.00', '2.15', '13.25', '303.15'],
#  ['MP Bharat Agro Prod', '603.20', '590.50', '2.15', '12.70', '6.89'],
#  ['Shiva Texyarn', '114.20', '111.80', '2.15', '2.40', '9.32'],
#  ['Divgi Torqtransfer', '623.65', '610.55', '2.15', '13.10', '447.95'],
#  ['Titan Co', '2450.35', '2399.10', '2.14', '51.25', '2317.11'],
#  ['Berger Paints India', '603.70', '591.15', '2.12', '12.55', '1481.68'],
#  ['Bharat Rasayan', '8586.85', '8411.80', '2.08', '175.05', '1.00'],
#  ['Peria Karamalai Tea', '295.00', '289.00', '2.08', '6.00', '0.02'],
#  ['Aditya Birla Money', '51.65', '50.60', '2.08', '1.05', '108.28'],
#  ['Om Infra', '34.75', '34.05', '2.06', '0.70', '65.28'],
#  ['Intrasoft Tech', '109.55', '107.35', '2.05', '2.20', '14.44'],
#  ['Kapston Services', '139.75', '136.95', '2.04', '2.80', '2.43'],
#  ['Tata Motors - DVR', '212.35', '208.10', '2.04', '4.25', '2949.06'],
#  ['Avonmore Capital', '62.60', '61.35', '2.04', '1.25', '12.15'],
#  ['Gujarat Pipavav Port', '112.90', '110.65', '2.03', '2.25', '2875.19'],
#  ['Mahindra Holi.&Resor', '276.85', '271.35', '2.03', '5.50', '270.88'],
#  ['Kamdhenu', '322.40', '316.00', '2.03', '6.40', '35.55'],
#  ['TVS Motor', '1053.60', '1032.75', '2.02', '20.85', '747.12'],
#  ['D.P. Abhushan', '308.50', '302.45', '2.00', '6.05', '12.27'],
#  ['NMDC Steel', '35.95', '35.25', '1.99', '0.70', '6789.06'],
#  ['Loyal Textile Mills', '645.10', '632.55', '1.98', '12.55', '0.09'],
#  ['Hi-Tech Pipes', '897.10', '879.90', '1.95', '17.20', '83.07'],
#  ['GTL', '5.25', '5.15', '1.94', '0.10', '348.61'],
#  ['Puravankara', '76.55', '75.10', '1.93', '1.45', '113.56'],
#  ['Aditya Birla Capital', '148.80', '146.00', '1.92', '2.80', '2258.79'],
#  ['Nandani Creation', '85.05', '83.45', '1.92', '1.60', '18.04'],
#  ['United Spirits', '776.45', '761.95', '1.90', '14.50', '1429.11'],
#  ['Kothari Products', '129.05', '126.65', '1.89', '2.40', '68.37'],
#  ['Bajaj Auto', '3800.20', '3730.00', '1.88', '70.20', '377.54'],
#  ['Borosil', '321.15', '315.30', '1.86', '5.85', '52.29'],
#  ['Rossari Biotech', '568.95', '558.65', '1.84', '10.30', '194.10'],
#  ['Atul', '6945.45', '6820.95', '1.83', '124.50', '58.58'],
#  ['Westlife Development', '682.15', '669.95', '1.82', '12.20', '60.98'],
#  ['Ganges Securities', '98.40', '96.65', '1.81', '1.75', '4.44'],
#  ['Jindal Poly Invest', '466.80', '458.60', '1.79', '8.20', '12.42'],
#  ['Punjab & Sind Bank', '25.75', '25.30', '1.78', '0.45', '2223.76'],
#  ['Omaxe', '54.55', '53.60', '1.77', '0.95', '207.38'],
#  ['Abans Holdings', '210.85', '207.20', '1.76', '3.65', '155.44'],
#  ['Alembic', '60.75', '59.70', '1.76', '1.05', '98.54'],
#  ['Sambhaav Media', '2.90', '2.85', '1.75', '0.05', '37.05'],
#  ['Transport Corp.', '622.15', '611.45', '1.75', '10.70', '630.44'],
#  ['Bannari Amman Spg', '37.90', '37.25', '1.74', '0.65', '76.17'],
#  ['21st Cent Mgt', '17.50', '17.20', '1.74', '0.30', '6.04'],
#  ['Greaves Cotton', '122.95', '120.85', '1.74', '2.10', '1075.18'],
#  ['Modison', '59.40', '58.40', '1.71', '1.00', '15.68'],
#  ['VST Industries', '3155.60', '3103.25', '1.69', '52.35', '4.72'],
#  ['Power Grid Corp', '232.15', '228.30', '1.69', '3.85', '13828.36'],
#  ['Sun Pharma Inds.', '967.40', '951.40', '1.68', '16.00', '2228.09'],
#  ['Shriram Finance', '1250.20', '1229.55', '1.68', '20.65', '797.71'],
#  ['Chaman Lal Setia Exp', '172.55', '169.70', '1.68', '2.85', '250.94'],
#  ['Indian Hotel', '320.90', '315.65', '1.66', '5.25', '2239.53'],
#  ['Smartlink Holdings', '146.70', '144.30', '1.66', '2.40', '17.95'],
#  ['Hindustan Media Vent', '49.00', '48.20', '1.66', '0.80', '36.28'],
#  ['HEC Infra Projects', '30.65', '30.15', '1.66', '0.50', '4.37'],
#  ['Indian Oil Corp.', '79.90', '78.60', '1.65', '1.30', '27348.57'],
#  ['Abbott India', '20704.00', '20367.50', '1.65', '336.50', '6.62'],
#  ['Kirloskar Oil Eng', '376.80', '370.70', '1.65', '6.10', '329.92'],
#  ['SRF', '2309.65', '2272.40', '1.64', '37.25', '446.51'],
#  ['KEC International', '468.80', '461.25', '1.64', '7.55', '144.63'],
#  ['Anjani Portland Cem.', '155.90', '153.40', '1.63', '2.50', '54.13'],
#  ['National Fertilizers', '72.20', '71.05', '1.62', '1.15', '5857.38'],
#  ['Zota Health Care', '295.95', '291.25', '1.61', '4.70', '27.46'],
#  ['Fiem Inds', '1600.10', '1574.75', '1.61', '25.35', '23.45'],
#  ['Britannia Inds', '4311.20', '4243.10', '1.60', '68.10', '260.04'],
#  ['Varroc Engineering', '276.80', '272.45', '1.60', '4.35', '456.27'],
#  ['RainbowChildrenS Med', '732.85', '721.35', '1.59', '11.50', '74.53'],
#  ['Times Guaranty', '48.10', '47.35', '1.58', '0.75', '3.46'],
#  ['Muthoot Finance', '930.30', '915.80', '1.58', '14.50', '333.01'],
#  ['Trejhara Solutions', '54.65', '53.80', '1.58', '0.85', '33.77'],
#  ['Alok Inds', '12.95', '12.75', '1.57', '0.20', '12565.76'],
#  ['Sudarshan Chemicals', '375.95', '370.15', '1.57', '5.80', '134.05'],
#  ['TTK Healthcare', '860.15', '847.00', '1.55', '13.15', '9.00'],
#  ['Premier Explosives', '405.60', '399.45', '1.54', '6.15', '13.46'],
#  ['Timken India', '2846.20', '2803.35', '1.53', '42.85', '35.44'],
#  ['BLB', '23.35', '23.00', '1.52', '0.35', '25.02'],
#  ['Indraprastha Gas', '427.50', '421.10', '1.52', '6.40', '1079.69'],
#  ['SBC Exports', '16.80', '16.55', '1.51', '0.25', '2497.05'],
#  ['The Western Indian', '80.70', '79.50', '1.51', '1.20', '0.60'],
#  ['Zenith Exports', '87.60', '86.30', '1.51', '1.30', '0.09'],
#  ['IDFC', '77.70', '76.55', '1.50', '1.15', '5494.09'],
#  ['VA Tech Wabag', '319.45', '314.75', '1.49', '4.70', '203.22'],
#  ['Prudent Corporate', '783.95', '772.45', '1.49', '11.50', '13.15'],
#  ['Texmaco Infra', '54.80', '54.00', '1.48', '0.80', '44.45'],
#  ['Noida Toll Bridge', '6.90', '6.80', '1.47', '0.10', '49.27'],
#  ['Newgen Software Tech', '444.65', '438.30', '1.45', '6.35', '116.07'],
#  ['NCC', '101.75', '100.30', '1.45', '1.45', '9494.26'],
#  ['Data Patterns (I)', '1337.25', '1318.25', '1.44', '19.00', '128.74'],
#  ['Inspirisys Solutions', '45.80', '45.15', '1.44', '0.65', '21.30'],
#  ['Vesuvius India', '1593.65', '1571.05', '1.44', '22.60', '8.96'],
#  ['Ador Welding', '845.30', '833.40', '1.43', '11.90', '8.60'],
#  ['Poly Medicure', '968.55', '954.95', '1.42', '13.60', '177.25'],
#  ['Monarch Networth Cap', '213.85', '210.85', '1.42', '3.00', '13.61'],
#  ['Websol Energy System', '75.10', '74.05', '1.42', '1.05', '96.25'],
#  ['Bank of Maharashtra', '25.20', '24.85', '1.41', '0.35', '12935.25'],
#  ['Esab india', '3760.65', '3708.45', '1.41', '52.20', '4.59'],
#  ['Dixon Technologies', '2868.05', '2828.25', '1.41', '39.80', '231.09'],
#  ['Torrent Power', '545.60', '538.05', '1.40', '7.55', '391.13'],
#  ['Starteck Finance', '134.15', '132.30', '1.40', '1.85', '2.00'],
#  ['Shalimar Paints', '148.70', '146.65', '1.40', '2.05', '22.22'],
#  ['Sutlej Textiles&Inds', '43.60', '43.00', '1.40', '0.60', '49.01'],
#  ['Summit Securities', '590.35', '582.30', '1.38', '8.05', '4.24'],
#  ['Thomas Cook (India)', '59.20', '58.40', '1.37', '0.80', '554.28'],
#  ['Ritco Logistics', '167.20', '164.95', '1.36', '2.25', '11.62'],
#  ['Gravita India', '451.50', '445.50', '1.35', '6.00', '202.34'],
#  ['Avenue Supermarts', '3382.15', '3337.25', '1.35', '44.90', '353.91'],
#  ['SBI', '524.50', '517.55', '1.34', '6.95', '20040.01'],
#  ['Indiabulls Real Est.', '57.20', '56.45', '1.33', '0.75', '7615.67'],
#  ['Bliss GVS Pharma', '76.45', '75.45', '1.33', '1.00', '131.68'],
#  ['Zydus Lifesciences', '479.65', '473.40', '1.32', '6.25', '1591.28'],
#  ['Dreamfolks Services', '426.65', '421.10', '1.32', '5.55', '148.40'],
#  ['Neogen Chemicals', '1315.00', '1297.90', '1.32', '17.10', '19.06'],
#  ['Mahanagar Gas', '987.10', '974.30', '1.31', '12.80', '484.63'],
#  ['Info Edge', '3425.85', '3381.45', '1.31', '44.40', '247.86'],
#  ['Visa Steel', '11.60', '11.45', '1.31', '0.15', '7.59'],
#  ['Sundaram Finance', '2264.55', '2235.35', '1.31', '29.20', '8.56'],
#  ['IRB Infra.&Developer', '27.20', '26.85', '1.30', '0.35', '14297.98'],
#  ['AMJ Land Holdings', '23.45', '23.15', '1.30', '0.30', '16.27'],
#  ['Indiamart Intermesh', '4800.80', '4739.40', '1.30', '61.40', '66.64'],
#  ['Pidilite Inds.', '2341.20', '2311.45', '1.29', '29.75', '263.33'],
#  ['Prince Pipes & Fitti', '574.80', '567.50', '1.29', '7.30', '90.94'],
#  ['Marksans Pharma', '67.00', '66.15', '1.28', '0.85', '1556.84'],
#  ['Madhucon Projects', '3.95', '3.90', '1.28', '0.05', '14.86'],
#  ['Vascon Engineers', '27.70', '27.35', '1.28', '0.35', '488.28'],
#  ['Ipca Laboratories', '781.30', '771.50', '1.27', '9.80', '288.79'],
#  ['Sasken Technologies', '804.15', '794.10', '1.27', '10.05', '8.53'],
#  ['MRF', '83140.70', '82107.10', '1.26', '1033.60', '7.11'],
#  ['Prestige EstatesProj', '400.25', '395.30', '1.25', '4.95', '330.94'],
#  ['Donear Inds', '85.10', '84.05', '1.25', '1.05', '137.40'],
#  ['Mastek', '1655.35', '1635.05', '1.24', '20.30', '38.39'],
#  ['TVS Srichakra', '2672.55', '2640.05', '1.23', '32.50', '7.61'],
#  ['Lupin', '666.20', '658.30', '1.20', '7.90', '596.96'],
#  ['Bajaj Hold & Invest', '6113.35', '6041.10', '1.20', '72.25', '24.49'],
#  ['Ashok Leyland', '139.75', '138.10', '1.19', '1.65', '10123.19'],
#  ['Paradeep Phosphates', '51.35', '50.75', '1.18', '0.60', '1459.95'],
#  ['Mcleod Russel', '17.15', '16.95', '1.18', '0.20', '261.33'],
#  ['United Drilling Tool', '207.35', '204.95', '1.17', '2.40', '21.95'],
#  ['Deep Industries', '261.80', '258.80', '1.16', '3.00', '21.98'],
#  ['DCM Nouvelle', '140.15', '138.55', '1.15', '1.60', '27.88'],
#  ['CSL Finance', '210.60', '208.20', '1.15', '2.40', '8.41'],
#  ['Saregama India', '318.00', '314.40', '1.15', '3.60', '157.30'],
#  ['Trent', '1336.35', '1321.25', '1.14', '15.10', '475.24'],
#  ['Electrotherm India', '57.85', '57.20', '1.14', '0.65', '42.34'],
#  ['Chemplast Sanmar', '364.95', '360.90', '1.12', '4.05', '847.05'],
#  ['LIC Housing Finance', '347.10', '343.25', '1.12', '3.85', '906.94'],
#  ['Care Ratings', '658.95', '651.65', '1.12', '7.30', '94.85'],
#  ['Ramkrishna Forgings', '284.50', '281.35', '1.12', '3.15', '1509.37'],
#  ['Indiabulls Enterpris', '9.15', '9.05', '1.10', '0.10', '793.16'],
#  ['Tips Films', '372.15', '368.10', '1.10', '4.05', '2.13'],
#  ['IDFC First Bank', '55.35', '54.75', '1.10', '0.60', '27896.43'],
#  ['Lumax Industries', '1687.00', '1669.20', '1.07', '17.80', '2.11'],
#  ['Glenmark Life Scienc', '386.70', '382.65', '1.06', '4.05', '56.93'],
#  ['Kothari Petrochem', '66.85', '66.15', '1.06', '0.70', '70.37'],
#  ['Tata Motors', '415.70', '411.35', '1.06', '4.35', '11854.89'],
#  ['Linde India', '3717.80', '3678.95', '1.06', '38.85', '36.14'],
#  ['Repro India', '379.00', '375.05', '1.05', '3.95', '4.39'],
#  ['Goyal Aluminiums', '307.80', '304.60', '1.05', '3.20', '116.00'],
#  ['Aarti Inds', '520.20', '514.80', '1.05', '5.40', '551.00'],
#  ['Gujarat Gas', '496.80', '491.65', '1.05', '5.15', '441.40'],
#  ['Jagran Prakashan', '72.35', '71.60', '1.05', '0.75', '84.08'],
#  ['Godrej Properties', '1101.80', '1090.45', '1.04', '11.35', '386.26'],
#  ['Welspun Enterprises', '126.80', '125.50', '1.04', '1.30', '198.90'],
#  ['Glenmark Pharma', '432.55', '428.15', '1.03', '4.40', '508.03'],
#  ['VIP Inds.', '568.45', '562.70', '1.02', '5.75', '330.26'],
#  ['UCO Bank', '25.10', '24.85', '1.01', '0.25', '12502.60'],
#  ['Lakshmi Finance&Indl', '105.95', '104.90', '1.00', '1.05', '1.89'],
#  ['Ahlada Engineers', '91.25', '90.35', '1.00', '0.90', '19.25'],
#  ['Tata Coffee', '202.00', '200.05', '0.97', '1.95', '373.46'],
#  ['PTC India', '88.30', '87.45', '0.97', '0.85', '1010.71'],
#  ['GE Power India', '109.25', '108.20', '0.97', '1.05', '77.06'],
#  ['Hercules Hoists', '198.00', '196.10', '0.97', '1.90', '21.40'],
#  ['GMR Airports Infra.', '41.75', '41.35', '0.97', '0.40', '17398.47'],
#  ['D.P. Wires', '376.05', '372.45', '0.97', '3.60', '6.02'],
#  ['Balkrishna Inds.', '1980.15', '1961.50', '0.95', '18.65', '162.81'],
#  ['Eicher Motors', '3035.45', '3006.90', '0.95', '28.55', '439.61'],
#  ['Coffee Day Enter.', '31.90', '31.60', '0.95', '0.30', '1917.19'],
#  ['Selan Exploratn Tech', '255.60', '253.20', '0.95', '2.40', '56.44'],
#  ['Prajay Engg.Syndicat', '10.65', '10.55', '0.95', '0.10', '31.30'],
#  ['Shoppers Stop', '644.10', '638.10', '0.94', '6.00', '18.70'],
#  ['Tata Consumer Produc', '694.00', '687.55', '0.94', '6.45', '974.83'],
#  ['Elecon Engg.', '385.00', '381.45', '0.93', '3.55', '346.68'],
#  ["Divi's Lab", '2801.60', '2775.80', '0.93', '25.80', '477.60'],
#  ['Ravinder Heights', '22.10', '21.90', '0.91', '0.20', '22.41'],
#  ['Creative Newtech', '429.20', '425.35', '0.91', '3.85', '4.77'],
#  ['Solara Active Pharma', '386.45', '383.00', '0.90', '3.45', '191.70'],
#  ['SKM Egg Products', '134.45', '133.25', '0.90', '1.20', '95.60'],
#  ['KSolves India', '449.95', '445.95', '0.90', '4.00', '17.67'],
#  ['Dishman Carbogen Amc', '130.95', '129.80', '0.89', '1.15', '548.43'],
#  ['Orient Press', '57.25', '56.75', '0.88', '0.50', '10.72'],
#  ['Symphony', '1124.80', '1115.00', '0.88', '9.80', '81.30'],
#  ['Future Enter.-B-DVR', '5.80', '5.75', '0.87', '0.05', '24.12'],
#  ['Schaeffler India', '2800.25', '2776.40', '0.86', '23.85', '123.34'],
#  ['Bajaj Finserv', '1293.60', '1282.60', '0.86', '11.00', '1539.28'],
#  ['Supreme Industries', '2509.85', '2488.55', '0.86', '21.30', '106.91'],
#  ['Hindware Home Innov.', '347.65', '344.70', '0.86', '2.95', '292.03'],
#  ['Vadilal Industries', '2213.10', '2194.50', '0.85', '18.60', '26.32'],
#  ['Rane Madras', '429.60', '426.00', '0.85', '3.60', '15.07'],
#  ['India Pesticides', '203.80', '202.10', '0.84', '1.70', '94.55'],
#  ['India Cements', '192.25', '190.65', '0.84', '1.60', '1623.35'],
#  ['Global Vectra Helico', '54.10', '53.65', '0.84', '0.45', '20.17'],
#  ['Texmaco Rail & Eng.', '43.35', '43.00', '0.81', '0.35', '1600.36'],
#  ['Kansai Nerolac Paint', '396.85', '393.65', '0.81', '3.20', '133.85'],
#  ['Securekloud Tech.', '43.55', '43.20', '0.81', '0.35', '72.29'],
#  ['Oberoi Realty', '854.20', '847.35', '0.81', '6.85', '305.80'],
#  ['Foods & Inns', '119.00', '118.05', '0.80', '0.95', '92.17'],
#  ['Rossell India', '250.60', '248.60', '0.80', '2.00', '12.56'],
#  ['United Breweries', '1453.95', '1442.40', '0.80', '11.55', '339.04'],
#  ['JB Chem & Pharma', '1961.20', '1945.65', '0.80', '15.55', '31.12'],
#  ['Axis Bank', '830.55', '824.05', '0.79', '6.50', '8791.38'],
#  ['NTPC', '179.60', '178.20', '0.79', '1.40', '9405.02'],
#  ['Autoline Inds', '64.50', '64.00', '0.78', '0.50', '158.87'],
#  ['Vodafone Idea', '6.45', '6.40', '0.78', '0.05', '70627.78'],
#  ['ABB India', '3327.95', '3302.25', '0.78', '25.70', '257.89'],
#  ['Rajdarshan Inds', '32.50', '32.25', '0.78', '0.25', '1.33'],
#  ['Voltas', '880.55', '873.80', '0.77', '6.75', '737.47'],
#  ['Dr. Lal Pathlabs', '1867.00', '1852.85', '0.76', '14.15', '171.78'],
#  ['Torrent Pharma', '1551.65', '1540.05', '0.75', '11.60', '339.47'],
#  ['Apollo Pipes', '569.20', '565.05', '0.73', '4.15', '172.62'],
#  ['Voltamp Transformers', '2749.50', '2729.50', '0.73', '20.00', '10.09'],
#  ['Ashima', '13.75', '13.65', '0.73', '0.10', '136.56'],
#  ['Dhunseri Ventures', '221.40', '219.80', '0.73', '1.60', '17.44'],
#  ['CMS Info Systems', '284.50', '282.45', '0.73', '2.05', '186.98'],
#  ['Celebrity Fashions', '13.95', '13.85', '0.72', '0.10', '59.63'],
#  ['Seya Industries', '28.20', '28.00', '0.71', '0.20', '16.64'],
#  ['Mohit Industries', '14.10', '14.00', '0.71', '0.10', '2.66'],
#  ['Vimta Labs', '306.75', '304.60', '0.71', '2.15', '19.68'],
#  ['L&T Finance Holdings', '85.75', '85.15', '0.70', '0.60', '3239.10'],
#  ['Shree Pushkar Chem', '159.45', '158.35', '0.69', '1.10', '44.60'],
#  ['LG Balakrishnan&Bros', '720.20', '715.25', '0.69', '4.95', '27.36'],
#  ['Dish TV India', '14.85', '14.75', '0.68', '0.10', '5477.53'],
#  ['Huhtamaki India', '195.00', '193.70', '0.67', '1.30', '22.92'],
#  ['Artemis Medicare', '67.60', '67.15', '0.67', '0.45', '78.33'],
#  ['BHEL', '75.60', '75.10', '0.67', '0.50', '10750.87'],
#  ['Mangalam Global Ent', '15.40', '15.30', '0.65', '0.10', '173.81'],
#  ['HDFC Bank', '1551.90', '1541.90', '0.65', '10.00', '10876.67'],
#  ['Shreyans Inds', '148.25', '147.30', '0.64', '0.95', '7.75'],
#  ['Grasim Industries', '1560.45', '1550.60', '0.64', '9.85', '581.06'],
#  ['JP Associate', '8.00', '7.95', '0.63', '0.05', '5632.29'],
#  ['PNB', '48.00', '47.70', '0.63', '0.30', '56323.40'],
#  ['JHS Svendgaard', '16.05', '15.95', '0.63', '0.10', '82.23'],
#  ['Silver Touch Tech.', '337.10', '335.00', '0.63', '2.10', '9.62'],
#  ['Cipla', '883.45', '877.95', '0.63', '5.50', '2024.00'],
#  ['Marico', '488.60', '485.60', '0.62', '3.00', '1104.68'],
#  ['Eros Internatl.Media', '25.00', '24.85', '0.60', '0.15', '294.15'],
#  ['K.P.R. Mill', '600.30', '596.70', '0.60', '3.60', '420.98'],
#  ['One Point OneSolutin', '16.85', '16.75', '0.60', '0.10', '1762.53'],
#  ['Transformers & Rect', '59.25', '58.90', '0.59', '0.35', '243.23'],
#  ['Garden Reach Ship', '407.15', '404.75', '0.59', '2.40', '236.31'],
#  ['Prime Securities', '101.85', '101.25', '0.59', '0.60', '90.09'],
#  ['ACC', '1750.30', '1740.00', '0.59', '10.30', '370.58'],
#  ['Poonawalla Fincorp', '281.30', '279.65', '0.59', '1.65', '1294.70'],
#  ['TGB Banquets', '8.70', '8.65', '0.58', '0.05', '51.05'],
#  ['Mahindra & Mahindra', '1167.05', '1160.35', '0.58', '6.70', '3604.48'],
#  ['SIRCA Paints India', '612.70', '609.20', '0.57', '3.50', '11.39'],
#  ['Ugro Capital', '149.40', '148.55', '0.57', '0.85', '43.11'],
#  ['Shree Cement', '25472.95', '25331.10', '0.56', '141.85', '40.52'],
#  ['Federal Bank', '127.30', '126.60', '0.55', '0.70', '9318.76'],
#  ['NRB Bearings', '128.95', '128.25', '0.55', '0.70', '109.36'],
#  ['Indo-National', '323.95', '322.20', '0.54', '1.75', '1.86'],
#  ['Tejas Networks', '584.70', '581.55', '0.54', '3.15', '425.60'],
#  ['ITC', '381.45', '379.40', '0.54', '2.05', '15710.09'],
#  ['Castrol India', '111.70', '111.10', '0.54', '0.60', '729.25'],
#  ['Bhageria Industries', '130.55', '129.85', '0.54', '0.70', '8.48'],
#  ['SMC Global Sec.', '74.85', '74.45', '0.54', '0.40', '135.96'],
#  ['Archies', '18.80', '18.70', '0.53', '0.10', '23.48'],
#  ['MTNL', '18.95', '18.85', '0.53', '0.10', '1236.21'],
#  ['Intellect Design', '401.65', '399.55', '0.53', '2.10', '484.86'],
#  ['Kilitch Drugs(India)', '143.45', '142.70', '0.53', '0.75', '13.91'],
#  ['Sukhjit Starch &Chem', '383.30', '381.30', '0.52', '2.00', '6.73'],
#  ['Gokul Agro Resources', '105.85', '105.30', '0.52', '0.55', '60.51'],
#  ['Narayana Hrudayalay', '805.90', '801.75', '0.52', '4.15', '253.09'],
#  ['HLV', '9.75', '9.70', '0.52', '0.05', '247.54'],
#  ['Spandana Sphoorty', '547.70', '544.90', '0.51', '2.80', '21.26'],
#  ['D.B. Corp', '98.00', '97.50', '0.51', '0.50', '231.17'],
#  ['GE T&D India', '117.90', '117.30', '0.51', '0.60', '91.84'],
#  ['Dwarikesh Sugar Inds', '88.45', '88.00', '0.51', '0.45', '1032.16'],
#  ['Max India', '80.85', '80.45', '0.50', '0.40', '125.53'],
#  ['Indian Energy Exch', '152.20', '151.45', '0.50', '0.75', '7008.03'],
#  ['Maral Overseas', '51.05', '50.80', '0.49', '0.25', '2.43'],
#  ['Share India Sec.', '1016.10', '1011.15', '0.49', '4.95', '110.65'],
#  ['Swan Energy', '246.80', '245.60', '0.49', '1.20', '3111.85'],
#  ['Sharda Motor Inds.', '609.20', '606.25', '0.49', '2.95', '11.07'],
#  ['Petronet LNG', '237.85', '236.70', '0.49', '1.15', '4126.16'],
#  ['Birla Corporation', '862.40', '858.35', '0.47', '4.05', '102.93'],
#  ['Star Cement', '107.30', '106.80', '0.47', '0.50', '134.69'],
#  ['Rites', '343.80', '342.20', '0.47', '1.60', '333.73'],
#  ['Praj Industries', '336.15', '334.60', '0.46', '1.55', '307.07'],
#  ['Surya Roshni', '664.30', '661.25', '0.46', '3.05', '275.16'],
#  ['GAIL India', '109.55', '109.05', '0.46', '0.50', '26757.81'],
#  ['Superhouse', '230.35', '229.30', '0.46', '1.05', '14.91'],
#  ['Pressman Advertising', '66.95', '66.65', '0.45', '0.30', '51.20'],
#  ['Tata Elxsi', '6115.10', '6088.05', '0.44', '27.05', '101.50'],
#  ['Wanbury', '34.30', '34.15', '0.44', '0.15', '4.97'],
#  ['Indraprastha Medical', '80.05', '79.70', '0.44', '0.35', '26.84'],
#  ['Kesoram Industries', '57.30', '57.05', '0.44', '0.25', '318.36'],
#  ['B&B Triplewall', '207.35', '206.45', '0.44', '0.90', '7.89'],
#  ['Heritage Foods', '138.40', '137.80', '0.44', '0.60', '76.04'],
#  ['Equippp Social', '34.85', '34.70', '0.43', '0.15', '4.32'],
#  ['Coal India', '220.85', '219.90', '0.43', '0.95', '4988.24'],
#  ['MIC Electronics', '11.85', '11.80', '0.42', '0.05', '36.34'],
#  ['R Systems Intl.', '251.05', '250.00', '0.42', '1.05', '66.92'],
#  ['Container Corp', '592.35', '589.90', '0.42', '2.45', '696.94'],
#  ['Bosch', '18118.35', '18043.60', '0.41', '74.75', '24.60'],
#  ['CentralBank of India', '24.35', '24.25', '0.41', '0.10', '6820.54'],
#  ['Nahar Spinning Mills', '258.60', '257.55', '0.41', '1.05', '109.65'],
#  ['Usha Martin', '210.15', '209.30', '0.41', '0.85', '922.45'],
#  ['Meghmani Organics', '86.65', '86.30', '0.41', '0.35', '417.90'],
#  ['Pilani Investment', '1724.15', '1717.25', '0.40', '6.90', '1.80'],
#  ['Kajaria Ceramics', '1074.90', '1070.60', '0.40', '4.30', '125.89'],
#  ['Filatex India', '37.70', '37.55', '0.40', '0.15', '278.15'],
#  ['Atul Auto', '323.05', '321.80', '0.39', '1.25', '277.70'],
#  ['REC', '117.20', '116.75', '0.39', '0.45', '8218.71'],
#  ['Hi-Tech Gears', '253.40', '252.45', '0.38', '0.95', '2.00'],
#  ['Waterbase', '67.10', '66.85', '0.37', '0.25', '30.18'],
#  ['Shankara Bldg. Prod', '660.05', '657.60', '0.37', '2.45', '17.43'],
#  ['Bharat Wire Ropes', '109.20', '108.80', '0.37', '0.40', '126.07'],
#  ['Tarsons Products', '573.50', '571.40', '0.37', '2.10', '67.60'],
#  ['Khandwala Securities', '27.45', '27.35', '0.37', '0.10', '3.00'],
#  ['Sreeleathers', '167.35', '166.75', '0.36', '0.60', '3.40'],
#  ['Tainwala Chem&Plast.', '112.15', '111.75', '0.36', '0.40', '8.18'],
#  ['HDFC Asset Mngt. Co', '1682.65', '1676.75', '0.35', '5.90', '655.60'],
#  ['5Paisa Capital', '286.75', '285.75', '0.35', '1.00', '20.72'],
#  ['Punjab Chem. & Corp', '892.75', '889.65', '0.35', '3.10', '8.22'],
#  ['PSP Projects', '665.60', '663.30', '0.35', '2.30', '107.57'],
#  ['Responsive Inds', '115.90', '115.50', '0.35', '0.40', '4.41'],
#  ['Bank Of Baroda', '159.75', '159.20', '0.35', '0.55', '24291.23'],
#  ['Ajmera Realty&Infra', '275.95', '275.00', '0.35', '0.95', '39.77'],
#  ['Escorts Kubota', '1896.05', '1889.55', '0.34', '6.50', '232.46'],
#  ['Swelect Energy', '278.25', '277.30', '0.34', '0.95', '6.81'],
#  ['VLS Finance', '178.80', '178.20', '0.34', '0.60', '88.21'],
#  ['Lotus Eye Hospital', '59.90', '59.70', '0.34', '0.20', '6.47'],
#  ['Arvind Smartspaces', '239.95', '239.15', '0.33', '0.80', '27.86'],
#  ['Marathon NextgenReal', '274.40', '273.50', '0.33', '0.90', '24.51'],
#  ['Bodal Chemicals', '61.35', '61.15', '0.33', '0.20', '184.32'],
#  ['Shanti Overseas Ind.', '15.80', '15.75', '0.32', '0.05', '8.41'],
#  ['Bajaj Electricals', '1076.95', '1073.55', '0.32', '3.40', '28.02'],
#  ['Accuracy Shipping', '15.95', '15.90', '0.31', '0.05', '131.87'],
#  ['ZF Comm Vehic Contr', '10192.15', '10160.45', '0.31', '31.70', '2.19'],
#  ['Kalyani Steels', '306.55', '305.60', '0.31', '0.95', '18.60'],
#  ['Bhartiya Internatl.', '177.55', '177.00', '0.31', '0.55', '6.16'],
#  ['Godrej Industries', '408.25', '407.00', '0.31', '1.25', '113.30'],
#  ['Energy Development', '16.45', '16.40', '0.30', '0.05', '34.76'],
#  ['Tech Mahindra', '1117.75', '1114.40', '0.30', '3.35', '2396.84'],
#  ['Mphasis', '1905.05', '1899.35', '0.30', '5.70', '333.66'],
#  ['Orient Electric', '267.60', '266.80', '0.30', '0.80', '359.75'],
#  ['Technocraft Inds', '1225.60', '1222.00', '0.29', '3.60', '33.13'],
#  ['Choice International', '255.70', '254.95', '0.29', '0.75', '34.14'],
#  ['Venus Remedies', '154.70', '154.25', '0.29', '0.45', '42.67'],
#  ['FSN E-Commerce', '138.10', '137.70', '0.29', '0.40', '7797.38'],
#  ['Karnataka Bank', '139.25', '138.85', '0.29', '0.40', '1063.07'],
#  ['Jain Irrigation(DVR)', '17.45', '17.40', '0.29', '0.05', '93.20'],
#  ['TARC', '35.65', '35.55', '0.28', '0.10', '272.79'],
#  ['Gland Pharma', '1217.75', '1214.45', '0.27', '3.30', '406.02'],
#  ['Biocon', '221.85', '221.25', '0.27', '0.60', '2654.39'],
#  ['Can Fin Homes', '521.15', '519.75', '0.27', '1.40', '476.80'],
#  ['Kirloskar Industries', '2257.75', '2251.70', '0.27', '6.05', '4.03'],
#  ['Kirloskar Ferrous', '448.75', '447.55', '0.27', '1.20', '467.95'],
#  ['BASF India', '2282.10', '2276.10', '0.26', '6.00', '18.95'],
#  ['Adani Enterprises', '1843.80', '1839.00', '0.26', '4.80', '6509.49'],
#  ['Dynemic Products', '268.90', '268.20', '0.26', '0.70', '24.93'],
#  ['Apollo Tyres', '308.95', '308.15', '0.26', '0.80', '1675.20'],
#  ['PNB Gilts', '58.20', '58.05', '0.26', '0.15', '125.70'],
#  ['GE Shipping', '591.15', '589.65', '0.25', '1.50', '504.48'],
#  ['Godawari Power & Isp', '374.45', '373.50', '0.25', '0.95', '897.43'],
#  ['3P Land Holdings', '20.10', '20.05', '0.25', '0.05', '8.42'],
#  ['Incredible Indu', '20.10', '20.05', '0.25', '0.05', '4.06'],
#  ['Matrimony.Com', '524.40', '523.10', '0.25', '1.30', '6.18'],
#  ['Prism Johnson', '103.10', '102.85', '0.24', '0.25', '183.59'],
#  ['MM Forgings', '839.45', '837.45', '0.24', '2.00', '11.75'],
#  ['ICDS', '21.25', '21.20', '0.24', '0.05', '0.81'],
#  ['Lakshmi Machine Work', '10158.25', '10134.90', '0.23', '23.35', '3.17'],
#  ['Kriti Nutrients', '44.05', '43.95', '0.23', '0.10', '11.35'],
#  ['Alembic Pharma', '486.55', '485.45', '0.23', '1.10', '173.23'],
#  ['Harsha Engineers Int', '332.25', '331.50', '0.23', '0.75', '112.95'],
#  ['Tata Power', '203.40', '202.95', '0.22', '0.45', '7483.70'],
#  ['State Trading Corp', '68.70', '68.55', '0.22', '0.15', '11.94'],
#  ['Indian Overseas Bank', '23.10', '23.05', '0.22', '0.05', '14093.27'],
#  ['Astrazeneca Pharma I', '3267.15', '3260.30', '0.21', '6.85', '2.44'],
#  ['Astron Paper & Board', '24.20', '24.15', '0.21', '0.05', '2889.62'],
#  ['Tide Water Oil Co(I)', '903.80', '901.95', '0.21', '1.85', '10.47'],
#  ['Stylam Industries', '1000.80', '998.80', '0.20', '2.00', '24.77'],
#  ['KM Sugar Mills', '25.15', '25.10', '0.20', '0.05', '233.63'],
#  ['Schneider Ele. Infra', '154.70', '154.40', '0.19', '0.30', '325.02'],
#  ['Suven Pharma', '473.40', '472.50', '0.19', '0.90', '193.88'],
#  ['Vedant Fashions', '1141.20', '1139.05', '0.19', '2.15', '50.79'],
#  ['The Ramco Cements', '717.10', '715.75', '0.19', '1.35', '221.16'],
#  ['Lumax Auto Tech', '268.05', '267.55', '0.19', '0.50', '141.38'],
#  ['Indian Railway Finance', '27.05', '27.00', '0.19', '0.05', '16145.41'],
#  ['360 One Wam', '433.10', '432.30', '0.19', '0.80', '151.17'],
#  ['Triveni Engg. & Inds', '271.45', '270.95', '0.18', '0.50', '444.13'],
#  ['Titagarh Wagons', '244.55', '244.10', '0.18', '0.45', '683.98'],
#  ['Exxaro Tiles', '110.55', '110.35', '0.18', '0.20', '35.57'],
#  ['V2 Retail', '83.80', '83.65', '0.18', '0.15', '15.26'],
#  ['Canara Bank', '281.65', '281.15', '0.18', '0.50', '9840.73'],
#  ['Agarwal Indl. Corp', '593.50', '592.45', '0.18', '1.05', '22.53'],
#  ['Allied Digital Serv.', '85.15', '85.00', '0.18', '0.15', '85.42'],
#  ['Steel Strips Wheels', '144.45', '144.20', '0.17', '0.25', '91.76'],
#  ['Steel City Securitie', '58.70', '58.60', '0.17', '0.10', '4.74'],
#  ['Priti International', '149.45', '149.20', '0.17', '0.25', '8.24'],
#  ['BCL Industries', '420.00', '419.30', '0.17', '0.70', '423.54'],
#  ['Oracle Finl. Service', '3205.40', '3200.15', '0.16', '5.25', '54.49'],
#  ['IIFL Finance', '428.50', '427.80', '0.16', '0.70', '291.09'],
#  ['Bombay Burmah Trdg.', '864.45', '863.10', '0.16', '1.35', '18.70'],
#  ['Menon Bearings', '96.60', '96.45', '0.16', '0.15', '26.57'],
#  ['Elgi Rubber Co.', '32.25', '32.20', '0.16', '0.05', '14.00'],
#  ['Global Health', '492.80', '492.05', '0.15', '0.75', '522.18'],
#  ['Electronics Mart Ind', '66.50', '66.40', '0.15', '0.10', '336.36'],
#  ['Mahalaxmi Rubtech', '272.20', '271.80', '0.15', '0.40', '80.02'],
#  ['TCPL Packaging', '1285.55', '1283.70', '0.14', '1.85', '6.60'],
#  ['Balrampur Chini Mill', '389.15', '388.60', '0.14', '0.55', '1285.76'],
#  ['Aditya Birla Sun AMC', '356.65', '356.15', '0.14', '0.50', '95.23'],
#  ['Mold-tek Packaging', '943.70', '942.40', '0.14', '1.30', '89.65'],
#  ['Kopran', '109.05', '108.90', '0.14', '0.15', '480.33'],
#  ['AU Small Fin. Bank', '584.00', '583.20', '0.14', '0.80', '1453.33'],
#  ['Engineers India', '76.60', '76.50', '0.13', '0.10', '1992.59'],
#  ['Rallis India', '193.25', '193.00', '0.13', '0.25', '121.01'],
#  ['Fusion Micro Fin.', '398.55', '398.05', '0.13', '0.50', '105.59'],
#  ['Uma Expo', '40.70', '40.65', '0.12', '0.05', '20.60'],
#  ['Aditya Birla Fashion', '215.00', '214.75', '0.12', '0.25', '2623.58'],
#  ['Salasar Techno Engg.', '43.35', '43.30', '0.12', '0.05', '319.64'],
#  ['Colgate Palmol. (I)', '1500.15', '1498.50', '0.11', '1.65', '313.22'],
#  ['HDFC', '2531.60', '2528.85', '0.11', '2.75', '3940.60'],
#  ['Bhagyanagar India', '46.70', '46.65', '0.11', '0.05', '12.99'],
#  ['Vardhman Acrylics', '47.55', '47.50', '0.11', '0.05', '110.17'],
#  ['RateGain Travel', '333.80', '333.45', '0.10', '0.35', '197.82'],
#  ['Laurus Labs', '305.75', '305.45', '0.10', '0.30', '1212.83'],
#  ['Kriti Industries (I)', '102.10', '102.00', '0.10', '0.10', '43.98'],
#  ['Fairchem Organics', '965.70', '964.80', '0.09', '0.90', '11.76'],
#  ['Orient Bell', '503.60', '503.15', '0.09', '0.45', '15.69'],
#  ['Firstsource Solution', '112.00', '111.90', '0.09', '0.10', '2127.15'],
#  ['Chola Invest & Fin.', '746.65', '746.00', '0.09', '0.65', '848.38'],
#  ['NXTDigital', '117.20', '117.10', '0.09', '0.10', '10.31'],
#  ['Mah & Mah Finl. Serv', '242.15', '241.95', '0.08', '0.20', '2168.83'],
#  ['Whirlpool Of India', '1340.90', '1339.80', '0.08', '1.10', '86.53'],
#  ['Zensar Technologies', '268.10', '267.90', '0.07', '0.20', '1130.81'],
#  ['Rajratan Global Wire', '717.50', '717.00', '0.07', '0.50', '38.43'],
#  ['GM Breweries', '554.35', '554.00', '0.06', '0.35', '10.50'],
#  ['Aries Agro', '159.80', '159.70', '0.06', '0.10', '62.87'],
#  ['ICICI Lombard Gen.', '1061.30', '1060.65', '0.06', '0.65', '302.07'],
#  ['Aether Industries', '862.70', '862.20', '0.06', '0.50', '13.51'],
#  ['Tokyo Plast Intl.', '92.05', '92.00', '0.05', '0.05', '3.46'],
#  ['Ultratech Cement', '7104.60', '7100.75', '0.05', '3.85', '459.81'],
#  ['Home First Finance', '671.35', '671.00', '0.05', '0.35', '226.84'],
#  ['Jagsonpal Pharma', '296.60', '296.45', '0.05', '0.15', '9.26'],
#  ['UTI Asset Management', '660.40', '660.10', '0.05', '0.30', '83.14'],
#  ['Johnson Controls', '1106.55', '1106.10', '0.04', '0.45', '15.87'],
#  ['Barbeque-Nation Hosp', '674.25', '674.00', '0.04', '0.25', '32.29'],
#  ['TeamLease Services', '2429.55', '2428.65', '0.04', '0.90', '8.49'],
#  ['Adani Ports &Special', '679.60', '679.35', '0.04', '0.25', '12992.24'],
#  ['Nath Bio-Genes', '146.80', '146.75', '0.03', '0.05', '36.62'],
#  ['Euro India FreshFood', '150.65', '150.60', '0.03', '0.05', '43.73'],
#  ['Wockhardt', '171.10', '171.05', '0.03', '0.05', '991.18'],
#  ['FDC', '249.90', '249.85', '0.02', '0.05', '47.41'],
#  ['Vishnu Chemicals', '262.25', '262.20', '0.02', '0.05', '47.46'],
#  ['Banna Amman Sugars', '2711.80', '2711.30', '0.02', '0.50', '0.45'],
#  ['Force Motors', '1221.00', '1220.85', '0.01', '0.15', '24.72'],
#  ['Shivalik Rasayan', '629.20', '629.15', '0.01', '0.05', '4.26'],
#  [],
#  ['Simplex Infrastruct.', '37.50', '43.20', '-13.19', '-5.70', '1033.33'],
#  ['SamvardhanaMotherson', '68.50', '76.80', '-10.81', '-8.30', '419907.53'],
#  ['Brightcom Group', '17.45', '19.40', '-10.05', '-1.95', '54544.82'],
#  ['Bhagiradha Chem', '1187.05', '1301.15', '-8.77', '-114.10', '13.61'],
#  ['Uniinfo Telecom Serv', '19.40', '21.25', '-8.71', '-1.85', '106.95'],
#  ['Panama Petrochem', '276.45', '300.75', '-8.08', '-24.30', '245.49'],
#  ['Indo Count Inds', '115.40', '125.30', '-7.90', '-9.90', '468.14'],
#  ['Dangee Dums', '14.95', '16.20', '-7.72', '-1.25', '381.67'],
#  ['Antarctica', '0.60', '0.65', '-7.69', '-0.05', '500.16'],
#  ['Aarey Drugs & Pharma', '25.75', '27.85', '-7.54', '-2.10', '91.81'],
#  ['Indoco Remedies', '320.35', '344.95', '-7.13', '-24.60', '414.71'],
#  ['Mold-Tek Tech', '229.25', '246.75', '-7.09', '-17.50', '319.82'],
#  ['Jindal Drilling&Inds', '257.40', '276.15', '-6.79', '-18.75', '86.02'],
#  ['Super Spinning Mills', '7.10', '7.60', '-6.58', '-0.50', '127.30'],
#  ['Narmada Agrobase', '19.95', '21.30', '-6.34', '-1.35', '33.94'],
#  ['Barak Valley Cements', '23.80', '25.40', '-6.30', '-1.60', '10.45'],
#  ['AYM Syntex', '65.80', '70.10', '-6.13', '-4.30', '40.91'],
#  ['Orissa BengalCarrier', '63.70', '67.80', '-6.05', '-4.10', '50.23'],
#  ['Mittal Life Style', '10.20', '10.85', '-5.99', '-0.65', '77.04'],
#  ['AAA Technologies', '49.50', '52.55', '-5.80', '-3.05', '8.83'],
#  ['Chennai Petrol. Corp', '253.55', '269.00', '-5.74', '-15.45', '2179.69'],
#  ['DRC Systems India', '33.10', '35.10', '-5.70', '-2.00', '46.82'],
#  ['Advanced Enzyme', '240.20', '254.60', '-5.66', '-14.40', '264.56'],
#  ['BAG Films & Media', '4.20', '4.45', '-5.62', '-0.25', '161.85'],
#  ['Shaily Engg. Plastic', '1010.40', '1070.00', '-5.57', '-59.60', '5.10'],
#  ['eMudhra', '225.35', '238.50', '-5.51', '-13.15', '165.75'],
#  ['Olectra Greentech', '598.15', '632.65', '-5.45', '-34.50', '1843.08'],
#  ['DCB Bank', '97.95', '103.55', '-5.41', '-5.60', '2290.87'],
#  ['Time Technoplast', '73.75', '77.95', '-5.39', '-4.20', '1317.97'],
#  ['JK Paper', '350.20', '370.05', '-5.36', '-19.85', '940.11'],
#  ['Mitcon Consultancy', '63.40', '66.95', '-5.30', '-3.55', '12.97'],
#  ['Hindalco', '384.95', '406.15', '-5.22', '-21.20', '16739.76'],
#  ['Bharat Road Network', '26.90', '28.35', '-5.11', '-1.45', '83.68'],
#  ['Ind-Swift', '7.50', '7.90', '-5.06', '-0.40', '55.89'],
#  ['Yaari Digital Integ', '12.20', '12.85', '-5.06', '-0.65', '206.72'],
#  ['Suratwwala Business', '175.00', '184.25', '-5.02', '-9.25', '6.69'],
#  ['Paramount Communicat', '29.40', '30.95', '-5.01', '-1.55', '895.44'],
#  ['Palash Securities', '90.15', '94.90', '-5.01', '-4.75', '5.28'],
#  ['Manali Petro', '61.75', '65.00', '-5.00', '-3.25', '859.95'],
#  ['Tirupati Forge', '9.50', '10.00', '-5.00', '-0.50', '606.30'],
#  ['Nintec Systems', '273.75', '288.15', '-5.00', '-14.40', '4.30'],
#  ['Brooks Laboratories', '67.50', '71.05', '-5.00', '-3.55', '69.17'],
#  ['Steelcast', '450.70', '474.30', '-4.98', '-23.60', '57.51'],
#  ['SVP Global Textiles', '16.25', '17.10', '-4.97', '-0.85', '772.42'],
#  ['Manomay Tex India', '116.65', '122.75', '-4.97', '-6.10', '0.63'],
#  ['Industl. Invst.Trust', '87.15', '91.70', '-4.96', '-4.55', '6.18'],
#  ['Nakoda Group', '58.65', '61.70', '-4.94', '-3.05', '21.53'],
#  ['Arvee Laboratories', '93.65', '98.50', '-4.92', '-4.85', '0.50'],
#  ['DSJ Keep Learning', '2.90', '3.05', '-4.92', '-0.15', '14.65'],
#  ['Future Lifestyle', '5.80', '6.10', '-4.92', '-0.30', '250.31'],
#  ['PC Jeweller', '28.05', '29.50', '-4.92', '-1.45', '4496.12'],
#  ['Suumaya Industries', '14.55', '15.30', '-4.90', '-0.75', '90.25'],
#  ['Jubilant Pharmova', '277.85', '292.15', '-4.89', '-14.30', '400.44'],
#  ['OSIA Hyper Retail', '35.00', '36.80', '-4.89', '-1.80', '425.41'],
#  ['Vijaya Diagnostic', '377.35', '396.75', '-4.89', '-19.40', '128.27'],
#  ['Xpro India', '609.25', '640.40', '-4.86', '-31.15', '101.97'],
#  ['Future Supply Chain', '13.75', '14.45', '-4.84', '-0.70', '23.44'],
#  ['Niraj Cement Struct.', '25.70', '27.00', '-4.81', '-1.30', '8.42'],
#  ['Alkali Metals', '94.95', '99.75', '-4.81', '-4.80', '24.45'],
#  ['Sanco Industries', '7.95', '8.35', '-4.79', '-0.40', '8.20'],
#  ['The Investment Trust', '72.65', '76.25', '-4.72', '-3.60', '42.59'],
#  ['Tracxn Technologies', '67.80', '71.15', '-4.71', '-3.35', '1452.48'],
#  ['Apar Inds', '2208.30', '2317.10', '-4.70', '-108.80', '138.63'],
#  ['DC Infotech and Comm', '112.35', '117.85', '-4.67', '-5.50', '5.21'],
#  ['Shree RamaMulti-Tech', '9.20', '9.65', '-4.66', '-0.45', '99.49'],
#  ['PNB Housing Finance', '497.95', '522.30', '-4.66', '-24.35', '1465.74'],
#  ['Siyaram Silk Mills', '444.85', '466.55', '-4.65', '-21.70', '229.94'],
#  ['Morarjee Textiles', '17.60', '18.45', '-4.61', '-0.85', '19.47'],
#  ['Jindal Steel & Power', '553.70', '580.15', '-4.56', '-26.45', '4208.64'],
#  ['S.E. Power', '13.70', '14.35', '-4.53', '-0.65', '22.47'],
#  ['Univastu India', '81.35', '85.20', '-4.52', '-3.85', '27.49'],
#  ['Blue Star', '1420.60', '1487.80', '-4.52', '-67.20', '90.41'],
#  ['Bartronics India', '5.30', '5.55', '-4.50', '-0.25', '26.13'],
#  ['Tree House Education', '13.85', '14.50', '-4.48', '-0.65', '26.66'],
#  ['Archidply Decor', '55.40', '58.00', '-4.48', '-2.60', '0.38'],
#  ['Camlin Fine Sciences', '136.90', '143.30', '-4.47', '-6.40', '257.02'],
#  ['HB Stockholdings', '47.30', '49.50', '-4.44', '-2.20', '14.49'],
#  ['Arshiya', '6.45', '6.75', '-4.44', '-0.30', '1830.95'],
#  ['Thomas Scott', '34.45', '36.05', '-4.44', '-1.60', '0.34'],
#  ['Kiri Industries', '278.95', '291.90', '-4.44', '-12.95', '147.50'],
#  ['Hindprakash Indust', '79.15', '82.80', '-4.41', '-3.65', '1.40'],
#  ['Krsnaa Diagnostics', '376.50', '393.85', '-4.41', '-17.35', '197.14'],
#  ['Crest Ventures', '154.30', '161.40', '-4.40', '-7.10', '7.43'],
#  ['SH Kelkar & Co', '93.50', '97.80', '-4.40', '-4.30', '266.93'],
#  ['Ambica Agarbathies', '20.90', '21.85', '-4.35', '-0.95', '25.79'],
#  ['Greenpanel Inds.', '272.90', '285.10', '-4.28', '-12.20', '439.32'],
#  ['Suven Life Sciences', '49.30', '51.50', '-4.27', '-2.20', '301.27'],
#  ['Future MarketNetwork', '4.50', '4.70', '-4.26', '-0.20', '112.33'],
#  ['Manaksia Coated', '15.75', '16.45', '-4.26', '-0.70', '54.41'],
#  ['Cinevista', '10.15', '10.60', '-4.25', '-0.45', '43.69'],
#  ['3I Infotech', '30.65', '32.00', '-4.22', '-1.35', '578.06'],
#  ['Maha Rashtra Apex', '95.15', '99.30', '-4.18', '-4.15', '10.36'],
#  ['Compucom Software', '16.05', '16.75', '-4.18', '-0.70', '60.78'],
#  ['West Coast Paper', '490.45', '511.70', '-4.15', '-21.25', '169.21'],
#  ['Saksoft', '143.15', '149.35', '-4.15', '-6.20', '668.05'],
#  ['Nitiraj Engineers', '67.25', '70.15', '-4.13', '-2.90', '34.19'],
#  ['JITF Infralogistics', '89.75', '93.60', '-4.11', '-3.85', '35.45'],
#  ['TV Vision', '2.35', '2.45', '-4.08', '-0.10', '0.24'],
#  ['Tarmat', '80.35', '83.75', '-4.06', '-3.40', '188.70'],
#  ['Hitech Corporation', '182.90', '190.60', '-4.04', '-7.70', '6.30'],
#  ['Rushil Decor', '297.85', '310.35', '-4.03', '-12.50', '80.48'],
#  ['Arihant Superstruct.', '189.90', '197.85', '-4.02', '-7.95', '14.61'],
# ...
#  ['Tata Steel', '105.05', '108.65', '-3.31', '-3.60', '81088.34'],
#  ['Karma Energy', '30.65', '31.70', '-3.31', '-1.05', '4.82'],
#  ['IVP', '118.55', '122.60', '-3.30', '-4.05', '5.08'],
#  ['NMDC', '113.15', '117.00', '-3.29', '-3.85', '7868.89'],
#  ['Andhra Sugars', '113.90', '117.75', '-3.27', '-3.85', '221.98'],
#  ['GNA  Axles', '862.20', '891.30', '-3.26', '-29.10', '35.48'],
#  ['Premier Polyfilm', '77.10', '79.70', '-3.26', '-2.60', '82.44'],
#  ['Lypsa Gems', '4.45', '4.60', '-3.26', '-0.15', '28.78'],
#  ['Ruby Mills', '159.35', '164.70', '-3.25', '-5.35', '15.08'],
#  ['Palred Technologies', '134.45', '138.95', '-3.24', '-4.50', '10.47'],
#  ['Asahi Songwon Colors', '179.75', '185.75', '-3.23', '-6.00', '10.56'],
#  ['Wealth First Port', '300.00', '310.00', '-3.23', '-10.00', '0.47'],
#  ['Veto Switchgears', '82.65', '85.40', '-3.22', '-2.75', '50.65'],
#  ['Avanti Feeds', '344.95', '356.40', '-3.21', '-11.45', '631.68'],
#  ['Tata Steel Long Prod', '628.15', '648.95', '-3.21', '-20.80', '45.35'],
#  ['GATI', '103.35', '106.75', '-3.19', '-3.40', '568.01'],
#  ['Hind Rectifiers', '202.25', '208.90', '-3.18', '-6.65', '3.75'],
#  ['RKEC Projects', '53.35', '55.10', '-3.18', '-1.75', '23.07'],
#  ['SAL Steels', '15.30', '15.80', '-3.16', '-0.50', '156.37'],
#  ['MMP Industries', '117.85', '121.70', '-3.16', '-3.85', '49.15'],
#  ['Plastiblends India', '151.65', '156.60', '-3.16', '-4.95', '13.05'],
#  ['Laxmi Organic Inds.', '235.00', '242.65', '-3.15', '-7.65', '485.49'],
#  ['Gayatri Projects', '6.15', '6.35', '-3.15', '-0.20', '433.68'],
#  ['Hathway Cable & Data', '13.85', '14.30', '-3.15', '-0.45', '4774.54'],
#  ['Welspun India', '64.75', '66.85', '-3.14', '-2.10', '1161.15'],
#  ['Digjam', '91.05', '94.00', '-3.14', '-2.95', '1.58'],
#  ['Panache Digilife', '61.95', '63.95', '-3.13', '-2.00', '25.73'],
#  ['Reliance Comm', '1.55', '1.60', '-3.13', '-0.05', '2327.84'],
#  ['Tembo Global Inds.', '160.05', '165.20', '-3.12', '-5.15', '886.10'],
#  ['GMR Power and Urban', '17.10', '17.65', '-3.12', '-0.55', '682.67'],
#  ['Tata Metaliks', '741.85', '765.70', '-3.11', '-23.85', '52.72'],
#  ['Manaksia Steels', '37.35', '38.55', '-3.11', '-1.20', '32.64'],
#  ['Triveni Turbine', '299.50', '309.10', '-3.11', '-9.60', '1710.00'],
#  ['Himatsingka Seide', '76.55', '79.00', '-3.10', '-2.45', '200.86'],
#  ['Indowind Energy', '10.95', '11.30', '-3.10', '-0.35', '184.23'],
#  ['Guj Raffia Inds', '25.10', '25.90', '-3.09', '-0.80', '0.83'],
#  ['ISGEC Heavy Engg.', '455.30', '469.80', '-3.09', '-14.50', '68.25'],
#  ['Banco Products (I)', '230.85', '238.20', '-3.09', '-7.35', '230.84'],
#  ['Jindal Photo', '298.15', '307.60', '-3.07', '-9.45', '14.61'],
#  ['Khadim India', '183.15', '188.95', '-3.07', '-5.80', '19.60'],
#  ['Ram Ratna Wires', '161.35', '166.45', '-3.06', '-5.10', '35.73'],
#  ['Pennar Industries', '68.05', '70.20', '-3.06', '-2.15', '678.63'],
#  ['Heads UP Ventures', '12.70', '13.10', '-3.05', '-0.40', '191.73'],
#  ['Tinplate Company', '310.00', '319.75', '-3.05', '-9.75', '158.13'],
#  ['Sri Adhikari Brother', '1.60', '1.65', '-3.03', '-0.05', '5.83'],
#  ['HLE Glascoat', '485.35', '500.50', '-3.03', '-15.15', '69.42'],
#  ['LT Foods', '94.65', '97.60', '-3.02', '-2.95', '606.72'],
#  ['VIP Clothing', '38.85', '40.05', '-3.00', '-1.20', '173.32'],
#  ['Remsons Inds', '202.55', '208.80', '-2.99', '-6.25', '7.37'],
#  ['Vardhman Textiles', '301.00', '310.25', '-2.98', '-9.25', '653.10'],
#  ['Tanla Platforms', '586.35', '604.30', '-2.97', '-17.95', '378.69'],
#  ['GRP', '2654.80', '2736.00', '-2.97', '-81.20', '1.20'],
#  ['Gateway Distriparks', '60.50', '62.35', '-2.97', '-1.85', '380.31'],
#  ['Vertoz Advertising', '211.65', '218.10', '-2.96', '-6.45', '157.58'],
#  ['Arman Financial Serv', '1244.05', '1281.95', '-2.96', '-37.90', '19.72'],
#  ['Landmark Cars', '512.70', '528.25', '-2.94', '-15.55', '28.39'],
#  ['Varun Beverages', '1306.15', '1345.65', '-2.94', '-39.50', '3100.23'],
#  ['Vaswani Industries', '21.50', '22.15', '-2.93', '-0.65', '127.22'],
#  ['Ashoka Buildcon', '76.15', '78.45', '-2.93', '-2.30', '910.88'],
#  ['Yes Bank', '14.90', '15.35', '-2.93', '-0.45', '207783.63'],
#  ['Refex Industries', '230.40', '237.35', '-2.93', '-6.95', '117.73'],
#  ['GRM Overseas', '218.15', '224.70', '-2.91', '-6.55', '63.68'],
#  ['IZMO', '81.70', '84.15', '-2.91', '-2.45', '61.07'],
#  ['Action Const. Equip', '361.05', '371.85', '-2.90', '-10.80', '584.70'],
#  ['Rupa & Co', '212.85', '219.20', '-2.90', '-6.35', '213.01'],
#  ['Neuland Laboratories', '1631.90', '1680.55', '-2.89', '-48.65', '12.99'],
#  ['Cosmo First', '599.30', '617.15', '-2.89', '-17.85', '55.40'],
#  ['ACE Integrated Solut', '42.05', '43.30', '-2.89', '-1.25', '4.26'],
#  ['IFGL Refractories', '218.20', '224.65', '-2.87', '-6.45', '17.88'],
#  ['Nandan Denim', '18.65', '19.20', '-2.86', '-0.55', '83.99'],
#  ['Aspinwall & Co', '200.25', '206.15', '-2.86', '-5.90', '1.39'],
#  ['Oswal Greentech', '17.05', '17.55', '-2.85', '-0.50', '286.95'],
#  ['Shilpa Medicare', '242.40', '249.50', '-2.85', '-7.10', '1139.91'],
#  ['Expleo Solutions', '1242.70', '1278.90', '-2.83', '-36.20', '9.07'],
#  ['Cambridge Tech Enter', '49.80', '51.25', '-2.83', '-1.45', '39.18'],
#  ['Kernex Microsystems', '279.95', '288.10', '-2.83', '-8.15', '8.58'],
#  ['Emami Realty', '61.85', '63.65', '-2.83', '-1.80', '36.47'],
#  ['Godrej Agrovet', '407.90', '419.75', '-2.82', '-11.85', '150.17'],
#  ['Uniphos Enterprises', '149.75', '154.10', '-2.82', '-4.35', '15.50'],
#  ['Orbit Exports', '127.50', '131.20', '-2.82', '-3.70', '18.61'],
#  ['Modi Rubber', '62.20', '64.00', '-2.81', '-1.80', '0.08'],
#  ['RHI Magnesita', '584.20', '601.10', '-2.81', '-16.90', '243.59'],
#  ['Surana Solar', '17.35', '17.85', '-2.80', '-0.50', '69.88'],
#  ['MRPL', '57.45', '59.10', '-2.79', '-1.65', '6020.42'],
#  ['Ujjivan Small Fin', '24.40', '25.10', '-2.79', '-0.70', '5632.71'],
#  ['Hubtown', '34.90', '35.90', '-2.79', '-1.00', '142.93'],
#  ['TTK Prestige', '699.85', '719.85', '-2.78', '-20.00', '67.57'],
#  ['LCC Infotech', '1.75', '1.80', '-2.78', '-0.05', '80.27'],
#  ['Hardwyn India', '304.60', '313.30', '-2.78', '-8.70', '5.80'],
#  ['Salona Cotspin', '219.50', '225.75', '-2.77', '-6.25', '0.32'],
#  ['Geekay Wires', '133.55', '137.35', '-2.77', '-3.80', '99.64'],
#  ['GOCL Corporation', '304.15', '312.80', '-2.77', '-8.65', '29.56'],
#  ['Cubex Tubings', '28.15', '28.95', '-2.76', '-0.80', '19.58'],
#  ['HOV Services', '37.00', '38.05', '-2.76', '-1.05', '10.10'],
#  ['UNO Minda', '472.45', '485.85', '-2.76', '-13.40', '1966.08'],
#  ['E.I.D. Parry (I)', '502.60', '516.85', '-2.76', '-14.25', '108.08'],
#  ['BSL', '162.55', '167.15', '-2.75', '-4.60', '4.68'],
#  ['Century Extrusions', '8.85', '9.10', '-2.75', '-0.25', '109.44'],
#  ['TruCap Finance', '57.00', '58.60', '-2.73', '-1.60', '410.94'],
#  ['Datamatic Global Ser', '292.25', '300.45', '-2.73', '-8.20', '203.21'],
#  ['Tourism Finance Corp', '69.65', '71.60', '-2.72', '-1.95', '474.53'],
#  ['Kellton Tech Solut.', '50.10', '51.50', '-2.72', '-1.40', '189.13'],
#  ['Motherson Sumi Wirin', '46.55', '47.85', '-2.72', '-1.30', '8369.98'],
#  ['Asahi India Glass', '467.50', '480.55', '-2.72', '-13.05', '116.78'],
#  ['Stove Kraft', '374.70', '385.15', '-2.71', '-10.45', '155.19'],
#  ['Liberty Shoes', '193.90', '199.30', '-2.71', '-5.40', '45.02'],
#  ['Balaji Amines', '2003.70', '2059.50', '-2.71', '-55.80', '67.53'],
#  ['Jyothy Labs', '181.65', '186.70', '-2.70', '-5.05', '108.59'],
#  ['Suprajit Engineering', '354.45', '364.30', '-2.70', '-9.85', '153.25'],
#  ['Hindcon Chemicals', '79.30', '81.50', '-2.70', '-2.20', '12.39'],
#  ['Max Ventures & Ind', '122.70', '126.10', '-2.70', '-3.40', '63.05'],
#  ['SAIL', '85.30', '87.65', '-2.68', '-2.35', '20684.93'],
#  ['Digicontent', '14.55', '14.95', '-2.68', '-0.40', '1.66'],
#  ['Privi Speciality Che', '1078.85', '1108.50', '-2.67', '-29.65', '88.53'],
#  ['Kalpataru PowerTrans', '562.25', '577.70', '-2.67', '-15.45', '453.69'],
#  ['HP Adhesives', '342.45', '351.85', '-2.67', '-9.40', '57.89'],
#  ['Centrum Capital', '20.10', '20.65', '-2.66', '-0.55', '422.07'],
#  ['Aro Granite', '42.05', '43.20', '-2.66', '-1.15', '41.68'],
#  ['GIC Housing Fin', '155.85', '160.10', '-2.65', '-4.25', '183.83'],
#  ['Century Plyboards(I)', '478.85', '491.90', '-2.65', '-13.05', '126.96'],
#  ['Snowman Logistics', '31.25', '32.10', '-2.65', '-0.85', '356.55'],
#  ['Astra Microwave Prod', '240.90', '247.45', '-2.65', '-6.55', '333.95'],
#  ['Avro India', '121.50', '124.80', '-2.64', '-3.30', '12.85'],
#  ['Sapphire Foods India', '1152.95', '1184.25', '-2.64', '-31.30', '210.34'],
#  ['S Chand And Co', '211.85', '217.60', '-2.64', '-5.75', '206.66'],
#  ['Accelya Solutions', '1077.40', '1106.60', '-2.64', '-29.20', '18.50'],
#  ['Radaan Mediaworks', '1.85', '1.90', '-2.63', '-0.05', '1.51'],
#  ['Inventure Growth&Sec', '1.85', '1.90', '-2.63', '-0.05', '2106.37'],
#  ['Dev Information Tech', '91.00', '93.45', '-2.62', '-2.45', '39.83'],
#  ['Rajesh Exports', '592.70', '608.65', '-2.62', '-15.95', '157.64'],
#  ['General Ins. Corp', '132.15', '135.70', '-2.62', '-3.55', '895.97'],
#  ['Hexa Tradex', '149.05', '153.05', '-2.61', '-4.00', '2.93'],
#  ['Igarashi Motors', '349.00', '358.35', '-2.61', '-9.35', '55.76'],
#  ['Macpower CNC Machine', '280.70', '288.20', '-2.60', '-7.50', '8.73'],
#  ['Ganesh Benzoplast', '159.30', '163.55', '-2.60', '-4.25', '229.71'],
#  ['Radhika Jewel', '153.95', '158.05', '-2.59', '-4.10', '39.76'],
#  ['Prataap Snacks', '712.60', '731.50', '-2.58', '-18.90', '6.82'],
#  ['Mangalam Cement', '252.75', '259.45', '-2.58', '-6.70', '85.63'],
#  ['Vishwaraj Sugar Ind.', '15.20', '15.60', '-2.56', '-0.40', '1071.12'],
#  ['Arihant Capital Mkt.', '39.95', '41.00', '-2.56', '-1.05', '81.46'],
#  ['Servotech Power Sys', '39.95', '41.00', '-2.56', '-1.05', '37.94'],
#  ['Dodla Dairy', '459.95', '472.00', '-2.55', '-12.05', '14.49'],
#  ['JM Financial', '59.35', '60.90', '-2.55', '-1.55', '1343.92'],
#  ['Indusind Bank', '1017.80', '1044.35', '-2.54', '-26.55', '9261.21'],
#  ['JSW Steel', '662.40', '679.65', '-2.54', '-17.25', '2512.47'],
#  ['Nuvoco Vistas Corpor', '326.90', '335.40', '-2.53', '-8.50', '233.23'],
#  ['SMS Pharmaceuticals', '65.40', '67.10', '-2.53', '-1.70', '34.69'],
#  ['Lancer Container', '156.00', '160.05', '-2.53', '-4.05', '131.21'],
#  ['Sree Rayal.Hi-Strent', '410.65', '421.30', '-2.53', '-10.65', '16.79'],
#  ['Dynamic Cables', '165.95', '170.25', '-2.53', '-4.30', '40.39'],
#  ['Caplin Point Lab', '613.80', '629.70', '-2.53', '-15.90', '86.01'],
#  ['Apcotex Inds', '434.90', '446.15', '-2.52', '-11.25', '32.97'],
#  ['Worth Peripherals', '96.70', '99.20', '-2.52', '-2.50', '15.05'],
#  ['Angel One', '1045.25', '1072.25', '-2.52', '-27.00', '426.30'],
#  ['Manaksia Aluminium', '21.30', '21.85', '-2.52', '-0.55', '54.25'],
#  ['Baid Finserv', '36.80', '37.75', '-2.52', '-0.95', '110.92'],
#  ['Usha Martin Educatn.', '3.90', '4.00', '-2.50', '-0.10', '13.45'],
#  ['Manaksia', '105.45', '108.15', '-2.50', '-2.70', '61.57'],
#  ['Maheshwari Logistics', '50.80', '52.10', '-2.50', '-1.30', '47.53'],
#  ['Shyam Metalics&Ener', '265.95', '272.75', '-2.49', '-6.80', '248.20'],
#  ['Bajaj Corp', '156.85', '160.85', '-2.49', '-4.00', '172.31'],
#  ['Thangamayil Jeweller', '1041.65', '1068.20', '-2.49', '-26.55', '9.53'],
#  ['Mishra Dhatu Nigam', '190.45', '195.30', '-2.48', '-4.85', '344.25'],
#  ['Coforge', '3852.05', '3950.00', '-2.48', '-97.95', '345.38'],
#  ['GeeCee Ventures', '132.15', '135.50', '-2.47', '-3.35', '2.51'],
#  ['Kritika Wires', '7.90', '8.10', '-2.47', '-0.20', '86.22'],
#  ['TV Today Network', '195.65', '200.60', '-2.47', '-4.95', '230.82'],
#  ['TRF', '160.70', '164.75', '-2.46', '-4.05', '55.52'],
#  ['CarTrade Tech', '410.50', '420.80', '-2.45', '-10.30', '87.40'],
#  ['JSW Ispat Special', '29.95', '30.70', '-2.44', '-0.75', '1231.86'],
#  ['Somany Ceramics', '521.65', '534.70', '-2.44', '-13.05', '75.60'],
#  ['Mawana Sugars', '83.95', '86.05', '-2.44', '-2.10', '200.52'],
#  ['Syncom Formulations', '6.00', '6.15', '-2.44', '-0.15', '1262.64'],
#  ['Vardhman Polytex', '20.00', '20.50', '-2.44', '-0.50', '13.13'],
#  ['Kaushalya Infra Dev', '4.00', '4.10', '-2.44', '-0.10', '44.14'],
#  ['Madhav Copper', '24.05', '24.65', '-2.43', '-0.60', '12.42'],
#  ['Hisar Metal Inds', '136.30', '139.70', '-2.43', '-3.40', '18.94'],
#  ['BSE', '440.40', '451.35', '-2.43', '-10.95', '746.18'],
#  ['PPAP Automotive', '174.05', '178.35', '-2.41', '-4.30', '13.16'],
#  ['Generic Eng. & Const', '60.75', '62.25', '-2.41', '-1.50', '157.58'],
#  ['Likhitha Infrastruct', '226.80', '232.40', '-2.41', '-5.60', '137.36'],
#  ['Polyplex Corporation', '1280.00', '1311.60', '-2.41', '-31.60', '97.64'],
#  ['Asian Granito India', '36.55', '37.45', '-2.40', '-0.90', '912.51'],
#  ['Deepak Fert & Petro', '587.10', '601.55', '-2.40', '-14.45', '223.37'],
#  ['Meghmani Finechem', '890.55', '912.45', '-2.40', '-21.90', '66.96'],
#  ['Onelife Capital', '12.20', '12.50', '-2.40', '-0.30', '5.28'],
#  ['Lyka Labs', '101.70', '104.20', '-2.40', '-2.50', '121.50'],
#  ['Windsor Machines', '38.75', '39.70', '-2.39', '-0.95', '59.69'],
#  ['Eimco Elecon (India)', '341.40', '349.75', '-2.39', '-8.35', '3.00'],
#  ['Kaynes Technology', '951.40', '974.65', '-2.39', '-23.25', '192.56'],
#  ['Rane Holdings', '859.50', '880.50', '-2.39', '-21.00', '29.43'],
#  ['Computer Age Man', '2164.60', '2217.40', '-2.38', '-52.80', '104.88'],
#  ['B.C. Power Controls', '4.10', '4.20', '-2.38', '-0.10', '128.36'],
#  ['Rama Phosphates', '189.35', '193.95', '-2.37', '-4.60', '27.75'],
#  ['Mirza International', '256.25', '262.45', '-2.36', '-6.20', '404.63'],
#  ['Rudrabhishek Enter.', '136.80', '140.10', '-2.36', '-3.30', '12.63'],
#  ['Navkar Corporation', '47.70', '48.85', '-2.35', '-1.15', '488.57'],
#  ['Cummins India', '1657.70', '1697.60', '-2.35', '-39.90', '655.84'],
#  ['Novartis', '565.95', '579.55', '-2.35', '-13.60', '8.00'],
#  ['Kavveri Telecom Prod', '6.25', '6.40', '-2.34', '-0.15', '7.45'],
#  ['De Nora India', '908.55', '930.30', '-2.34', '-21.75', '15.81'],
#  ['Oil Country Tubular', '14.65', '15.00', '-2.33', '-0.35', '17.17'],
#  ['Pearl Polymers', '18.85', '19.30', '-2.33', '-0.45', '41.81'],
#  ['Kamat Hotels (India)', '125.85', '128.85', '-2.33', '-3.00', '102.78'],
#  ['Sequent Scientific', '73.45', '75.20', '-2.33', '-1.75', '5782.14'],
#  ['Ruchi Infra.', '8.40', '8.60', '-2.33', '-0.20', '122.49'],
#  ['FCS Software Soltns.', '2.10', '2.15', '-2.33', '-0.05', '2224.59'],
#  ['Burnpur Cement', '4.20', '4.30', '-2.33', '-0.10', '90.31'],
#  ['Ujaas Energy', '2.10', '2.15', '-2.33', '-0.05', '137.91'],
#  ['KFin Technologies', '283.60', '290.35', '-2.32', '-6.75', '88.01'],
#  ['Bhansali Engg. Poly.', '98.20', '100.50', '-2.29', '-2.30', '346.97'],
#  ['Axita Cotton', '55.60', '56.90', '-2.28', '-1.30', '370.74'],
#  ['Welspun Corp', '197.30', '201.90', '-2.28', '-4.60', '1199.28'],
#  ['Genus Power Infra', '85.95', '87.95', '-2.27', '-2.00', '537.12'],
#  ['Kirloskar Brothers', '372.85', '381.50', '-2.27', '-8.65', '65.90'],
#  ['Sanghvi Movers', '340.65', '348.55', '-2.27', '-7.90', '47.27'],
#  ['MIRC Electronics', '13.00', '13.30', '-2.26', '-0.30', '223.56'],
#  ['Agro Phos', '32.65', '33.40', '-2.25', '-0.75', '52.80'],
#  ['Som Distilleries', '135.20', '138.30', '-2.24', '-3.10', '372.43'],
#  ['DMCC Speciality Chem', '266.20', '272.30', '-2.24', '-6.10', '9.49'],
#  ['Royal Orchid Hotels', '244.90', '250.50', '-2.24', '-5.60', '35.46'],
#  ['Hitachi Energy India', '3255.60', '3329.95', '-2.23', '-74.35', '13.07'],
#  ['NBCC (India)', '35.05', '35.85', '-2.23', '-0.80', '3515.62'],
#  ['JTL Industries', '311.35', '318.45', '-2.23', '-7.10', '65.59'],
#  ['Manugraph India', '17.55', '17.95', '-2.23', '-0.40', '20.88'],
#  ['Sona BLW Precision', '413.65', '423.05', '-2.22', '-9.40', '3489.55'],
#  ['CMI', '13.25', '13.55', '-2.21', '-0.30', '50.01'],
#  ['Alicon Castalloy', '724.65', '741.05', '-2.21', '-16.40', '29.94'],
#  ['GTPL Hathway', '101.65', '103.95', '-2.21', '-2.30', '134.19'],
#  ['Vakrangee', '20.00', '20.45', '-2.20', '-0.45', '3868.11'],
#  ['Asian Energy Service', '80.20', '82.00', '-2.20', '-1.80', '97.00'],
#  ['DJ Mediaprint & Logi', '133.90', '136.90', '-2.19', '-3.00', '2.29'],
#  ...]

# %%
import datetime

import pandas, openpyxl, requests, bs4, pyodbc


class WriteData(ReadData):

    def wExcel(self, df: list):
        data = pandas.DataFrame(df)
        data.to_excel(r"C:\Users\DELL\Desktop\kPython RND folder\abhil.xlsx")

    def wStockPriceSQL(self):
        self.stockPriceInfo = super().rCurrentStockPriceInfoWeb()
        query1 = "delete from tblCurrentStockInfo"
        litequery='''CREATE TABLE "persons" ("Name" TEXT NOT NULL,"Age" INTEGER,"Marks" NUMERIC, PRIMARY KEY("Name"))'''
        # query2 = "create table tblCurrentStockInfo ([Stock Name] nvarchar(60) not null primary key,[LTP] int,[Prev Price] int,[Change(%)] int,[Change Price] int,[Vol] int),[Date] date not null"
        query3 = "insert into tblCurrentStockInfo values ('{}',{},{},{},{},{},'{}')"

        try:

            connection_string = 'Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con = pyodbc.connect(connection_string)
            cursor = con.cursor()
            try:
                cursor.execute(query1)
            except pyodbc.ProgrammingError:
                pass

            df = self.stockPriceInfo
            for i in range(0, len(df)):

                if len(df[i]) == 0:
                    continue
                cursor.execute(query3.format(df[i][0], df[i][1], df[i][2], df[i][3], df[i][4], df[i][5],
                                             datetime.datetime.now().date().strftime("%m/%d/%Y")))
                cursor.commit()
        finally:
            cursor.close()
            con.close()
            print('close')

    def wStockVolSQL(self):
        self.stockVolInfo = super().rCurrentStockVolDelInfoWeb()
        query1 = "delete from tblCurrentStockVolInfo"
        # query2 = "create table tblCurrentStockVolInfo ([Stock Name] nvarchar(60) not null primary key,[Trade Vol] float,[Delivery Vol] float,[Delivery(%)] float,[LTP] float)"
        query3 = "insert into tblCurrentStockVolInfo values ('{}',{},{},{},{})"

        try:
            connection_string = 'Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con = pyodbc.connect(connection_string)
            cursor = con.cursor()
            try:
                cursor.execute(query1)
            except pyodbc.ProgrammingError:
                pass
            # cursor.execute(query2)
            df = self.stockVolInfo
            for i in range(0, len(df)):
                if len(df[i]) == 0:
                    continue
                cursor.execute(query3.format(df[i][0], df[i][1], df[i][2], df[i][3], df[i][4]))
            cursor.commit()
        finally:

            cursor.close()
            con.close()
            print('close')

    def makeCurrentNayiTable(self):
        query1 = "drop table nayiTable"
        query2 = "select [dbo].[tblCurrentStockInfo].[Stock Name],[dbo].[tblCurrentStockInfo].[LTP],[dbo].[tblCurrentStockInfo].[Change(%)],[dbo].[tblCurrentStockInfo].[Change Price],[dbo].[tblCurrentStockInfo].[Vol],[dbo].[tblCurrentStockVolInfo].[Delivery Vol],[dbo].[tblCurrentStockVolInfo].[Delivery(%)],[Date] into nayiTable from [Stock_Market_K].[dbo].[tblCurrentStockInfo] inner join dbo.tblCurrentStockVolInfo on dbo.tblCurrentStockInfo.[Stock Name]=dbo.tblCurrentStockVolInfo.[Stock Name]"
        try:
            connection_string = 'Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con = pyodbc.connect(connection_string)
            cursor = con.cursor()
#             try:
            cursor.execute(query1)
#             except pyodbc.ProgrammingError:
#                 pass
            cursor.execute(query2)
            cursor.commit()
        finally:

            cursor.close()
            con.close()
            print('close')

    def allDateStockInfo(self):

        query2 = "insert into allDateStockInfo select * from allDateStockInfo union all select * from nayiTable"
        try:
            connection_string = 'Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con = pyodbc.connect(connection_string)
            cursor = con.cursor()
            cursor.execute(query2)
            cursor.commit()
        finally:
            cursor.close()
            con.close()
            print('close')

    def sqlFinalStocklistOfTuple(self):

        query = "select top(72) * from nayiTable order by [Change(%)] desc"
        try:
            connection_string = 'Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con = pyodbc.connect(connection_string)
            cursor = con.cursor()
            cursor.execute(query)
            df = cursor.fetchall()

        finally:
            cursor.close()
            con.close()
            print('close')
        return df

    def fetchFromAllDateStockInfo(self):
        query = "select top(72) * from allDateStockInfo order by [Change(%)] desc"
        try:
            connection_string = 'Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con = pyodbc.connect(connection_string)
            cursor = con.cursor()
            cursor.execute(query)
            df = cursor.fetchall()

        finally:
            cursor.close()
            con.close()
            print('close')
        return df

    def stockListToExcel(self):
        stockList = self.sqlToStocklist()
        lst1 = []
        for i in stockList:
            lst2 = [j for j in i]
            lst1.append(lst2)
        df = pandas.DataFrame(lst1, columns=['Stock Name', 'LTP', 'Change Price', 'Change(%)', 'Volume', 'Delivery Vol',
                                             'Delivery %'])
        df.set_index('Stock Name', inplace=True)
        df.to_excel(r"C:\Users\DELL\Desktop\b.xlsx")

WriteData().wStockPriceSQL()
WriteData().wStockVolSQL()
WriteData().makeCurrentNayiTable()
WriteData().allDateStockInfo()
# Out:
# close
# close
# close
# close

# %%
WriteData().wStockPriceSQL()
WriteData().wStockVolSQL()
WriteData().makeCurrentNayiTable()
# Out:
# close
# close
# close

# %%
# Out:
# close

# %%
WriteData().makeCurrentNayiTable()
# Out:
# close

# %%
WriteData().allDateStockInfo()
# Out:
# close

# %%
i=0
name="lbl_StockName_"
for j in obj1:
    "lbl_StockName_{}".format()
# Out:
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0
# lbl_StockName_0

# %%
j={}
for i in range(10):
    j.append("lbl_StockName_{}".format(i))=
# Out:
# ['lbl_StockName_0', 'lbl_StockName_1', 'lbl_StockName_2', 'lbl_StockName_3', 'lbl_StockName_4', 'lbl_StockName_5', 'lbl_StockName_6', 'lbl_StockName_7', 'lbl_StockName_8', 'lbl_StockName_9']

# %%
import pandas,openpyxl

lst1=[]
for i in obj1:
    lst2=[j for j in i]
    lst1.append(lst2)

df=pandas.DataFrame(lst1,columns=['Stock Name','LTP','Change Price','Change(%)','Volume','Delivery Vol','Delivery %'])
df.set_index('Stock Name',inplace=True)
df.to_excel(r"C:\Users\DELL\Desktop\b.xlsx")

# %%
lst1
# Out:
# [['20 Microns', 69, 9, 6, 1089, 608.32, 55.85],
#  ['3I Infotech', 8, -1, 0, 27016, 13214.33, 48.91],
#  ['3P Land Holdings', 13, 0, 0, 33, 25.44, 76.03],
#  ['5Paisa Capital', 368, 0, -2, 29, 17.77, 60.77],
#  ['Aakash Exploration', 157, 0, 1, 64, 19.54, 30.15],
#  ['Aarti Drugs', 738, -1, -10, 410, 177.62, 43.23],
#  ['Aarti Inds', 1674, 0, 9, 638, 248.62, 38.92],
#  ['AARTISURF', 1471, -6, -97, 104, 66.19, 63.1],
#  ['Aarvi Encon', 55, 4, 2, 164, 106.7, 64.99],
#  ['Aavas Financiers', 2325, 0, 16, 91, 63.29, 69.14],
#  ['Aban Offshore', 34, 0, 0, 60, 38.41, 63.58],
#  ['ABB India', 1475, 2, 42, 234, 141.1, 60.24],
#  ['ABB Power Products', 1840, 3, 67, 44, 21.76, 49.05],
#  ['ACC', 1984, 0, 19, 657, 179.67, 27.33],
#  ['Accelya Solutions', 898, 4, 40, 17, 12.64, 74.13],
#  ['Accuracy Shipping', 57, -7, -4, 31, 21.45, 67.92],
#  ['Acrysil', 449, 13, 52, 1552, 474.45, 30.56],
#  ['Action Const. Equip', 169, 6, 9, 1009, 598.71, 59.33],
#  ['Adani Enterprises', 1306, 0, -8, 7913, 3209.04, 40.55],
#  ['Adani Green Energy', 1360, 4, 61, 1906, 621.82, 32.61],
#  ['Adani Ports &Special', 766, 0, -2, 8354, 807.97, 9.67],
#  ['Adani Power', 101, 0, 0, 9135, 5268.52, 57.67],
#  ['Adani Total Gas', 1324, -1, -14, 4487, 2654.12, 59.15],
#  ['Adani Transmission', 1526, 5, 72, 3473, 2117.72, 60.97],
#  ['ADF Foods', 1039, 1, 17, 57, 23.96, 41.92],
#  ['Aditya Birla Capital', 125, 0, 0, 2507, 888.92, 35.45],
#  ['Aditya Birla Fashion', 191, 1, 3, 1981, 996.17, 50.28],
#  ['Aditya Birla Money', 49, 2, 1, 983, 444.9, 45.26],
#  ['Ador Welding', 438, 7, 30, 103, 42.81, 41.5],
#  ['Advanced Enzyme', 473, -1, -6, 203, 84.07, 41.36],
#  ['Advani Hotel&Resorts', 61, 4, 2, 36, 26.95, 73.33],
#  ['Aegis Logistics', 349, 5, 17, 1317, 605.86, 45.97],
#  ['Affle (India)', 5216, 2, 119, 117, 57.89, 49.1],
#  ['Agarwal Indl. Corp', 221, 1, 3, 49, 30.48, 61.96],
#  ['AGC Networks', 1448, 0, -3, 29, 10.99, 36.76],
#  ['Agro Phos', 13, 1, 0, 51, 40.83, 78.7],
#  ['Ahluwalia Contract(I', 303, 2, 6, 51, 39.75, 76.72],
#  ['AIA Engineering', 1957, -1, -27, 19, 11.07, 56.54],
#  ['Airan', 21, 1, 0, 119, 68.61, 57.18],
#  ['Ajanta Pharma', 1955, 1, 20, 112, 27.96, 24.77],
#  ['Ajmera Realty&Infra', 128, 1, 1, 141, 67.16, 47.4],
#  ['Akash Infra-Projects', 217, 0, 1, 36, 35.22, 96.18],
#  ['Aksharchem (I)', 312, 2, 8, 116, 50.48, 43.44],
#  ['Akzo Nobel India', 2253, 0, -13, 36, 13.15, 36.11],
#  ['Alankit', 16, 1, 0, 222, 179.23, 80.72],
#  ['Alembic', 134, 1, 1, 1003, 284.18, 28.32],
#  ['Alembic Pharma', 960, 0, 3, 251, 99.71, 39.68],
#  ['Alicon Castalloy', 587, 11, 62, 97, 35.39, 36.39],
#  ['Alkali Metals', 60, 0, 0, 39, 24.84, 63.07],
#  ['Alkem Laboratories', 2996, 0, -7, 255, 151.4, 59.2],
#  ['Alkyl Amines Chem', 3571, -1, -36, 95, 55.09, 57.66],
#  ['Allcargo Logistics', 132, 0, 0, 305, 136.27, 44.55],
#  ['Allied Digital Serv.', 59, 4, 2, 474, 291.39, 61.39],
#  ['Allsec Tech.', 354, -5, -19, 21, 10.37, 47.36],
#  ['Almondz Global Sec', 36, 3, 1, 18, 13.23, 72.6],
#  ['Alok Inds', 20, 0, 0, 8800, 4420.34, 50.23],
#  ['Alphageo India', 243, 3, 7, 33, 19.95, 60.24],
#  ['Alps Inds', 1, -2, 0, 31, 26.81, 84.81],
#  ['Amara Raja Batteries', 783, -1, -8, 1978, 439.87, 22.23],
#  ['Amber Enterprises', 2930, -2, -75, 198, 125.45, 63.09],
#  ['Ambica Agarbathies', 26, -5, -1, 209, 124.05, 59.33],
#  ['Ambika Cotton Mills', 1092, -2, -24, 17, 11.85, 67.56],
#  ['Ambuja Cement', 326, 1, 4, 4875, 1535.79, 31.5],
#  ['AMD Industries', 20, 3, 0, 36, 20.39, 55.75],
#  ['AMJ Land Holdings', 26, -2, 0, 15, 11.64, 72.95],
#  ['Amrutanjan Healthcar', 765, 1, 14, 129, 45.03, 34.84],
#  ['Anant Raj', 61, 4, 2, 191, 191.57, 100.0],
#  ['Andhra Paper', 237, 2, 6, 42, 28.18, 66.52],
#  ['Andhra Sugars', 410, -1, -7, 129, 53.17, 41.1],
#  ['Angel Broking', 752, 0, 3, 706, 214.72, 30.41],
#  ['Anik Industries', 15, 9, 1, 138, 118.57, 85.62],
#  ['Anjani Portland Cem.', 298, 10, 28, 1059, 407.36, 38.44],
#  ['Ansal Housing', 5, 1, 0, 45, 30.16, 65.73],
#  ['Ansal Prop. & Infra', 5, -3, 0, 878, 632.04, 71.93],
#  ['Antony Waste Hand', 311, 0, 0, 153, 72.34, 47.19],
#  ['Anupam Rasayan India', 768, 0, -1, 287, 86.69, 30.19],
#  ['Apar Inds', 553, 5, 28, 175, 91.66, 52.09],
#  ['Apcotex Inds', 346, -4, -15, 138, 69.4, 50.29],
#  ['Apex Frozen Foods', 251, 0, 0, 43, 24.32, 55.55],
#  ['APL Apollo Tubes', 1253, 0, 0, 75, 44.82, 59.3],
#  ['Apollo Hospital Ent.', 3261, 0, 13, 611, 269.0, 43.96],
#  ['Apollo Micro Systems', 115, -1, -2, 219, 112.41, 51.17],
#  ['Apollo Pipes', 1108, 0, -6, 27, 20.64, 73.91],
#  ['Apollo Sindoori', 972, 19, 161, 60, 21.87, 35.93],
#  ['Apollo Tyres', 218, 0, 1, 4624, 855.9, 18.51],
#  ['Aptech', 212, 0, 0, 100, 33.09, 32.89],
#  ['Archies', 11, -2, 0, 52, 44.87, 86.26],
#  ['Aries Agro', 109, 0, 0, 187, 56.97, 30.32],
#  ['Aro Granite', 52, 7, 3, 488, 255.38, 52.3],
#  ['Arshiya', 29, 1, 0, 47, 18.06, 38.05],
#  ['ARSS Infra Project', 28, 0, 0, 20, 15.95, 77.68],
#  ['Arvind', 77, -1, 0, 828, 450.07, 54.31],
#  ['Arvind Fashions', 140, 0, 0, 242, 134.56, 55.54],
#  ['Arvind Smartspaces', 106, 4, 4, 562, 279.52, 49.65],
#  ['Asahi India Glass', 310, 3, 11, 189, 87.96, 46.39],
#  ['Asahi Songwon Colors', 370, 3, 12, 25, 16.41, 64.14],
#  ['Ashapura Minechem', 153, 1, 2, 228, 110.54, 48.45],
#  ['Ashiana Housing', 119, -1, -2, 83, 58.1, 69.78],
#  ['Ashok Leyland', 125, 0, 0, 9555, 2205.5, 23.08],
#  ['Ashoka Buildcon', 91, 4, 3, 6029, 2197.32, 36.44],
#  ['Asian Granito India', 196, 4, 8, 786, 461.68, 58.69],
#  ['Asian Hotels (North)', 75, 7, 5, 44, 19.31, 43.5],
#  ['Asian Paints', 2819, 0, -13, 813, 326.11, 40.11],
#  ['Assoc Alcohols &Brew', 440, 2, 9, 111, 55.93, 50.37],
#  ['Astec Lifesciences', 1472, 15, 197, 827, 178.99, 21.62],
#  ['Aster DM Healthcare', 148, 0, 0, 357, 231.42, 64.81],
#  ['Astra Microwave Prod', 131, 5, 6, 2380, 869.88, 36.54],
#  ['Astral', 1790, 2, 37, 259, 96.9, 37.28],
#  ['Astrazeneca Pharma I', 3832, 1, 58, 70, 28.63, 40.52],
#  ['Atul', 8647, 0, 84, 25, 11.63, 46.03],
#  ['Atul Auto', 187, 0, -1, 71, 44.34, 61.84],
#  ['AU Small Fin. Bank', 978, 0, -2, 832, 202.57, 24.34],
#  ['Aurionpro Solutions', 142, 2, 3, 70, 40.39, 57.22],
#  ['Aurobindo Pharma', 1013, 0, 0, 1249, 471.14, 37.69],
#  ['Auto.Axle', 1339, 1, 22, 41, 18.53, 44.49],
#  ['Autoline Inds', 35, 0, 0, 15, 12.9, 83.04],
#  ['Avadh Sugar & Energy', 300, 0, -1, 122, 42.52, 34.68],
#  ['Avanti Feeds', 539, 1, 10, 377, 177.01, 46.87],
#  ['Avenue Supermarts', 3040, 0, 6, 236, 85.85, 36.25],
#  ['AVT Natural Prod', 65, 9, 5, 1465, 702.79, 47.96],
#  ['Axis Bank', 741, 1, 10, 15716, 4680.06, 29.78],
#  ['Axiscades Tech.', 67, 6, 3, 346, 154.95, 44.71],
#  ['AYM Syntex', 63, 2, 1, 75, 54.81, 72.82],
#  ['Bajaj  Hold & Invest', 3556, 0, -31, 46, 39.01, 83.64],
#  ['Bajaj Auto', 4142, 0, 16, 500, 165.48, 33.08],
#  ['Bajaj Corp', 279, 0, 0, 556, 261.04, 46.88],
#  ['Bajaj Electricals', 1137, 0, 1, 153, 86.86, 56.53],
#  ['Bajaj Finance', 5602, 0, -28, 1215, 173.73, 14.3],
#  ['Bajaj Finserv', 11166, 0, -98, 214, 45.58, 21.28],
#  ['Bajaj Hindusthan Sug', 11, 4, 0, 15453, 7267.91, 47.03],
#  ['Balaji Amines', 2893, 3, 90, 235, 92.07, 39.1],
#  ['Balaji Telefilms', 64, 5, 3, 1226, 516.36, 42.08],
#  ['Balkrishna Inds.', 2137, 0, 6, 373, 129.88, 34.78],
#  ['Balkrishna Paper', 25, 4, 1, 20, 20.63, 98.81],
#  ['Balmer Lawrie & Co', 136, 0, -1, 323, 154.95, 47.95],
#  ['Balrampur Chini Mill', 293, -3, -9, 2700, 1223.95, 45.32],
#  ['Banaras Beads', 56, -2, -1, 70, 33.8, 48.21],
#  ['Banco Products (I)', 170, 2, 4, 1185, 422.9, 35.68],
#  ['Bandhan Bank', 298, 0, 0, 7371, 3144.35, 42.66],
#  ['Bang Overseas', 30, 0, 0, 13, 10.0, 75.46],
#  ['Bank Of Baroda', 81, 0, 0, 129796, 29948.07, 23.07],
#  ['Bank Of India', 78, 0, 0, 8330, 1981.76, 23.79],
#  ['Bank of Maharashtra', 25, 0, 0, 4733, 2167.95, 45.8],
#  ['Banka Bioloo', 78, -4, -4, 20, 15.08, 72.82],
#  ['Bannari Amman Spg', 77, 9, 6, 462, 333.26, 72.09],
#  ['Banswara Syntex', 131, -3, -4, 54, 32.35, 59.74],
#  ['Barbeque-Nation Hosp', 637, 2, 14, 249, 89.54, 35.88],
#  ['BASF India', 2405, -1, -38, 38, 21.48, 55.41],
#  ['Bata india', 1512, 1, 27, 523, 159.35, 30.42],
#  ['Bayer CropScience', 5306, -1, -98, 32, 19.66, 60.32],
#  ['BC Power', 3, 1, 0, 193, 118.76, 61.4],
#  ['BCL Industries', 160, 3, 4, 588, 308.63, 52.42],
#  ['BEML', 1328, 1, 14, 485, 121.45, 25.03],
#  ['Berger Paints India', 808, 2, 17, 1680, 232.52, 13.84],
#  ['Best Agrolife', 295, 0, 2, 224, 155.4, 69.36],
#  ['BF Investment', 321, -1, -4, 47, 14.72, 31.2],
#  ['BF Utilities', 315, 1, 4, 350, 75.55, 21.58],
#  ['BGR  Energy Systems', 56, -1, 0, 213, 129.15, 60.39],
#  ['Bhageria Industries', 204, 3, 6, 215, 111.78, 51.85],
#  ['Bhagyanagar India', 57, 4, 2, 51, 31.48, 61.21],
#  ['Bhagyanagar Propert', 29, 2, 0, 30, 14.7, 48.84],
#  ['Bhandari Hosiery Exp', 2, 4, 0, 363, 296.54, 81.64],
#  ['Bhansali Engg. Poly.', 158, -1, -2, 697, 378.33, 54.24],
#  ['Bharat Dynamics', 359, 0, 0, 169, 82.93, 49.03],
#  ['Bharat Electronics', 156, 0, 0, 24874, 13611.32, 54.72],
#  ['Bharat Forge', 651, 1, 6, 2281, 772.46, 33.86],
#  ['Bharat Gears', 106, -1, -1, 73, 32.53, 43.98],
#  ['Bharat Road Network', 26, -1, 0, 273, 204.84, 74.92],
#  ['Bharat Wire Ropes', 53, -4, -2, 62, 52.08, 83.94],
#  ['Bharti Airtel', 526, 0, -4, 6268, 2249.79, 35.89],
#  ['BHEL', 72, 0, 0, 62656, 10976.45, 17.52],
#  ['Biocon', 383, 0, 0, 1993, 860.62, 43.16],
#  ['Biofil Chem & Pharma', 70, 0, 0, 38, 23.69, 61.03],
#  ['Birla Cable', 75, -1, -1, 189, 93.3, 49.22],
#  ['Birla Corporation', 1260, 0, 0, 222, 86.31, 38.78],
#  ['Birla Tyres', 28, 0, 0, 606, 383.26, 63.19],
#  ['Birlasoft', 297, 11, 30, 12339, 3044.2, 24.67],
#  ['BL Kashyap & Sons', 17, 2, 0, 400, 233.19, 58.28],
#  ['BLB', 7, 2, 0, 34, 28.13, 80.73],
#  ['Bliss GVS Pharma', 110, 1, 1, 602, 285.98, 47.49],
#  ['BLS Internatl.Serv', 113, 0, 0, 481, 279.66, 58.05],
#  ['Blue Dart Express', 6066, 1, 107, 33, 10.97, 32.5],
#  ['Blue Star', 814, 0, 6, 76, 44.55, 58.06],
#  ['Bodal Chemicals', 98, -1, -1, 568, 281.06, 49.48],
#  ['Bombay Burmah Trdg.', 1217, 1, 15, 105, 28.61, 27.09],
#  ['Bombay Dyeing Mfg.', 75, -1, -1, 1709, 651.47, 38.11],
#  ['Bombay Rayon Fashion', 6, 0, 0, 180, 153.09, 84.73],
#  ['Borosil', 228, 0, -1, 302, 131.03, 43.25],
#  ['Borosil Renewables', 282, -1, -5, 890, 528.12, 59.32],
#  ['Bosch', 15193, 0, -94, 83, 14.31, 17.15],
#  ['BPCL', 472, 2, 11, 11470, 3544.98, 30.9],
#  ['BPL', 37, 0, 0, 233, 138.68, 59.32],
#  ['Brigade Enterprises', 270, 0, 1, 476, 331.07, 69.51],
#  ['Brightcom Group', 8, -1, 0, 3688, 1804.96, 48.93],
#  ['Britannia Inds', 3379, -1, -56, 1643, 1148.59, 69.88],
#  ['Brooks Laboratories', 100, 4, 4, 93, 71.24, 76.13],
#  ['BSE', 787, 5, 40, 1454, 417.75, 28.72],
#  ['BSL', 50, 0, 0, 112, 76.71, 68.34],
#  ['Burger King India', 148, 2, 3, 5260, 1653.23, 31.43],
#  ['Burnpur Cement', 3, 4, 0, 126, 126.37, 99.98],
#  ['ButterflyGandhimathi', 786, 1, 11, 1153, 497.91, 43.18],
#  ['Cadila Healthcare', 621, 1, 8, 12458, 2658.59, 21.34],
#  ['California Software', 9, 0, 0, 38, 27.64, 72.64],
#  ['Cambridge Tech Enter', 31, -4, -1, 41, 26.3, 62.98],
#  ['Camlin Fine Sciences', 172, 5, 9, 884, 458.71, 51.86],
#  ['Can Fin Homes', 536, 4, 25, 567, 253.27, 44.63],
#  ['Canara Bank', 154, 0, 1, 50412, 10204.45, 20.24],
#  ['Cantabil Retail', 369, 0, 0, 92, 16.65, 18.01],
#  ['Capacite Infraprojec', 208, 3, 7, 291, 149.18, 51.18],
#  ['Capital Trust', 94, 0, 0, 19, 13.38, 67.56],
#  ['Caplin Point Lab', 620, 5, 31, 538, 224.35, 41.64],
#  ['Capri Global Capital', 460, 0, 0, 131, 111.61, 84.58],
#  ['Carborundum Univer.', 590, 0, 1, 116, 41.79, 35.83],
#  ['Care Ratings', 551, 0, 0, 170, 65.86, 38.57],
#  ['Career Point', 133, 0, 0, 28, 21.8, 76.24],
#  ['Castrol India', 135, 4, 5, 3920, 1762.61, 44.96],
#  ['CCL Products (India)', 327, 5, 15, 2776, 1074.48, 38.7],
#  ['CEAT', 1322, 2, 36, 682, 175.11, 25.65],
#  ['Celebrity Fashions', 6, 4, 0, 36, 36.1, 99.77],
#  ['Central Dep. Service', 886, 1, 15, 896, 352.83, 39.35],
#  ['CentralBank of India', 19, 4, 0, 19936, 9917.01, 49.74],
#  ['Centrun Capital', 38, 0, 0, 2449, 1257.2, 51.33],
#  ['Century Enka', 303, 3, 10, 138, 73.5, 53.26],
#  ['Century Extrusions', 6, -1, 0, 208, 146.38, 70.35],
#  ['Century Plyboards(I)', 437, 8, 35, 1198, 467.78, 39.04],
#  ['Century Textile &Ind', 505, 0, 4, 820, 194.59, 23.7],
#  ['Cerebra Integ. Tech', 49, -1, 0, 370, 239.98, 64.83],
#  ['CESC', 684, 0, -4, 1031, 409.73, 39.71],
#  ['CG Power & Indl.Soln', 88, 0, 0, 2586, 1738.28, 67.19],
#  ['Chalet Hotels', 163, 4, 6, 488, 267.8, 54.83],
#  ['Chaman Lal Setia Exp', 128, -3, -4, 145, 89.05, 61.13],
#  ['Chambal Fert & Chem', 280, -2, -5, 528, 312.42, 59.06],
#  ['Chembond Chemicals', 203, 1, 2, 67, 38.32, 56.76],
#  ['Chemcon Speciality', 437, 0, 0, 177, 86.85, 48.94],
#  ['Chemfab Alkalis', 148, -7, -11, 67, 34.86, 51.54],
#  ['Chennai Petrol. Corp', 133, 3, 4, 3662, 1219.8, 33.3],
#  ['Chola Invest & Fin.', 576, -1, -6, 6891, 2939.52, 42.65],
#  ['Cholamandalam Fin.', 629, 3, 19, 883, 493.64, 55.85],
#  ['Cigniti Technologies', 422, 0, 2, 55, 39.01, 69.96],
#  ['Cineline India', 37, 2, 1, 119, 62.16, 51.82],
#  ['Cipla', 931, 0, 4, 6420, 2053.46, 31.99],
#  ['City Union Bank', 176, 0, 1, 4895, 1643.71, 33.57],
#  ['CL Educate', 86, 1, 1, 92, 81.56, 88.57],
#  ['Clariant Chem.(India', 483, 1, 5, 153, 103.71, 67.53],
#  ['Coal India', 148, 1, 1, 14192, 3449.39, 24.3],
#  ['Cochin Shipyard', 389, 1, 4, 267, 131.22, 49.02],
#  ['Coffee Day Enter.', 24, -3, 0, 1893, 875.25, 46.23],
#  ['Coforge', 3290, -1, -39, 639, 159.75, 24.96],
#  ['Colgate Palmol. (I)', 1632, 0, 0, 316, 140.16, 44.23],
#  ['Commercial Engineers', 21, -4, -1, 224, 156.49, 69.84],
#  ['Compuage Infocom', 22, 0, 0, 399, 176.88, 44.32],
#  ['Compucom Software', 9, 0, 0, 37, 31.65, 84.77],
#  ['Computer Age Man', 2536, 5, 124, 399, 132.86, 33.25],
#  ['Confidence Petroleum', 64, 0, 0, 900, 444.3, 49.33],
#  ['Container Corp', 634, 8, 47, 24246, 2911.15, 12.01],
#  ['Control Print', 388, 6, 23, 221, 98.36, 44.39],
#  ['Coral India Fin &Hsg', 26, -4, -1, 102, 73.02, 71.08],
#  ['Cords Cable Inds', 47, 2, 1, 305, 136.57, 44.74],
#  ['Coromandel Interntl.', 820, -1, -14, 328, 134.73, 40.97],
#  ['Cosmo Films', 808, 0, 4, 162, 79.26, 48.82],
#  ['Country CondoS', 2, 4, 0, 119, 95.06, 79.69],
#  ['Craftsman Automation', 1494, 1, 17, 35, 16.66, 46.39],
#  ['Creative Peripherals', 91, 5, 4, 228, 122.94, 53.88],
#  ['CreditAccess Grameen', 618, 1, 10, 200, 176.1, 87.95],
#  ['Crest Ventures', 104, 2, 2, 449, 139.11, 30.93],
#  ['CRISIL', 1920, 0, 17, 24, 16.8, 67.77],
#  ['Crompt.Greaves Cons.', 398, 2, 9, 3464, 1991.97, 57.5],
#  ['CSB Bank', 305, -2, -8, 545, 152.64, 27.96],
#  ['Cummins India', 839, 0, 6, 849, 265.36, 31.23],
#  ['Cupid', 242, 3, 8, 261, 96.91, 37.1],
#  ['Cybertech Sys. &Soft', 144, 5, 7, 656, 239.16, 36.41],
#  ['Cyient', 803, 0, -2, 70, 39.21, 55.5],
#  ['Dabur India', 533, 0, -3, 2142, 1285.98, 60.03],
#  ['Dalmia Bharat', 1878, 2, 47, 58, 34.63, 59.14],
#  ['Dalmia Bharat Sugar', 330, 0, -1, 320, 120.84, 37.72],
#  ['Damodar Inds.', 32, 6, 2, 66, 43.95, 66.37],
#  ['Datamatic Global Ser', 139, 3, 5, 880, 389.12, 44.21],
#  ['DB Corp', 93, 3, 3, 636, 239.38, 37.64],
#  ['DB Realty', 21, 4, 1, 489, 398.89, 81.57],
#  ['DCB Bank', 104, 1, 1, 2066, 876.76, 42.43],
#  ['DCM', 29, 1, 0, 59, 31.53, 53.01],
#  ['DCM Financial Serv.', 1, 2, 0, 10, 10.84, 99.99],
#  ['DCM Nouvelle', 118, 0, 0, 102, 63.48, 62.17],
#  ['DCM Shriram', 677, 0, -5, 174, 45.33, 25.94],
#  ['DCW', 36, 0, 0, 6885, 3814.98, 55.41],
#  ['De Nora India', 359, 10, 35, 198, 76.58, 38.62],
#  ['Deccan Cements', 508, 1, 8, 69, 37.48, 53.86],
#  ['Deep Energy Res.', 42, 2, 1, 108, 68.91, 63.31],
#  ['Deep Industries', 67, 0, 0, 37, 22.72, 60.79],
#  ['Deepak Fert & Petro', 303, 1, 5, 385, 212.16, 55.05],
#  ['Deepak Nitrite', 1787, 1, 25, 850, 168.41, 19.8],
#  ['Delta Corp', 175, 7, 12, 12088, 3043.13, 25.17],
#  ['Den Networks', 48, 2, 1, 13816, 7292.81, 52.78],
#  ['Dewan Hsg Fin. Corp.', 18, 4, 0, 890, 757.52, 85.11],
#  ['DFM Foods', 338, 1, 6, 185, 97.19, 52.52],
#  ['Dhampur Sugar Mills', 312, -3, -10, 1200, 391.22, 32.58],
#  ['Dhani Services', 177, 0, 1, 652, 390.23, 59.8],
#  ['Dhanlaxmi Bank', 14, 1, 0, 1020, 745.22, 73.04],
#  ['Dhanuka Agritech', 865, -2, -26, 244, 94.97, 38.87],
#  ['Dharan Sugars & Chem', 10, -4, 0, 47, 42.7, 89.52],
#  ['Dhunseri Ventures', 157, 3, 4, 319, 181.12, 56.72],
#  ['Digicontent', 8, 5, 0, 99, 80.8, 80.99],
#  ['Digispice Technolog', 41, -3, -1, 231, 173.8, 75.14],
#  ['Diligent Media Corpn', 1, 2, 0, 71, 71.58, 100.0],
#  ['Dilip Buildcon', 540, 0, 4, 278, 115.11, 41.3],
#  ['Dish TV India', 12, 0, 0, 11497, 4749.27, 41.31],
#  ['Dishman Carbogen Amc', 192, 0, -1, 1227, 384.1, 31.28],
#  ['Divis Lab', 4097, 0, 17, 591, 188.35, 31.84],
#  ['Dixon Technologies', 3906, 0, -38, 210, 119.83, 56.97],
#  ['DLF', 277, 3, 8, 11223, 2435.81, 21.7],
#  ['D-Link (India)', 110, 1, 1, 371, 187.98, 50.54],
#  ['Dolat Investment', 72, 0, 0, 265, 170.82, 64.41],
#  ['Dollar Industries', 309, 14, 39, 1902, 830.97, 43.68],
#  ['Donear Inds', 37, 3, 1, 319, 148.19, 46.42],
#  ['DP Abhushan', 133, 5, 7, 143, 56.63, 39.53],
#  ['Dr Lal Pathlabs', 2784, -1, -46, 502, 120.57, 23.98],
#  ['Dr. Reddys Lab', 5272, 1, 55, 706, 171.83, 24.32],
#  ['Dredging Corp', 398, -1, -6, 129, 48.17, 37.1],
#  ['Ducon Infra.', 7, 3, 0, 161, 102.59, 63.49],
#  ['Dwarikesh Sugar Inds', 52, 1, 0, 3818, 1389.9, 36.4],
#  ['Dynacons Sys & Sol', 104, -2, -3, 69, 29.55, 42.77],
#  ['Dynamatic Tech', 1353, -3, -46, 32, 14.55, 44.25],
#  ['Dynemic Products', 569, 13, 68, 427, 188.21, 43.99],
#  ['E.I.D. Parry (I)', 416, 0, 0, 383, 97.58, 25.47],
#  ['Easy Trip Planners', 264, 9, 23, 6463, 1779.23, 27.53],
#  ['Ebixcash World Mon.I', 686, -5, -42, 16, 10.35, 62.77],
#  ['eClerx Services', 1172, -1, -21, 28, 16.99, 60.41],
#  ['Edelweiss Financial', 64, 0, 0, 2678, 1533.91, 57.27],
#  ['Eicher Motors', 2551, 1, 28, 850, 314.29, 36.97],
#  ['EIH', 105, 5, 5, 2073, 862.88, 41.61],
#  ['EIH Associated Hotel', 278, 2, 7, 53, 25.09, 46.81],
#  ['Elecon Engg.', 100, 12, 11, 3398, 1283.56, 37.77],
#  ['Elgi Equipments', 216, 0, 1, 882, 393.08, 44.54],
#  ['Elgi Rubber Co.', 37, 1, 0, 75, 49.82, 65.8],
#  ['Emami', 511, 1, 7, 344, 218.81, 63.52],
#  ['Emami Paper Mills', 124, 0, -1, 21, 12.46, 57.31],
#  ['Emami Realty', 49, 2, 1, 85, 63.46, 74.13],
#  ['EmkayGlobal Finl.Ser', 73, -5, -3, 167, 96.67, 57.76],
#  ['Emmbi Industries', 102, -2, -2, 48, 27.61, 57.2],
#  ['Endurance Tech', 1435, 2, 37, 259, 133.73, 51.47],
#  ['Energy Development', 9, 0, 0, 54, 32.24, 58.7],
#  ['Engineers India', 81, 1, 0, 3346, 1228.42, 36.71],
#  ['Entertain. Network', 167, 7, 11, 260, 130.37, 50.0],
#  ['EPL', 242, -1, -2, 585, 416.67, 71.12],
#  ['Equitas Holdings', 88, 0, 0, 988, 485.23, 49.07],
#  ['Equitas Small Fin.', 59, 2, 1, 779, 525.93, 67.46],
#  ['Eris Lifesciences', 704, 0, -3, 83, 33.39, 40.14],
#  ['Eros Internatl.Media', 26, 13, 3, 5610, 2223.25, 39.63],
#  ['Escorts', 1169, 0, 10, 2422, 837.25, 34.56],
#  ['Essar Shipping', 9, 0, 0, 106, 69.89, 65.36],
#  ['Ester Inds', 144, 0, 0, 338, 196.35, 57.98],
#  ['Eveready Inds. (I)', 316, 2, 8, 3262, 1284.7, 39.38],
#  ['Everest Industries', 375, 1, 5, 133, 65.41, 49.01],
#  ['Everest Kanto Cylind', 102, -1, -1, 420, 238.55, 56.79],
#  ['Exide Inds', 192, 3, 5, 7700, 2071.23, 26.9],
#  ['Expleo Solutions', 610, -4, -30, 97, 60.51, 61.92],
#  ['Fairchem Organics', 929, 5, 47, 39, 25.97, 65.81],
#  ['FDC', 365, 3, 10, 480, 223.35, 46.51],
#  ['Federal Bank', 86, 1, 1, 32717, 6767.79, 20.69],
#  ['Federal-Mogul Goetze', 289, 0, 1, 176, 88.23, 50.05],
#  ['Fert Chem Travancore', 126, -1, -2, 381, 147.91, 38.72],
#  ['Fiem Inds', 609, 4, 26, 151, 61.32, 40.36],
#  ['Filatex India', 99, -2, -2, 439, 265.0, 60.31],
#  ['Fine Organic Inds.', 3495, 0, 0, 31, 12.45, 39.46],
#  ['Fineotex Chemical', 82, -1, -1, 391, 234.29, 59.81],
#  ['Finolex Cables', 399, 3, 13, 991, 570.73, 57.55],
#  ['Finolex Inds', 162, 3, 5, 1300, 644.31, 49.54],
#  ['Firstsource Solution', 138, 0, 0, 3119, 890.52, 28.55],
#  ['Force Motors', 1255, 0, 3, 48, 12.42, 25.46],
#  ['Fortis Healthcare', 227, 0, 0, 2016, 799.21, 39.64],
#  ['Future Consumer', 6, 2, 0, 7747, 2810.45, 36.28],
#  ['Future Enter.-B-DVR', 12, 2, 0, 56, 47.34, 84.07],
#  ['Future Enterprises', 9, 1, 0, 441, 267.48, 60.6],
#  ['Future Lifestyle', 54, 1, 1, 399, 173.13, 43.28],
#  ['Future MarketNetwork', 14, 1, 0, 55, 35.67, 64.43],
#  ['Future Retail', 46, 1, 0, 2366, 1354.57, 57.25],
#  ['Future Supply Chain', 72, 0, 0, 55, 30.25, 54.4],
#  ['Gabriel India', 125, 7, 8, 2368, 1007.43, 42.53],
#  ['GAIL India', 151, 4, 5, 15741, 3732.4, 23.71],
#  ['Galaxy Surfactants', 3082, 0, 9, 32, 15.12, 46.8],
#  ['Gallantt Ispat', 49, 0, 0, 52, 24.84, 46.91],
#  ['Gallantt Metal', 61, 0, 0, 50, 23.33, 46.51],
#  ['Gammon Infra Proj', 1, 8, 0, 16488, 5739.4, 34.81],
#  ['Ganesh Housing Corp', 60, -2, -1, 22, 16.48, 74.74],
#  ['Ganesha Ecosphere', 577, -6, -37, 59, 39.94, 67.39],
#  ['Garden Reach Ship', 186, 0, 0, 457, 226.34, 49.46],
#  ['Garware Tech. Fibres', 2891, 0, -1, 30, 20.52, 67.4],
#  ['Gateway Distriparks', 297, 3, 9, 668, 369.94, 55.35],
#  ['GATI', 127, -2, -2, 1296, 508.04, 39.18],
#  ['Gayatri Highways', 0, 7, 0, 660, 352.0, 53.3],
#  ['Gayatri Projects', 36, 3, 1, 2230, 1246.0, 55.87],
#  ['GE Power India', 271, 1, 5, 252, 120.5, 47.63],
#  ['GE Shipping', 409, 1, 5, 458, 227.64, 49.68],
#  ['GE T&D India', 120, 0, 0, 686, 601.65, 87.62],
#  ['GeeCee Ventures', 114, 4, 5, 74, 21.43, 28.68],
#  ['General Insuranc', 193, 0, 0, 233, 117.26, 50.27],
#  ['Genesys Intl.  Corpn', 95, -2, -2, 19, 10.03, 50.73],
#  ['Genus Paper & Boards', 9, 0, 0, 601, 405.15, 67.37],
#  ['Genus Power Infra', 52, 1, 0, 122, 91.88, 74.93],
#  ['Geojit Finl. Service', 69, 0, 0, 890, 410.02, 46.06],
#  ['GFL', 71, 0, 0, 40, 33.02, 81.1],
#  ['GHCL', 258, 0, 0, 566, 128.27, 22.65],
#  ['GIC Housing Fin', 126, -2, -2, 239, 123.6, 51.63],
#  ['Ginni Filaments', 30, -4, -1, 301, 197.31, 65.52],
#  ['Gland Pharma', 3135, -1, -34, 287, 135.22, 47.03],
#  ['Glaxosmithkline Phar', 1467, 0, 5, 21, 10.89, 51.53],
#  ['Glenmark Pharma', 605, 0, -2, 2167, 418.8, 19.32],
#  ['Global Education', 52, 0, 0, 53, 42.95, 80.98],
#  ['Global Vectra Helico', 44, 3, 1, 27, 22.73, 83.88],
#  ['Globus Spirits', 327, 1, 4, 227, 155.97, 68.42],
#  ['GM Breweries', 425, 2, 10, 51, 27.53, 53.48],
#  ['GMDC', 74, 0, 0, 1781, 565.02, 31.72],
#  ['GMM Pfaudler', 5317, 4, 225, 341, 65.72, 19.26],
#  ['GMR Infrastructure', 26, 1, 0, 14800, 4257.15, 28.76],
#  ['GNA  Axles', 442, 11, 46, 1265, 384.76, 30.41],
#  ['GNFC', 375, -2, -10, 1071, 585.66, 54.67],
#  ['Goa Carbon', 340, 2, 9, 123, 36.19, 29.3],
#  ['Godawari Power & Isp', 910, 3, 29, 333, 146.5, 43.92],
#  ['Godfrey Phillips', 906, 0, 5, 46, 15.35, 33.02],
#  ['Godrej Agrovet', 558, 1, 9, 546, 166.54, 30.47],
#  ['Godrej Consumer Prod', 808, -1, -10, 1910, 924.55, 48.4],
#  ['Godrej Industries', 569, 1, 5, 843, 139.64, 16.56],
#  ['Godrej Properties', 1352, 3, 47, 1862, 433.0, 23.24],
#  ['Gokaldas Exports', 124, -4, -5, 422, 269.72, 63.84],
#  ['Gokul Agro Resources', 27, -1, 0, 288, 156.07, 54.17],
#  ['Gokul Refoils & Solv', 24, -3, 0, 193, 114.97, 59.33],
#  ['Goldiam Internatl.', 435, 2, 12, 191, 85.58, 44.7],
#  ['Goldstone Technology', 10, -2, 0, 41, 31.99, 76.94],
#  ['Goodluck India', 97, 0, 0, 121, 69.45, 57.04],
#  ['Goodyear India', 939, 0, 6, 27, 20.96, 75.0],
#  ['GP Petroleums', 51, 3, 1, 786, 422.05, 53.68],
#  ['GPT Infraprojects', 43, 0, 0, 36, 30.17, 81.87],
#  ['Granules India', 320, 0, -2, 3178, 1316.27, 41.41],
#  ['Graphite India', 792, 6, 50, 5508, 1132.37, 20.56],
#  ['Grasim Industries', 1370, 0, -1, 1445, 452.36, 31.3],
#  ['Gravita India', 105, 0, 0, 215, 118.17, 54.96],
#  ['Greaves Cotton', 130, 0, 0, 659, 339.4, 51.49],
#  ['Greenpanel Inds.', 249, -2, -6, 559, 439.63, 78.64],
#  ['Greenply Industries', 216, -1, -4, 1029, 476.87, 46.3],
#  ['Grindwell Norton', 1188, 0, -5, 45, 16.87, 37.02],
#  ['GSFC', 117, 0, 0, 1955, 762.99, 39.02],
#  ['GSS Infotech', 66, -4, -2, 174, 137.17, 78.78],
#  ['GTL', 7, 5, 0, 179, 146.69, 81.92],
#  ['GTPL Hathway', 147, 0, 1, 78, 48.48, 62.08],
#  ['Gufic Biosciences', 197, 0, -1, 1287, 689.54, 53.56],
#  ['Guj. Alkalies & Chem', 412, 0, -1, 240, 85.74, 35.66],
#  ['Guj. Ambuja Exports', 172, -5, -9, 3672, 1568.6, 42.72],
#  ['Guj. Apollo Inds', 217, -4, -9, 25, 17.19, 66.69],
#  ['Guj. Inds.  Power', 83, 0, 0, 402, 252.44, 62.65],
#  ['Guj. Sidhee Cement', 40, -3, -1, 480, 204.67, 42.57],
#  ['Guj. State Petronet', 270, 0, -1, 355, 165.81, 46.62],
#  ['Gujarat Fluorochemic', 823, 0, -7, 58, 31.19, 53.15],
#  ['Gujarat Gas', 522, 1, 10, 979, 438.78, 44.79],
#  ['Gujarat Pipavav Port', 103, 0, 0, 822, 380.99, 46.32],
#  ['Gulf Oil Lubricant', 709, 0, 4, 19, 11.58, 59.69],
#  ['Gulshan Polyols', 169, -3, -6, 593, 409.0, 68.88],
#  ['Happiest Minds Tech.', 749, -1, -12, 1644, 653.54, 39.74],
#  ['Harrisons Malayalam', 180, 0, 0, 652, 128.27, 19.65],
#  ['Hathway Cable & Data', 26, 4, 1, 16636, 7689.77, 46.22],
#  ['Hatsun Agro Products', 853, 0, -2, 249, 230.16, 92.14],
#  ['Havells India', 1015, -1, -12, 1361, 336.77, 24.74],
#  ['HBL Power Sys', 41, 3, 1, 1577, 921.12, 58.39],
#  ['HCC', 9, 1, 0, 6074, 3717.24, 61.19],
#  ['HCL Infosystems', 9, 0, 0, 420, 263.79, 62.68],
#  ['HCL Tech.', 932, 0, 2, 4191, 2261.63, 53.95],
#  ['HDFC', 2540, 0, 22, 2655, 1356.42, 51.08],
#  ['HDFC Asset Mngt. Co', 2821, 0, 7, 122, 62.61, 51.3],
#  ['HDFC Bank', 1509, 0, 12, 11073, 4781.06, 43.18],
#  ['HDFC Life Insurance', 670, 0, 0, 1785, 833.45, 46.68],
#  ['HealthcareGlobal', 193, 2, 4, 134, 32.99, 24.46],
#  ['HEG', 2413, 10, 219, 1131, 348.25, 30.79],
#  ['Heidelberg Cement', 243, 0, -2, 455, 358.29, 78.58],
#  ['Hemisphere Propert.', 140, 0, 0, 3074, 1407.3, 45.78],
#  ['Heranba Industries', 726, 0, 2, 309, 74.43, 24.08],
#  ['Hercules Hoists', 125, 1, 2, 116, 55.14, 47.45],
#  ['Heritage Foods', 336, 2, 9, 379, 168.52, 44.35],
#  ['Hero MotoCorp', 2900, 0, 16, 1587, 365.42, 23.02],
#  ['Hexa Tradex', 120, 2, 2, 53, 38.75, 71.96],
#  ['HFCL', 44, -8, -4, 52344, 20579.76, 39.32],
#  ['HG Infra Engineering', 373, 4, 15, 789, 380.13, 48.17],
#  ['Hikal', 405, 4, 19, 934, 490.89, 52.55],
#  ['Himadri Speciality', 49, 0, 0, 4265, 1744.53, 40.9],
#  ['Himatsingka Seide', 178, 3, 6, 621, 351.77, 56.62],
#  ['Hind National Glass', 37, 0, 0, 21, 16.0, 74.91],
#  ['Hind Oil Exploration', 104, -7, -8, 1415, 854.73, 60.39],
#  ['Hind Rectifiers', 140, 2, 3, 21, 12.79, 59.49],
#  ['Hindalco', 389, 0, 0, 23694, 5382.75, 22.72],
#  ['Hinduja Global Soln.', 1819, 3, 60, 112, 78.2, 69.82],
#  ['Hindustan Aeron', 1014, -1, -10, 253, 196.11, 77.3],
#  ['Hindustan Composites', 332, 10, 31, 154, 59.67, 38.67],
#  ['Hindustan Copper', 170, 0, 1, 6000, 2189.62, 36.49],
#  ['Hindustan Media Vent', 76, 7, 5, 298, 166.19, 55.72],
#  ['Hindustan Motors', 7, -2, 0, 282, 237.17, 84.07],
#  ['Hindustan Unilever', 2336, -1, -25, 1194, 789.7, 66.09],
#  ['Hindustan Zinc', 329, -4, -15, 5130, 1863.66, 36.32],
#  ['Hitech Corporation', 177, -1, -2, 105, 62.11, 58.65],
#  ['Hi-Tech Gears', 199, 0, 0, 19, 13.01, 67.7],
#  ['Hi-Tech Pipes', 427, 8, 32, 531, 161.03, 30.32],
#  ['HLE Glascoat', 3261, -3, -114, 30, 16.46, 54.82],
#  ['HLV', 7, 8, 0, 1255, 880.39, 70.12],
#  ['Home First Finance', 512, 0, 1, 62, 29.6, 47.37],
#  ['Housing & Urban Dev.', 49, 5, 2, 11701, 3195.87, 27.31],
#  ['HOV Services', 58, 3, 2, 48, 35.66, 73.55],
#  ['HPCL', 284, 2, 8, 7145, 2291.9, 32.08],
#  ['HPL Electric', 57, 4, 2, 111, 111.67, 100.0],
#  ['HSIL', 217, 6, 13, 1344, 563.7, 41.92],
#  ['HT Media', 26, 19, 4, 5061, 3101.45, 61.28],
#  ['Hubtown', 17, 2, 0, 148, 109.21, 73.49],
#  ['Huhtamaki India', 284, 6, 17, 669, 346.07, 51.66],
#  ['ICE MakeRefrigeratio', 75, 2, 2, 53, 37.53, 70.34],
#  ['ICICI Bank', 647, 0, 4, 20323, 6650.27, 32.72],
#  ['ICICI Lombard Gen.', 1493, -2, -33, 402, 189.1, 46.96],
#  ['ICICI Prudential', 553, 1, 8, 1138, 334.93, 29.41],
#  ['ICICI Securities', 582, -1, -6, 1020, 478.2, 46.84],
#  ['IDBI', 39, 0, 0, 18383, 6987.32, 38.01],
#  ['IDFC', 56, 3, 2, 14752, 8910.52, 60.4],
#  ['IDFC First Bank', 59, 3, 2, 91370, 26828.02, 29.36],
#  ['IFB Agro Inds', 500, 3, 18, 136, 58.21, 42.74],
#  ['IFB Industries', 971, 0, 0, 33, 17.5, 51.95],
#  ['IFCI', 11, 4, 0, 4329, 2324.44, 53.69],
#  ['IFGL Refractories', 357, -5, -22, 124, 78.17, 62.64],
#  ['IG Petrochem.', 568, 3, 18, 400, 213.99, 53.47],
#  ['Igarashi Motors', 473, 0, -2, 66, 27.02, 40.43],
#  ['IIFL Finance', 264, 0, 1, 158, 84.96, 53.64],
#  ['IIFL Securities', 75, 3, 2, 9121, 2155.16, 23.63],
#  ['IIFL Wealth Mgment.', 1197, 7, 79, 438, 409.27, 93.26],
#  ['Imagicaaworld Enter', 7, 4, 0, 432, 403.71, 93.25],
#  ['IMP Powers', 14, 0, 0, 20, 12.09, 60.32],
#  ['Incredible Indu', 30, 18, 4, 563, 215.76, 38.27],
#  ['Ind Tourism Dev Corp', 371, 0, 1, 63, 18.13, 28.34],
#  ['Indbank Merch. Bankg', 16, 2, 0, 517, 250.1, 48.34],
#  ['India Cements', 196, -2, -5, 22380, 4046.94, 18.08],
#  ['India Glycols', 491, 0, -2, 74, 30.61, 41.08],
#  ['India Hume Pipe', 187, 5, 9, 359, 173.27, 48.21],
#  ['India Nipon Electric', 400, 3, 13, 92, 48.03, 51.91],
#  ['India Power Corpn.', 12, 1, 0, 46, 42.69, 91.48],
#  ['Indiabulls Housing', 217, 0, 1, 15898, 2555.84, 16.08],
#  ['Indiabulls Real Est.', 91, 0, 0, 6987, 1961.72, 28.08],
#  ['Indiamart Intermesh', 7585, -1, -89, 101, 26.38, 26.04],
#  ['Indian Bank', 144, 3, 4, 8821, 1521.36, 17.25],
#  ['Indian Energy Exch', 367, -1, -5, 1952, 947.29, 48.51],
#  ['Indian Hotel', 129, 0, 0, 3784, 2323.78, 61.41],
#  ['Indian Metal & Ferro', 416, 0, 2, 36, 20.4, 55.65],
#  ['Indian Oil Corp.', 109, 4, 5, 83199, 23286.11, 27.99],
#  ['Indian Overseas Bank', 17, 0, 0, 10334, 3824.41, 37.01],
#  ['Indian Railway Finance', 24, 2, 0, 32823, 17586.51, 53.58],
#  ['Indian Terrain Fash.', 35, 0, 0, 679, 427.91, 62.98],
#  ['Indigo Paints', 2566, 1, 37, 76, 39.02, 51.1],
#  ['Indo Count Inds', 152, -1, -2, 278, 133.44, 47.94],
#  ['Indo Rama Synth', 51, -1, 0, 307, 201.57, 65.51],
#  ['Indo Tech Transform.', 122, 4, 5, 131, 57.94, 43.91],
#  ['Indoco Remedies', 358, 2, 9, 214, 108.94, 50.83],
#  ['Indostar Capital Fin', 303, 0, 0, 55, 45.0, 81.06],
#  ['Indowind Energy', 4, 1, 0, 78, 58.05, 74.24],
#  ['Indraprastha Gas', 507, 1, 5, 2425, 1258.9, 51.89],
#  ['Indraprastha Medical', 87, -1, -1, 652, 274.91, 42.14],
#  ['Ind-Swift Lab.', 90, 9, 7, 1795, 895.49, 49.87],
#  ['Indus Towers', 242, -1, -3, 2612, 1464.14, 56.04],
#  ['Indusind Bank', 1004, -1, -11, 5385, 948.19, 17.61],
#  ['INEOS Styrolution', 1334, 0, -11, 98, 52.28, 53.22],
#  ['Infibeam Avenues', 40, -1, 0, 1866, 1084.28, 58.09],
#  ['Info Edge', 4356, 0, 22, 523, 217.17, 41.46],
#  ['Infobeans Tech.', 252, -3, -9, 95, 47.9, 50.17],
#  ['Infosys', 1348, 0, -6, 4225, 2718.19, 64.33],
#  ['Ingersoll Rand', 839, 1, 15, 116, 53.51, 46.02],
#  ['Inox Leisure', 299, 1, 3, 233, 95.22, 40.82],
#  ['Inox Wind', 75, 1, 0, 80, 45.89, 57.28],
#  ['Insecticides India', 557, 0, -1, 45, 21.96, 47.87],
#  ['Intellect Design', 775, 1, 13, 551, 378.82, 68.73],
#  ['Intense Tech', 55, -4, -2, 146, 87.65, 59.63],
#  ['Interglobe Aviation', 1683, 0, -9, 427, 163.58, 38.22],
#  ['Intrasoft Tech', 81, 1, 0, 48, 37.14, 76.0],
#  ['Inventure Growth&Sec', 33, 0, 0, 166, 96.81, 58.05],
#  ['IOL Chem & Pharma', 620, 0, 0, 304, 117.26, 38.52],
#  ['Ipca Laboratories', 2246, 0, 18, 196, 99.86, 50.87],
#  ['IRB Infra.&Developer', 109, 0, 0, 2278, 916.82, 40.23],
#  ['Ircon International', 49, -4, -2, 10707, 5400.93, 50.44],
#  ['IRCTC', 1884, 1, 22, 1271, 326.17, 25.66],
#  ['ISGEC Heavy Engg.', 528, -1, -7, 75, 60.13, 79.73],
#  ['ITC', 211, 1, 2, 28865, 16372.25, 56.72],
#  ['ITD Cementation', 88, 3, 3, 1851, 866.6, 46.8],
#  ['ITI', 120, 0, -1, 275, 117.88, 42.77],
#  ['IZMO', 76, -3, -2, 121, 74.19, 61.18],
#  ['J Kumar Infraproject', 186, 0, -1, 90, 50.84, 56.49],
#  ['J&K Bank', 29, 0, 0, 8671, 3864.73, 44.57],
#  ['Jagran Prakashan', 57, 6, 3, 2655, 1047.82, 39.46],
#  ['Jagsonpal Pharma', 98, 0, 0, 94, 52.38, 55.67],
#  ['Jai Balaji Inds', 46, -3, -1, 32, 25.77, 80.43],
#  ['Jai Corp', 104, 5, 5, 6598, 1368.88, 20.74],
#  ['Jain Irrigation Sys', 21, -2, 0, 2875, 2040.06, 70.95],
#  ['Jain Irrigation(DVR)', 13, -3, 0, 46, 35.04, 75.02],
#  ['Jamna Auto Inds.', 80, 4, 3, 9445, 2338.1, 24.75],
#  ['Jash Engineering', 434, 0, 1, 50, 25.77, 51.45],
#  ['Jay Bharat Maruti', 345, 8, 27, 270, 104.68, 38.65],
#  ['Jay Shree Tea', 99, -2, -2, 420, 104.15, 24.77],
#  ['Jayant Agro-Organics', 181, 0, -1, 56, 35.12, 62.34],
#  ['Jayaswal Neco Inds', 17, -2, 0, 283, 197.42, 69.62],
#  ['Jaypee Infratech', 1, 2, 0, 424, 424.82, 100.0],
#  ['JB Chem & Pharma', 1427, -1, -15, 112, 43.38, 38.62],
#  ['JBM Auto', 435, 2, 10, 52, 24.2, 45.7],
#  ['JHS Svendgaard', 21, -1, 0, 100, 73.15, 72.87],
#  ['Jindal Drilling&Inds', 105, -2, -2, 74, 58.72, 79.08],
#  ['Jindal Hisar', 180, -2, -4, 825, 430.83, 52.21],
#  ['Jindal Poly Films', 855, -1, -14, 87, 54.64, 62.28],
#  ['Jindal Saw', 90, 1, 1, 4307, 1461.23, 33.92],
#  ['Jindal Stainless', 94, -1, -1, 1093, 609.39, 55.72],
#  ['Jindal Steel & Power', 397, -1, -5, 10885, 2093.68, 19.23],
#  ['Jindal Worldwide', 52, -1, -1, 158, 17.69, 11.16],
#  ['JK Cement', 2927, 0, 11, 25, 14.94, 57.93],
#  ['JK Lakshmi Cement', 527, 6, 34, 3175, 793.87, 25.0],
#  ['JK Paper', 151, -1, -1, 1083, 354.69, 32.75],
#  ['JK Tyres & Inds.', 126, 2, 2, 2129, 1118.77, 52.53],
#  ['JM Financial', 83, 0, 0, 1549, 757.77, 48.92],
#  ['JMC Projects (India)', 107, 1, 1, 356, 198.34, 55.57],
#  ['JMT Auto', 2, -1, 0, 465, 350.68, 75.36],
#  ['Jocil', 201, 16, 28, 534, 180.47, 33.78],
#  ['Johnson Controls', 2267, 0, 9, 86, 51.53, 59.75],
#  ['JP Power Ventures', 3, 4, 0, 35949, 20015.95, 55.68],
#  ['JSW Energy', 116, 0, 0, 3916, 1354.23, 34.57],
#  ['JSW Ispat Special', 53, 4, 2, 8854, 4282.13, 48.36],
#  ['JSW Steel', 681, -2, -16, 22332, 2453.02, 10.98],
#  ['JTEKT India', 114, 20, 19, 11578, 2563.11, 22.14],
#  ['Jubilant FoodWorks', 3013, 0, -6, 536, 101.56, 18.94],
#  ['Jubilant Inds.', 298, 0, 2, 44, 29.19, 65.27],
#  ['Jubilant Ingrevia', 484, 10, 47, 1985, 697.42, 35.13],
#  ['Jubilant Pharmova', 830, -1, -15, 239, 140.93, 58.8],
#  ['Jullundur Motor Agen', 46, 3, 1, 43, 38.6, 88.8],
#  ['Jump Networks', 6, 4, 0, 454, 454.9, 100.0],
#  ['Just Dial', 787, -1, -11, 1252, 298.48, 23.83],
#  ['Jyothy Labs', 146, 0, 0, 443, 270.36, 60.96],
#  ['Kabra Extrus.technik', 193, 9, 16, 510, 258.8, 50.69],
#  ['Kajaria Ceramics', 952, 2, 21, 382, 281.47, 73.58],
#  ['Kakatiya Cemen Sugar', 257, -1, -3, 31, 15.75, 50.52],
#  ['Kalpataru PowerTrans', 430, 2, 11, 710, 248.41, 34.97],
#  ['Kalyan Jewell.India', 63, 1, 1, 3276, 1670.13, 50.97],
#  ['Kalyani Steels', 387, -3, -15, 232, 123.02, 52.87],
#  ['Kamat Hotels (India)', 40, 5, 2, 620, 337.03, 54.31],
#  ['Kamdhenu', 149, -1, -2, 98, 42.74, 43.28],
#  ['Kanani Industries', 4, 2, 0, 21, 14.88, 70.15],
#  ['Kanoria Chem. & Inds', 133, 4, 5, 62, 48.64, 78.3],
#  ['Kanpur Plastipack', 198, 1, 2, 158, 97.56, 61.74],
#  ['Kansai Nerolac Paint', 565, 1, 6, 146, 86.17, 58.64],
#  ['Karda Constructions', 176, -2, -4, 105, 59.02, 55.77],
#  ['Karnataka Bank', 71, 2, 1, 4661, 1671.94, 35.87],
#  ['Karur Vysya Bank', 59, 3, 1, 6452, 2390.92, 37.05],
#  ['Kaveri Seed', 765, -1, -11, 178, 72.7, 40.66],
#  ['Kaya', 283, 1, 2, 28, 16.81, 59.71],
#  ['KCP', 109, -2, -3, 215, 133.39, 61.98],
#  ['KCP Sugar&Inds. Corp', 20, -1, 0, 616, 258.66, 41.93],
#  ['KDDL', 281, -3, -9, 20, 14.32, 68.86],
#  ['KEC International', 421, 3, 13, 488, 215.14, 44.03],
#  ['Keerti Knowledge', 21, -2, 0, 245, 86.81, 35.42],
#  ['KEI Industries', 612, 1, 6, 876, 247.89, 28.28],
#  ['Kellton Tech Solut.', 67, 6, 4, 2857, 959.3, 33.57],
#  ['Kesoram Industries', 78, 0, 0, 634, 331.91, 52.34],
#  ['Khadim India', 168, 3, 6, 225, 78.0, 34.55],
#  ['Khaitan Chem & Fert.', 32, -4, -1, 365, 212.29, 58.12],
#  ['Khandwala Securities', 18, 9, 1, 37, 17.36, 46.55],
#  ['KIOCL', 214, 2, 6, 207, 118.47, 57.15],
#  ['Kiri Industries', 460, 0, -1, 53, 22.34, 41.85],
#  ['Kirloskar Brothers', 299, 3, 8, 124, 53.86, 43.15],
#  ['Kirloskar Ferrous', 242, -1, -3, 106, 68.88, 64.61],
#  ['Kirloskar Oil Eng', 211, 1, 3, 433, 205.06, 47.33],
#  ['Kitex Garments', 114, 0, 0, 549, 320.95, 58.45],
#  ['KM Sugar Mills', 18, -1, 0, 849, 372.65, 43.88],
#  ['KNR Construction', 233, 2, 5, 1621, 723.66, 44.64],
#  ['Kokuyo Camlin', 57, 0, 0, 306, 199.44, 65.12],
#  ['Kolte Patil Develop.', 236, 0, 0, 403, 200.75, 49.8],
#  ['Kopran', 194, 1, 3, 775, 444.77, 57.33],
#  ['Kotak Mahindra Bank', 1757, 0, 0, 3613, 2173.36, 60.14],
#  ['Kothari Petrochem', 41, 0, 0, 225, 129.18, 57.25],
#  ['Kothari Products', 81, -2, -2, 24, 13.62, 56.25],
#  ['Kothari Sugars &Chem', 37, -2, 0, 901, 378.07, 41.94],
#  ['KPIT Technologies', 245, 0, 0, 851, 523.51, 61.45],
#  ['KPR  Mill', 1483, 2, 32, 43, 29.75, 68.75],
#  ['KRBL', 236, -2, -6, 665, 345.96, 51.98],
#  ['Krebs Biochem.&Inds', 128, 0, 0, 30, 20.31, 65.7],
#  ['Kridhan Infra', 4, 7, 0, 217, 193.26, 88.78],
#  ['KSB', 988, 1, 16, 125, 51.73, 41.08],
#  ['L&T Finance Holdings', 90, 0, 0, 11771, 4271.39, 36.29],
#  ['L&T Infotech', 3664, 0, 8, 169, 76.28, 44.93],
#  ['L&T Technology Serv.', 2588, -1, -36, 122, 57.71, 47.15],
#  ['La Opala R G', 281, 8, 23, 2245, 339.63, 15.12],
#  ['Lambodhara Textiles', 64, 0, 0, 39, 20.66, 52.24],
#  ['Landmark PropertyDev', 2, -4, 0, 21, 19.44, 91.55],
#  ['Larsen & Toubro', 1443, 1, 25, 5035, 1686.59, 33.49],
#  ['Lasa Supergenerics', 80, 2, 2, 729, 318.41, 43.62],
#  ['Laurus Labs', 514, 5, 25, 7496, 1994.35, 26.6],
#  ['Laxmi Organic Inds.', 237, 5, 12, 6644, 1798.69, 27.07],
#  ['LCC Infotech', 1, -3, 0, 287, 287.44, 100.0],
#  ['Lemon Tree Hotels', 41, 1, 0, 3194, 1362.27, 42.65],
#  ['LG Balakrishnan&Bros', 325, 7, 23, 503, 167.42, 33.28],
#  ['LGB Forge', 4, -1, 0, 119, 111.33, 93.53],
#  ['Libas Consumer Prod', 47, -3, -1, 408, 222.7, 54.47],
#  ['Liberty Shoes', 140, 2, 2, 282, 89.41, 31.67],
#  ['LIC Housing Finance', 458, 0, 2, 2277, 711.38, 31.24],
#  ['Likhitha Infrastruct', 421, 0, 3, 133, 51.65, 38.79],
#  ['Lincoln Pharma', 320, -1, -6, 258, 99.34, 38.49],
#  ['Linde India', 1644, 0, -2, 86, 57.18, 65.99],
#  ['Lovable Lingerie', 112, 9, 9, 2503, 579.03, 23.13],
#  ['LT Foods', 88, 1, 1, 3825, 1376.15, 35.97],
#  ['Lumax Auto Tech', 148, 1, 2, 193, 79.38, 40.96],
#  ['Lupin', 1198, -1, -15, 3053, 659.15, 21.58],
#  ['Lux Industries', 2225, 9, 183, 380, 194.13, 51.03],
#  ['Lyka Labs', 63, 4, 3, 66, 66.77, 99.98],
#  ['Lypsa Gems', 4, 1, 0, 24, 15.34, 62.99],
#  ['Maan Aluminium', 191, 1, 2, 40, 21.57, 53.2],
#  ['Macpower CNC Machine', 95, 4, 4, 71, 54.81, 76.28],
#  ['Macrotech Developers', 644, 0, 0, 300, 180.61, 60.03],
#  ['Madhav Marbles&Gran.', 60, 4, 2, 311, 142.59, 45.77],
#  ['Madras Fertilizers', 29, -1, 0, 169, 108.42, 63.9],
#  ['Magadh Sugar & Energ', 172, -1, -3, 65, 32.38, 49.19],
#  ['Magma Fincorp', 133, -1, -1, 900, 529.71, 58.82],
#  ['Magnum Ventures', 5, 4, 0, 13, 13.65, 100.0],
#  ['Mah & Mah Finl. Serv', 163, 1, 2, 12142, 4491.55, 36.99],
#  ['Mahamaya Steel Inds', 89, 1, 1, 20, 14.91, 71.04],
#  ['Mahanagar Gas', 1141, 0, 10, 681, 109.03, 15.99],
#  ['Maharashtra Seamless', 292, 0, 0, 71, 32.42, 45.21],
#  ['Maheshwari Logistics', 111, -1, -1, 26, 15.44, 57.9],
#  ['Mahindra & Mahindra', 810, -1, -8, 3495, 1593.18, 45.58],
#  ['Mahindra CIE Auto.', 186, 0, -1, 202, 89.36, 44.06],
#  ['Mahindra EPC Irrigat', 144, 0, 1, 67, 37.2, 55.45],
#  ['Mahindra Holi.&Resor', 219, 1, 2, 493, 258.54, 52.4],
#  ['Mahindra Life. Dev', 525, -1, -7, 18, 11.81, 62.48],
#  ['Mahindra Logistics', 540, 1, 7, 94, 43.62, 46.11],
#  ['Maithan Alloys', 756, 0, 1, 59, 29.52, 49.53],
#  ['Majesco', 76, 0, 0, 330, 242.47, 73.38],
#  ['Malu Paper Mills', 28, 0, 0, 27, 14.22, 51.38],
#  ['Man Industries', 105, 5, 5, 768, 372.29, 48.44],
#  ['Man InfraConstruct', 42, -1, 0, 683, 410.9, 60.09],
#  ['Manaksia', 65, 4, 3, 200, 130.63, 65.3],
#  ['Manaksia Coated', 15, -3, 0, 53, 40.53, 75.21],
#  ['Manaksia Steels', 26, 4, 1, 98, 61.59, 62.6],
#  ['Manali Petro', 80, 0, 0, 602, 367.89, 61.07],
#  ['Manappuram Finance', 160, 0, 0, 2955, 1123.24, 38.0],
#  ['Mangalam Cement', 310, -5, -18, 260, 136.82, 52.57],
#  ['Mangalam Drugs&Org.', 133, -2, -2, 209, 112.84, 53.87],
#  ['Mangalam Global Ent', 48, 2, 1, 25, 24.29, 94.37],
#  ['Mangalam Timber Prod', 12, -3, 0, 26, 21.95, 84.02],
#  ['Mangalore Chem &Fert', 87, -2, -2, 580, 376.26, 64.83],
#  ['Manugraph India', 12, 1, 0, 19, 13.2, 69.08],
#  ['Maral Overseas', 38, 0, 0, 29, 21.79, 73.36],
#  ['Marathon NextgenReal', 54, -2, -1, 61, 45.05, 72.67],
#  ['Marico', 460, 0, 0, 834, 271.58, 32.55],
#  ['Marine Electricals', 81, 0, 0, 659, 203.36, 30.84],
#  ['Marksans Pharma', 73, -1, 0, 2560, 922.1, 36.01],
#  ['Maruti Suzuki', 6871, 0, 56, 1027, 308.6, 30.03],
#  ['Mastek', 1864, 0, -6, 58, 30.82, 52.3],
#  ['Matrimony.Com', 892, 0, -2, 19, 15.48, 77.77],
#  ['Mawana Sugars', 50, 4, 2, 218, 113.66, 52.03],
#  ['Max Financial', 900, 0, -2, 372, 147.1, 39.52],
#  ['Max Healthcare  Inst', 234, 3, 7, 7236, 4736.42, 65.45],
#  ['Max India', 68, 0, 0, 185, 141.05, 76.21],
#  ['Max Ventures & Ind', 67, 1, 0, 238, 136.4, 57.29],
#  ['Mayur Uniquoters', 439, 1, 7, 63, 32.1, 50.77],
#  ['Mazagon Dock Ship', 210, 0, 0, 368, 162.35, 44.02],
#  ['MBL Infrastructures', 20, 9, 1, 465, 255.9, 54.99],
#  ['Mcdowell Holdings', 40, -1, 0, 20, 11.27, 56.0],
#  ['Mcleod Russel', 28, 4, 1, 451, 418.89, 92.87],
#  ['Menon Bearings', 65, 6, 4, 438, 190.68, 43.53],
#  ['MEP Infrastructure', 23, 19, 3, 3977, 1987.13, 49.96],
#  ['Mercator', 1, 3, 0, 1159, 704.9, 60.81],
#  ['Metropolis Health.', 2339, 2, 56, 40, 19.42, 48.14],
#  ['Minda Corporation', 112, 2, 2, 640, 270.76, 42.28],
#  ['Minda Industries', 569, 1, 8, 581, 110.48, 18.99],
#  ['Mindtree', 2136, 0, 14, 659, 161.61, 24.52],
#  ['MIRC Electronics', 18, 4, 0, 1788, 771.42, 43.14],
#  ['Mishra Dhatu Nigam', 199, 0, -1, 401, 225.74, 56.29],
#  ['Mittal Life Style', 10, 0, 0, 33, 26.29, 79.48],
#  ['Modison Metals', 57, 4, 2, 59, 47.23, 78.96],
#  ['Mohit Industries', 7, 4, 0, 14, 10.44, 73.22],
#  ['Mohota Industries', 6, 4, 0, 27, 24.55, 89.55],
#  ['MOIL', 170, 1, 1, 1059, 310.36, 29.3],
#  ['Moksh Ornaments', 61, -1, 0, 174, 151.6, 86.67],
#  ['Mold-tek Packaging', 508, 7, 36, 440, 144.36, 32.8],
#  ['Mold-Tek Tech', 59, 9, 5, 1027, 341.57, 33.25],
#  ['Monte Carlo Fashions', 272, 2, 7, 110, 74.17, 67.35],
#  ['Morarjee Textiles', 15, 0, 0, 15, 12.54, 79.57],
#  ['Morepen Laboratories', 58, -1, 0, 2465, 1558.95, 63.22],
#  ['Motherson Sumi Sys', 240, -2, -4, 13720, 4215.15, 30.72],
#  ['Motilal Oswal Fin', 840, 3, 27, 1281, 311.33, 24.3],
#  ['Motor & General Fin', 19, -4, 0, 24, 17.67, 73.5],
#  ['Mphasis', 1829, 2, 43, 581, 275.75, 47.43],
#  ['MPS', 643, 3, 22, 21, 13.95, 63.73],
#  ['MRPL', 50, -1, -1, 4801, 1388.16, 28.91],
#  ['Mrs.Bectors Foods', 402, 0, 3, 389, 155.4, 39.88],
#  ['MSTC', 276, 0, -2, 263, 156.87, 59.5],
#  ['MT Educare', 7, 2, 0, 80, 68.53, 84.79],
#  ['MTAR Technologies', 929, 0, 3, 87, 34.09, 38.83],
#  ['MTNL', 17, 0, 0, 1685, 600.1, 35.61],
#  ['Mukta Arts', 38, 9, 3, 210, 105.14, 49.86],
#  ['Multi Commodity Exch', 1587, -2, -39, 396, 125.92, 31.79],
#  ['Munjal Auto Inds', 64, 6, 3, 4382, 992.05, 22.64],
#  ['Munjal Showa', 154, 6, 9, 760, 205.31, 27.0],
#  ['Murudeshwar Ceramics', 23, -1, 0, 194, 106.14, 54.52],
#  ['Music Broadcast', 23, 0, 0, 714, 581.69, 81.38],
#  ['Muthoot Capital Serv', 397, 4, 17, 159, 112.91, 70.84],
#  ['Muthoot Finance', 1268, 0, 2, 952, 374.94, 39.38],
#  ['NACL Industries', 50, 0, 0, 164, 117.52, 71.5],
#  ['Nagarjuna Fertilizer', 10, -4, 0, 2536, 1572.61, 62.0],
#  ['Nagreeka Exports', 21, 0, 0, 30, 12.11, 39.55],
#  ['Nahar Capital &Finl.', 126, 0, 0, 17, 12.88, 72.71],
#  ['Nahar Poly Films', 160, 1, 1, 182, 84.4, 46.3],
#  ['Nahar Spinning Mills', 138, 3, 4, 101, 67.23, 66.49],
#  ['Narayana Hrudayalay', 435, 0, -1, 360, 273.74, 75.87],
#  ['Natco Pharma', 1083, 9, 93, 7891, 2754.97, 34.91],
#  ['Nath Bio-Genes', 422, 0, -1, 40, 17.86, 44.46],
#  ['National Aluminium', 73, 3, 2, 37218, 10680.43, 28.7],
#  ['National Fertilizers', 66, -1, 0, 2666, 723.67, 27.14],
#  ['Nava Bharat Ventures', 93, 6, 6, 1401, 581.22, 41.46],
#  ['Navin Fluorine Intl', 3210, 0, 12, 117, 31.36, 26.6],
#  ['Navkar Corporation', 42, 1, 0, 1277, 543.68, 42.55],
#  ['Navneet Education', 79, 3, 2, 374, 191.03, 50.97],
#  ['Nazara Technologies', 1647, 0, -11, 205, 92.33, 45.01],
#  ['NBCC (India)', 48, 0, 0, 9148, 3403.75, 37.21],
#  ['NCC', 85, -3, -2, 8713, 4699.0, 53.93],
#  ['NCL Industries', 203, 0, 1, 185, 94.17, 50.69],
#  ['Nectar Lifesciences', 29, -1, 0, 779, 512.54, 65.71],
#  ['Nelcast', 79, 4, 3, 1546, 563.17, 36.41],
#  ['NELCO', 214, -1, -3, 117, 53.38, 45.54],
#  ['Neogen Chemicals', 995, 2, 20, 151, 55.8, 36.73],
#  ['NESCO', 536, 2, 12, 168, 62.16, 36.84],
#  ['Nestle', 17360, 0, -136, 57, 25.03, 43.75],
#  ['Network 18 Media Inv', 39, -1, 0, 2588, 1217.88, 47.04],
#  ['Neueon Towers', 0, 5, 0, 36, 36.61, 100.0],
#  ['Neuland Laboratories', 2204, 0, 19, 61, 39.39, 64.31],
#  ['New Delhi Television', 82, 4, 3, 33, 33.84, 100.0],
#  ['New India Assurance', 162, -1, -1, 361, 192.24, 53.17],
#  ['Newgen Software Tech', 380, 6, 23, 882, 289.9, 32.87],
#  ['Neyveli Lignite', 61, 0, 0, 7286, 2363.15, 32.43],
#  ['NHPC', 25, 0, 0, 3184, 1402.51, 44.04],
#  ['NIIT', 183, 2, 4, 358, 182.05, 50.83],
#  ['Nila Spaces', 1, 3, 0, 107, 93.64, 87.1],
#  ['Nippon Life India As', 351, 0, 0, 592, 306.2, 51.71],
#  ['Nitco', 22, 0, 0, 83, 61.48, 73.22],
#  ['Nitin Spinners', 114, -1, -2, 196, 147.51, 75.01],
#  ['Nitiraj Engineers', 52, 4, 2, 14, 12.64, 86.93],
#  ['NMDC', 182, 3, 6, 23212, 3710.9, 15.99],
#  ['NOCIL', 215, 0, 1, 655, 378.23, 57.74],
#  ['Noida Toll Bridge', 6, -1, 0, 99, 68.23, 68.29],
#  ['North Eastern Carry.', 10, 0, 0, 43, 30.5, 70.05],
#  ['NR Agarwal Inds', 253, 0, 1, 43, 24.69, 57.18],
#  ['NRB Bearings', 117, 4, 4, 1154, 555.02, 48.07],
#  ['NTPC', 112, 0, 0, 11341, 4733.8, 41.74],
#  ['Nucleus Software Exp', 583, 0, 3, 52, 29.26, 56.08],
#  ['Nureca Ltd.', 1617, 2, 35, 45, 20.79, 45.75],
#  ['Oberoi Realty', 589, -3, -22, 1093, 455.7, 41.68],
#  ['Oil India', 130, -1, -1, 642, 346.37, 53.94],
#  ['Olectra Greentech', 187, 4, 8, 720, 320.88, 44.55],
#  ['Om Infra', 22, -1, 0, 88, 58.23, 66.12],
#  ['Omax Autos', 48, 4, 2, 308, 109.17, 35.43],
#  ['Omaxe', 80, -1, -1, 147, 81.4, 55.35],
#  ['OMDC', 2601, 4, 121, 30, 15.53, 51.66],
#  ['Onelife Capital', 7, -1, 0, 19, 16.81, 87.98],
#  ['ONGC', 113, 0, 0, 24785, 9346.29, 37.71],
#  ['Onmobile Global', 119, 1, 2, 3470, 1377.09, 39.68],
#  ['Onward Technologies', 121, 1, 2, 130, 80.45, 61.59],
#  ['Optiemus Infracom', 126, -1, -2, 132, 99.39, 74.78],
#  ['Oracle Finl. Service', 3705, 1, 45, 74, 44.32, 59.36],
#  ['Orbit Exports', 70, -2, -1, 15, 10.23, 67.94],
#  ['Oricon Enterprises', 26, 2, 0, 208, 125.18, 60.17],
#  ['Orient Abrasives', 24, 0, 0, 64, 39.47, 60.98],
#  ['Orient Bell', 262, -1, -4, 57, 33.39, 58.42],
#  ['Orient Cement', 138, 0, 0, 2042, 1080.94, 52.91],
#  ['Orient Electric', 299, 0, 0, 443, 208.45, 46.96],
#  ['Orient Paper & Inds.', 27, 0, 0, 920, 605.25, 65.73],
#  ['Orient Refractories', 306, -1, -5, 607, 255.55, 42.07],
#  ['Oriental Carbon&Chem', 979, 3, 31, 37, 24.16, 65.14],
#  ['Oriental Hotels', 36, 19, 6, 2144, 1122.72, 52.34],
#  ['Oriental Trimex', 8, 2, 0, 463, 437.34, 94.31],
#  ['Ortin Laboratories', 28, -2, 0, 31, 19.41, 62.31],
#  ['Oswal Agro Mills', 9, 1, 0, 154, 108.03, 69.77],
#  ['Oswal Greentech', 20, 4, 0, 578, 383.76, 66.32],
#  ['Page Industries', 30537, 4, 1257, 63, 17.0, 26.88],
#  ['Palash Securities', 54, -3, -2, 13, 12.14, 92.99],
#  ['Panacea Biotec', 384, 3, 12, 1326, 524.13, 39.5],
#  ['Panama Petrochem', 207, 7, 13, 666, 326.56, 49.02],
#  ['Parag Milk Foods', 141, 0, 0, 329, 190.21, 57.8],
#  ['Paramount Communicat', 11, 4, 0, 1110, 708.8, 63.82],
#  ['Patel Engineering', 14, -2, 0, 541, 351.63, 64.91],
#  ['PC Jeweller', 28, 4, 1, 3417, 1928.89, 56.44],
#  ['Pearl Global Inds.', 220, -1, -4, 12, 10.2, 80.07],
#  ['Pearl Polymers', 15, 0, 0, 14, 13.56, 92.1],
#  ['Pennar Industries', 20, 0, 0, 1336, 784.5, 58.68],
#  ['Persistent Systems', 2429, 1, 39, 172, 46.38, 26.92],
#  ['Petronet LNG', 237, 0, 1, 2021, 871.37, 43.11],
#  ['Pfizer', 5242, 0, 9, 40, 11.19, 27.37],
#  ['PG Electroplast', 374, 5, 17, 28, 27.69, 98.21],
#  ['Phillips CarbonBlack', 227, -2, -4, 2743, 606.96, 22.13],
#  ['Phoenix Mills', 726, 0, -5, 129, 60.23, 46.67],
#  ['PI Industries', 2549, 0, -16, 548, 378.1, 68.9],
#  ['Pidilite Inds.', 2059, 4, 81, 2672, 879.45, 32.91],
#  ['Pioneer Distilleries', 116, 4, 4, 149, 105.52, 70.61],
#  ['Pioneer Embroideries', 53, -2, -1, 128, 70.93, 55.26],
#  ['Piramal Enterprises', 1699, -1, -28, 692, 167.62, 24.19],
#  ['Pitti Engineering', 74, 10, 7, 710, 313.62, 44.16],
#  ['Plastiblends India', 258, -2, -7, 57, 33.41, 58.15],
#  ['PNB', 39, 4, 1, 277203, 80843.26, 29.16],
#  ['PNB Gilts', 59, -1, 0, 572, 375.93, 65.63],
#  ['PNB Housing Finance', 426, 2, 10, 745, 267.48, 35.9],
#  ['PNC Infratech', 254, 1, 4, 939, 693.87, 73.82],
#  ['Pokarna', 329, 3, 10, 556, 174.99, 31.44],
#  ['Poly Medicure', 1051, -7, -82, 796, 250.78, 31.5],
#  ['Polycab India', 1677, 3, 51, 392, 156.22, 39.81],
#  ['Polyplex Corporation', 1191, 2, 33, 207, 93.64, 45.04],
#  ['Power Finance Corp', 119, 0, 0, 4127, 1176.08, 28.5],
#  ['Power Grid Corpn.', 231, 1, 3, 12391, 2971.72, 23.98],
#  ['Power Mech Projects', 601, 0, 4, 27, 15.61, 56.87],
#  ['PPAP Automotive', 213, 4, 8, 106, 52.44, 49.34],
#  ['Praj Industries', 329, -6, -21, 5762, 2617.02, 45.41],
#  ['Prakash Inds.', 86, -1, -1, 1522, 860.74, 56.53],
#  ['Prakash Pipes', 159, 16, 22, 2292, 667.52, 29.11],
#  ['Prataap Snacks', 552, 0, 1, 30, 19.27, 62.33],
#  ['Precision Camshafts', 61, 10, 6, 2156, 790.77, 36.67],
#  ['Precision Wire India', 202, 0, 0, 20, 10.93, 52.92],
#  ['Precot', 163, 3, 5, 24, 20.36, 83.52],
#  ['Premier Explosives', 141, -4, -6, 30, 21.1, 68.52],
#  ['Premier Polyfilm', 52, 8, 4, 231, 93.36, 40.3],
#  ['Pressman Advertising', 24, 0, 0, 27, 17.52, 64.69],
#  ['Prestige Estate Proj', 267, 0, 0, 340, 202.37, 59.37],
#  ['Pricol', 89, 5, 5, 3931, 2097.45, 53.35],
#  ['Prime Securities', 46, 3, 1, 46, 31.88, 68.9],
#  ['Prince Pipes & Fitti', 739, 2, 19, 1629, 592.06, 36.34],
#  ['Prism Johnson', 139, 0, 0, 362, 279.48, 77.17],
#  ['Privi Speciality Che', 1102, 0, 6, 49, 21.67, 43.89],
#  ['Procter&Gamble Healt', 6035, 2, 157, 28, 18.92, 67.04],
#  ['Prozone Intu Propert', 20, 4, 0, 602, 344.29, 57.14],
#  ['PSP Projects', 411, 2, 11, 233, 163.82, 70.13],
#  ['PTC India', 89, -2, -2, 1717, 1122.37, 65.36],
#  ['Pudumjee Paper', 23, 0, 0, 92, 66.58, 72.22],
#  ['Punjab & Sind Bank', 21, 3, 0, 4650, 2783.18, 59.85],
#  ['Puravankara', 80, 0, 0, 456, 245.69, 53.84],
#  ['PVR', 1244, 0, -2, 620, 140.84, 22.7],
#  ['Quess Corp', 646, -1, -12, 124, 60.73, 48.8],
#  ['Quick Heal Tech', 236, 4, 9, 3028, 742.77, 24.53],
#  ['R Systems Intl.', 133, -1, -2, 60, 37.71, 61.94],
#  ['Radico Khaitan', 586, 0, -3, 325, 119.37, 36.65],
#  ['Rail Vikas Nigam', 30, 0, 0, 8379, 3737.37, 44.6],
#  ['Railtel Corporation Of India Lt..', 130, 0, -1, 1193, 667.89, 55.94],
#  ['Rain Industries', 173, 0, 0, 2735, 1161.68, 42.47],
#  ['Raj Oil Mills', 108, 4, 4, 14, 10.38, 69.87],
#  ['Rajesh Exports', 516, 0, 0, 330, 185.75, 56.15],
#  ['Rajratan Global Wire', 961, -5, -57, 37, 24.19, 64.42],
#  ['Rajshree Sugars&Chem', 21, 1, 0, 36, 20.48, 56.6],
#  ['Rallis India', 309, -1, -4, 451, 166.04, 36.75],
#  ['Rama Steel Tubes', 76, 2, 1, 29, 17.51, 59.09],
#  ['Ramco Inds.', 299, 0, 2, 196, 108.09, 55.13],
#  ['Ramco Systems', 552, -2, -13, 134, 78.11, 57.93],
#  ['Ramkrishna Forgings', 634, 1, 6, 121, 68.09, 56.26],
#  ['Ramky Infrastructure', 82, 4, 3, 266, 154.29, 57.91],
#  ['Rana Sugars', 15, 6, 0, 2170, 945.52, 43.55],
#  ['Rane Holdings', 577, 0, 1, 37, 19.72, 52.5],
#  ['Rane Madras', 347, -1, -5, 64, 31.67, 49.31],
#  ['Ratnamani Metals', 1937, 0, 4, 19, 11.33, 57.39],
#  ['RattanIndia Ent', 18, 4, 0, 89, 89.47, 100.0],
#  ['RattanIndia Power', 3, -1, 0, 7792, 5048.76, 64.79],
#  ['Ravi Kumar Distiller', 9, 2, 0, 15, 11.72, 77.93],
#  ['Ravinder Heights', 19, 4, 0, 31, 31.81, 100.0],
#  ['Raymond', 365, 0, -2, 424, 148.84, 35.1],
#  ['RBL Bank', 210, 1, 2, 9637, 1768.05, 18.35],
#  ['RCF', 83, 0, 0, 3041, 964.11, 31.7],
#  ['REC', 144, 0, 0, 3348, 882.13, 26.34],
#  ['Redington', 180, -2, -3, 470, 262.51, 55.75],
#  ['Refex Industries', 150, 8, 11, 1386, 552.66, 39.85],
#  ['Relaxo Footwears', 1032, 0, -3, 235, 74.5, 31.64],
#  ['Reliance Capital', 11, 4, 0, 4757, 2257.9, 47.46],
#  ['Reliance Home Financ', 2, -1, 0, 7445, 3446.28, 46.29],
#  ['Reliance Indl. Infra', 414, 1, 7, 667, 108.5, 16.26],
#  ['Reliance Industries', 1985, 0, -16, 3946, 1599.4, 40.53],
#  ['Reliance Infra', 56, 9, 4, 24808, 10583.38, 42.66],
#  ['Reliance Power', 7, 4, 0, 37246, 26543.72, 71.26],
#  ['Religare Enterprises', 102, 4, 4, 4394, 2337.44, 53.18],
#  ['Renaissance Global', 515, 3, 15, 60, 12.25, 20.2],
#  ['Repco Home Finance', 350, 1, 6, 139, 93.43, 67.07],
#  ['Responsive Inds', 159, -1, -1, 37, 15.35, 41.12],
#  ['Rico Auto Inds', 48, 11, 4, 10656, 2906.92, 27.28],
#  ['Rites', 247, 0, 0, 139, 89.33, 63.83],
#  ['RKEC Projects', 65, 3, 2, 32, 25.89, 79.82],
#  ['Rollatainers', 2, -3, 0, 56, 55.92, 99.81],
#  ['Rolta India', 4, 2, 0, 669, 398.77, 59.58],
#  ['Rossari Biotech', 1216, 3, 45, 208, 82.58, 39.66],
#  ['Rossell India', 118, 0, 0, 61, 34.11, 55.21],
#  ['Route Mobile', 1510, 0, -14, 273, 128.74, 47.02],
#  ['Royal Orchid Hotels', 78, 5, 3, 505, 316.54, 62.58],
#  ['RPG Life Sciences', 451, 0, 0, 29, 12.36, 41.69],
#  ['RPP Infra Projects', 68, -2, -1, 36, 22.51, 60.86],
#  ['RPSG Ventures', 428, 8, 34, 278, 142.0, 51.05],
#  ['RS Software (India)', 27, -1, 0, 67, 47.42, 70.43],
#  ['RSWM', 244, 2, 5, 75, 59.19, 77.94],
#  ['Ruchi Soya Inds', 1073, 5, 51, 28, 28.38, 100.0],
#  ['Ruchira Papers', 68, 1, 1, 50, 34.86, 68.63],
#  ['Rudrabhishek Enter.', 197, 0, 0, 73, 45.1, 61.58],
#  ['Rupa & Co', 328, 2, 8, 948, 327.99, 34.58],
#  ['S Chand And Co', 96, 0, 0, 61, 33.37, 53.92],
#  ['Sadbhav Engineering', 69, -1, 0, 388, 220.66, 56.83],
#  ['Sadbhav Infra. Proj', 22, 1, 0, 462, 272.85, 58.95],
#  ['Sagar Cements', 913, 2, 24, 82, 37.09, 45.05],
#  ['SAIL', 124, 2, 2, 96749, 21262.11, 21.98],
#  ['Sakar Healthcare', 137, -2, -3, 32, 22.45, 68.36],
#  ['Saksoft', 512, 3, 15, 45, 31.01, 68.18],
#  ...]

# %%
import pandas,openpyxl,pyodbc

class WriteData:
    
    connection_string='Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
    con=pyodbc.connect(connection_string)
    cursor=con.cursor()
    
    
    def __init__(self):
        
        self.stockPriceInfo=super().rCurrentStockInfoWeb()
        self.stockVolInfo=super().rCurrentStockVolDelInfoWeb()
        
    
    def wExcel(self,df:list):
        data=pandas.DataFrame(df)
        data.to_excel(r"C:\Users\DELL\Desktop\kPython RND folder\abhil.xlsx")
    
   
    def wSQL(self):
        
        query1="drop table tblCurrentStockInfo" 
        query2="create table tblCurrentStockInfo ([Stock Name] nvarchar(60) not null primary key,[LTP] int,[Prev Price] int,[Change(%)] int,[Change Price] int,[Vol] int)"
        query3="insert into tblCurrentStockInfo values ('{}',{},{},{},{},{})"
        
        try:
#             connection_string='Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
#             con=pyodbc.connect(connection_string)
#             cursor=con.cursor()
            try:
                cursor.execute(query1)
            except pyodbc.ProgrammingError:
                pass
            cursor.execute(query2)
            df=self.stockPriceInfo
            for i in range(0,len(df)):
                if len(df[i])==0:
                    continue
                cursor.execute(query3.format(df[i][0],df[i][1],df[i][2],df[i][3],df[i][4],df[i][5]))
            cursor.commit()
        finally:

            cursor.close()
            con.close()
            print('close')

            
    def wStockVolSQL(self):
        query1="drop table tblCurrentStockVolInfo" 
        query2="create table tblCurrentStockVolInfo ([Stock Name] nvarchar(60) not null primary key,[Trade Vol] float,[Delivery Vol] float,[Delivery(%)] float,[LTP] float)"
        query3="insert into tblCurrentStockVolInfo values ('{}',{},{},{},{})"
        
        try:
            connection_string='Driver={SQL Server};Server=DESKTOP-2CDQJ66\SQLEXPRESS;Database=Stock_Market_K;Trusted_Connection=yes;'
            con=pyodbc.connect(connection_string)
            cursor=con.cursor()
            try:
                cursor.execute(query1)
            except pyodbc.ProgrammingError:
                pass
            cursor.execute(query2)
            df=self.stockVolInfo
            for i in range(0,len(df)):
                if len(df[i])==0:
                    continue
                cursor.execute(query3.format(df[i][0],df[i][1],df[i][2],df[i][3],df[i][4]))
            cursor.commit()
        finally:

            cursor.close()
            con.close()
            print('close')
# Out:
# close

# %%
for i in range(10):
    locals()["abh{}".format(i)]=i
#     "abh{}".format(i))
print(abh3)
# Out:
# 3

# %%
class Parent():
    pass

# %%
p=Parent()

# %%
locals()["abh"]=QtWidget.QLabel()

# %%
"abh"=a;Nb"abh"

# %%
import pandas, openpyxl
df=pandas.read_excel(r"C:\Users\DELL\Desktop\a.xlsx",nrows=117,skiprows=1)
df
# Out:
#        0      ('20 Microns', 69, 9, 6, 1089, 608.32, 55.85)  Unnamed: 2  \
# 0      1  ('3I Infotech', 8, -1, 0, 27016, 13214.33, 48.91)         NaN
# 1      2   ('3P Land Holdings', 13, 0, 0, 33, 25.44, 76.03)         NaN
# 2      3   ('5Paisa Capital', 368, 0, -2, 29, 17.77, 60.77)         NaN
# 3      4  ('Aakash Exploration', 157, 0, 1, 64, 19.54, 3...         NaN
# 4      5  ('Aarti Drugs', 738, -1, -10, 410, 177.62, 43.23)         NaN
# ..   ...                                                ...         ...
# 112  113  ('Aurobindo Pharma', 1013, 0, 0, 1249, 471.14,...         NaN
# 113  114       ('Auto.Axle', 1339, 1, 22, 41, 18.53, 44.49)         NaN
# 114  115       ('Autoline Inds', 35, 0, 0, 15, 12.9, 83.04)         NaN
# 115  116  ('Avadh Sugar & Energy', 300, 0, -1, 122, 42.5...         NaN
# 116  117   ('Avanti Feeds', 539, 1, 10, 377, 177.01, 46.87)         NaN
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...
# 112         NaN         NaN         NaN         NaN         NaN
# 113         NaN         NaN         NaN         NaN         NaN
# 114         NaN         NaN         NaN         NaN         NaN
# 115         NaN         NaN         NaN         NaN         NaN
# 116         NaN         NaN         NaN         NaN         NaN
#
#                                 Unnamed: 8
# 0                                Abrasives
# 1                              Agriculture
# 2                         Air Conditioners
# 3                                 Airlines
# 4           Aluminium & Aluminium Products
# ..                                     ...
# 112                        Travel Services
# 113  TV Broadcasting & Software Production
# 114                         Tyres & Allied
# 115                  Watches & Accessories
# 116                   Wood & Wood Products
#
# [117 rows x 9 columns]

# %%
df['Unnamed: 8']
# Out:
# 0                                  Abrasives
# 1                                Agriculture
# 2                           Air Conditioners
# 3                                   Airlines
# 4             Aluminium & Aluminium Products
#                        ...
# 112                          Travel Services
# 113    TV Broadcasting & Software Production
# 114                           Tyres & Allied
# 115                    Watches & Accessories
# 116                     Wood & Wood Products
# Name: Unnamed: 8, Length: 117, dtype: object

# %%
lst=[i for i in df['Unnamed: 8']]
lst
# Out:
# ['Abrasives',
#  'Agriculture',
#  'Air Conditioners',
#  'Airlines',
#  'Aluminium & Aluminium Products',
#  'Amusement Parks/Recreation/Club',
#  'Aquaculture',
#  'Auto Ancillary',
#  'Automobile Two & Three Wheelers',
#  'Automobiles - Passenger Cars',
#  'Automobiles-Tractors',
#  'Automobiles-Trucks/Lcv',
#  'Bank - Private',
#  'Bank - Public',
#  'Batteries',
#  'Bearings',
#  'BPO/ITeS',
#  'Breweries & Distilleries',
#  'Cable',
#  'Carbon Black',
#  'Castings/Forgings',
#  'Cement & Construction Materials',
#  'Ceramics/Marble/Granite/Sanitaryware',
#  'Chemicals ',
#  'Cigarettes/Tobacco',
#  'Compressors / Pumps',
#  'Construction - Real Estate',
#  'Consumer Durables - Domestic Appliances',
#  'Consumer Durables - Electronics',
#  'Consumer Food',
#  'Courier Services',
#  'Cycles',
#  'Defence',
#  'Diamond & Jewellery',
#  'Diesel Engines',
#  'Diversified',
#  'Dyes & Pigments',
#  'e-Commerce',
#  'Educational Institutions',
#  'Electric Equipment',
#  'Electrodes & Welding Equipment',
#  'Electronics - Components',
#  'Engineering',
#  'Engineering - Construction',
#  'Engineering - Industrial Equipments',
#  'Fasteners',
#  'Ferro & Silica Manganese',
#  'Fertilizers',
#  'Film Production, Distribution & Entertainment',
#  'Finance - Asset Management',
#  'Finance - Housing',
#  'Finance - Investment',
#  'Finance - NBFC',
#  'Finance - Others',
#  'Finance - Stock Broking',
#  'Finance Term Lending',
#  'Footwear',
#  'Forgings',
#  'Gas Transmission/Marketing',
#  'Glass',
#  'Hospital & Healthcare Services',
#  'Hotel, Resort & Restaurants',
#  'Household & Personal Products',
#  'Industrial Gases & Fuels',
#  'Insurance',
#  'IT - Education',
#  'IT - Hardware',
#  'IT - Networking',
#  'IT - Software ',
#  'Laminates/Decoratives',
#  'Leather',
#  'Logistics',
#  'Lubricants',
#  'Medical Equipment/Supplies/Accessories',
#  'Metal - Non Ferrous ',
#  'Mining & Minerals',
#  'Miscellaneous',
#  'Oil Exploration',
#  'Paints',
#  'Paper & Paper Products',
#  'Pesticides & Agrochemicals',
#  'Petrochemicals',
#  'Pharmaceuticals & Drugs',
#  'Photographic Products',
#  'Plastic Products',
#  'Port',
#  'Power Generation/Distribution',
#  'Printing & Stationery',
#  'Printing And Publishing',
#  'Railways Wagons',
#  'Ratings',
#  'Refineries',
#  'Refractories',
#  'Retailing',
#  'Rubber Products',
#  'Sector',
#  'Ship Building',
#  'Shipping',
#  'Solvent Extraction',
#  'Steel & Iron Products',
#  'Steel/Sponge Iron/Pig Iron',
#  'Sugar',
#  'Tea/Coffee',
#  'Telecommunication - Equipment',
#  'Telecommunication - Service Provider',
#  'Textile ',
#  'Textile - Machinery',
#  'Textile - Manmade Fibres',
#  'Textile - Spinning',
#  'Textile - Weaving',
#  'Trading',
#  'Transmission Towers / Equipments',
#  'Travel Services',
#  'TV Broadcasting & Software Production',
#  'Tyres & Allied',
#  'Watches & Accessories',
#  'Wood & Wood Products']

# %%
shiva
hhhhhhhhhhhhhhhhhhhhh[[[m ]]]
r
# Out:
# "Select stoke,[LTP],[Change(%)],[Change Price],Vol,[Delivery Vol],[Delivery(%)],Industry,[Market Cap] from dbo.All$ inner join dbo.nayiTable on dbo.All$.Stoke=dbo.nayiTable.[Stock Name] where Industry='auto' and 'LTP' = 400 order by ltp desc"

# %% [markdown]
# break and continue

# %%
for i in range(10):
    if i==5:
        continue
        
    print(i,"yes")
# Out:
# 0 yes
# 1 yes
# 2 yes
# 3 yes
# 4 yes
# 6 yes
# 7 yes
# 8 yes
# 9 yes

# %%
for i in range(10):
    if i==5:
        break        
    print(i,"yes")
# Out:
# 0 yes
# 1 yes
# 2 yes
# 3 yes
# 4 yes

# %%
for i in range(10):
    if i==5:
        print(i*2)
    else:
        pass
    print(i,"yes")
# Out:
#   File "<ipython-input-13-1117645c99ab>", line 5
#     print(i,"yes")
#     ^
# IndentationError: expected an indented block

# %%
for i in range(10):
    if i==5:
        continue
        print(i)
    print(i,"yes")
# Out:
# 0 yes
# 1 yes
# 2 yes
# 3 yes
# 4 yes
# 6 yes
# 7 yes
# 8 yes
# 9 yes

# %%
class A:
    def m1(self):
        print("m1")

# %%
class B(A):
    pass

# %%
# !python -m pip install db-sqlite3
# Out:
# Collecting db-sqlite3
#   Downloading db-sqlite3-0.0.1.tar.gz (1.4 kB)
# Collecting db
#   Downloading db-0.1.1.tar.gz (3.4 kB)
# Collecting antiorm
#   Downloading antiorm-1.2.1.tar.gz (171 kB)
# Using legacy 'setup.py install' for db-sqlite3, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for db, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for antiorm, since package 'wheel' is not installed.
# Installing collected packages: antiorm, db, db-sqlite3
#     Running setup.py install for antiorm: started
#     Running setup.py install for antiorm: finished with status 'done'
#     Running setup.py install for db: started
#     Running setup.py install for db: finished with status 'done'
#     Running setup.py install for db-sqlite3: started
#     Running setup.py install for db-sqlite3: finished with status 'done'
# Successfully installed antiorm-1.2.1 db-0.1.1 db-sqlite3-0.0.1
# WARNING: You are using pip version 20.2.3; however, version 21.1.2 is available.
# You should consider upgrading via the 'C:\Users\DELL\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import sqlite3
dbFile=r"C:\Users\DELL\Desktop\College.db"
conn=sqlite3.connect(dbFile)

# %%
#Sql lite query
def liteQuery():
#         self.stockPriceInfo = super().rCurrentStockPriceInfoWeb()
        query1 = "delete from PersonLO"
        litequery='''CREATE TABLE "PersonLO" ("Name" TEXT NOT NULL,"Age" INTEGER,"Marks" NUMERIC, PRIMARY KEY("Name"))'''
        # query2 = "create table tblCurrentStockInfo ([Stock Name] nvarchar(60) not null primary key,[LTP] int,[Prev Price] int,[Change(%)] int,[Change Price] int,[Vol] int),[Date] date not null"
#         query3 = "insert into tblCurrentStockInfo values ('{}',{},{},{},{},{},'{}')"
        query3 = "insert into personLo values ('abhkjadfkhi',12,20.2)"

        try:
            dbFile=r"C:\Users\DELL\Desktop\College.db"
            con=sqlite3.connect(dbFile)
            cursor = con.cursor()
            try:
                cursor.execute(query1)
            except sqlite3.OperationalError:
                pass
            print("executing lite query")
#             cursor.execute(litequery)
            cursor.execute(query3)
            print("lite query executed successfully")
#             df = self.stockPriceInfo
#             for i in range(0, len(df)):

#                 if len(df[i]) == 0:
#                     continue
#                 cursor.execute(query3.format(df[i][0], df[i][1], df[i][2], df[i][3], df[i][4], df[i][5],
#                                              datetime.datetime.now().date().strftime("%m/%d/%Y")))
            con.commit()
        finally:
            cursor.close()
            con.close()
            print('close')

liteQuery()
# Out:
# executing lite query
# lite query executed successfully
# close

# %%
import datetime
import sqlite3

import pandas, openpyxl, requests, bs4, pyodbc


class sqlLite(ReadData):

   

    def sqlLiteStockPrice(self):
        self.stockPriceInfo = super().rCurrentStockPriceInfoWeb()
        query1 = "drop table tblCurrentStockPriceInfo"
        query2 = '''CREATE TABLE "tblCurrentStockPriceInfo" ("Stock Name" TEXT NOT NULL,"LTP" NUMERIC,"Prev Price" NUMERIC,"Change(%)" NUMERIC,"Change Price" NUMERIC,"Vol" NUMERIC,"Date" TEXT not null)'''
        query3 = "insert into tblCurrentStockPriceInfo values ('{}',{},{},{},{},{},'{}')"

        try:

            dbFile=r"C:\Users\DELL\Desktop\College.db"
            con=sqlite3.connect(dbFile)
            cursor = con.cursor()
            try:
                cursor.execute(query1)
            except sqlite3.OperationalError:
                pass
            
            cursor.execute(query2)
            df = self.stockPriceInfo
            for i in range(0, len(df)):

                if len(df[i]) == 0:
                    continue
                cursor.execute(query3.format(df[i][0], df[i][1], df[i][2], df[i][3], df[i][4], df[i][5],
                                             datetime.datetime.now().date().strftime("%m/%d/%Y")))
                con.commit()
        finally:
            cursor.close()
            con.close()
            print('close')

    def sqlLiteStockVol(self):
        self.stockVolInfo = super().rCurrentStockVolDelInfoWeb()
        query1 = "drop Table tblCurrentStockVolInfo"
        query2 = '''CREATE TABLE "tblCurrentStockVolInfo" ("Stock Name" TEXT NOT NULL,"Vol" NUMERIC,"Delivery Vol" NUMERIC,"Delivery(%)" NUMERIC,"LTP" NUMERIC)'''
        query3 = "insert into tblCurrentStockVolInfo values ('{}',{},{},{},{})"
        
        try:
          
            dbFile=r"C:\Users\DELL\Desktop\College.db"
            con=sqlite3.connect(dbFile)
            cursor = con.cursor()
            try:
                cursor.execute(query1)
            except sqlite3.OperationalError:
                pass
            
            cursor.execute(query2)
            df = self.stockVolInfo
            for i in range(0, len(df)):

                if len(df[i]) == 0:
                    continue
                cursor.execute(query3.format(df[i][0], df[i][1], df[i][2], df[i][3], df[i][4]))
                con.commit()
        finally:

            cursor.close()
            con.close()
            print('close')


    def sqlFinalStocklistOfTuple(self):

        query = '''select * from nayiTable'''
        try:
            dbFile=r"C:\Users\DELL\Desktop\College.db"
            con=sqlite3.connect(dbFile)
            cursor = con.cursor()
            cursor.execute(query)
            df = cursor.fetchall()

        finally:
            cursor.close()
            con.close()
            print('close')
        return df
    
    
    def makeCurrentNayiTable(self):
        query1 = "drop table nayiTable"
        query2='''
create Table nayiTable as
select tblCurrentStockPriceInfo."Stock Name",tblCurrentStockPriceInfo."LTP",tblCurrentStockPriceInfo."Change(%)",
tblCurrentStockPriceInfo."Change Price",tblCurrentStockPriceInfo.[Vol],[tblCurrentStockVolInfo]."Delivery Vol",
[tblCurrentStockVolInfo]."Delivery(%)",tblCurrentStockPriceInfo."Date" from tblCurrentStockPriceInfo
inner join tblCurrentStockVolInfo on "tblCurrentStockPriceInfo"."Stock Name"=tblCurrentStockVolInfo."Stock Name"'''
        
        try:
            dbFile=r"C:\Users\DELL\Desktop\College.db"
            con=sqlite3.connect(dbFile)
            cursor = con.cursor()
            cursor.execute(query1)
            cursor.execute(query2)
            con.commit()
        finally:

            cursor.close()
            con.close()
            print('close')

# sqlLite().makeCurrentNayiTable()
d=sqlLite().sqlFinalStocklistOfTuple()
# Out:
# close
# [('Gokul Refoils & Solv', 32.7, 20, 5.45, 2410.36, 1007.6, 41.8, '06/03/2021'),
#  ('Technocraft Inds', 476.1, 20, 79.35, 349.32, 145.81, 41.74, '06/03/2021'),
#  ('Century Enka', 396.3, 20, 66.05, 2591.06, 732.95, 28.29, '06/03/2021'),
#  ('Themis Medicare', 760.9, 20, 126.8, 436.25, 118.83, 27.24, '06/03/2021'),
#  ('Kiri Industries', 548.5, 20, 91.4, 1819.62, 667.44, 36.68, '06/03/2021'),
#  ('Emami Paper Mills',
#   152.45,
#   19.99,
#   25.4,
#   320.82,
#   188.4,
#   58.72,
#   '06/03/2021'),
#  ('Alphageo India', 285.45, 19.99, 47.55, 352.12, 146.93, 41.73, '06/03/2021'),
#  ('Sutlej Textiles&Inds',
#   57.95,
#   19.98,
#   9.65,
#   3535.22,
#   1418.17,
#   40.12,
#   '06/03/2021'),
#  ('Ravi Kumar Distiller',
#   13.85,
#   19.91,
#   2.3,
#   1279.5,
#   318.95,
#   24.93,
#   '06/03/2021'),
#  ('Steel City Securitie',
#   45.6,
#   16.33,
#   6.4,
#   550.43,
#   189.54,
#   34.44,
#   '06/03/2021'),
#  ('DP Abhushan', 162.55, 15.49, 21.8, 232.67, 106.3, 45.69, '06/03/2021'),
#  ('Infobeans Tech.', 279.2, 14.97, 36.35, 353.42, 144.99, 41.03, '06/03/2021'),
#  ('PTC India Fin. Serv',
#   21.3,
#   14.82,
#   2.75,
#   13182.96,
#   6598.18,
#   50.05,
#   '06/03/2021'),
#  ('Compuage Infocom',
#   25.95,
#   14.82,
#   3.35,
#   2218.76,
#   857.91,
#   38.67,
#   '06/03/2021'),
#  ('PNB Gilts', 86.6, 14.32, 10.85, 29546.98, 3899.19, 13.2, '06/03/2021'),
#  ('GTPL Hathway', 156.8, 14.08, 19.35, 591.87, 260.38, 43.99, '06/03/2021'),
#  ('Maithan Alloys', 865.8, 13.82, 105.1, 708.96, 217.6, 30.69, '06/03/2021'),
#  ('Sumitomo Chemical India',
#   363.35,
#   13.74,
#   43.9,
#   12993.36,
#   2498.64,
#   19.23,
#   '06/03/2021'),
#  ('Om Infra', 29.05, 13.7, 3.5, 1904.61, 909.52, 47.75, '06/03/2021'),
#  ('Motherson Sumi Sys',
#   269.1,
#   13.4,
#   31.8,
#   101188.21,
#   13991.23,
#   13.83,
#   '06/03/2021'),
#  ('Transformers & Rect',
#   28.75,
#   13.19,
#   3.35,
#   2652.6,
#   1102.4,
#   41.56,
#   '06/03/2021'),
#  ('IRB Infra.&Developer',
#   130.9,
#   12.8,
#   14.85,
#   25088.04,
#   5710.86,
#   22.76,
#   '06/03/2021'),
#  ('Sarla Perform. Fibre',
#   37.6,
#   12.24,
#   4.1,
#   694.62,
#   351.18,
#   50.56,
#   '06/03/2021'),
#  ('KRBL', 225.35, 11.12, 22.55, 3408.97, 1179.57, 34.6, '06/03/2021'),
#  ('BGR  Energy Systems',
#   64.4,
#   10.75,
#   6.25,
#   1933.37,
#   604.61,
#   31.27,
#   '06/03/2021'),
#  ('Nilkamal', 2443.75, 10.28, 227.75, 246.49, 54.27, 22.02, '06/03/2021'),
#  ('Rajratan Global Wire',
#   1129.6,
#   10.27,
#   105.25,
#   104.71,
#   47.33,
#   45.2,
#   '06/03/2021'),
#  ('Salzer Electronics',
#   156.6,
#   10.17,
#   14.45,
#   2279.64,
#   581.37,
#   25.5,
#   '06/03/2021'),
#  ('Tide Water Oil Co(I)',
#   11532.95,
#   10,
#   1048.45,
#   85.17,
#   17.58,
#   20.65,
#   '06/03/2021'),
#  ('Mindteck', 68.75, 10, 6.25, 241.7, 143.15, 59.22, '06/03/2021'),
#  ('PNB Housing Finance',
#   693.8,
#   10,
#   63.05,
#   4035.73,
#   1695.56,
#   42.01,
#   '06/03/2021'),
#  ('Jindal Drilling&Inds',
#   117.2,
#   10,
#   10.65,
#   446.69,
#   208.67,
#   46.72,
#   '06/03/2021'),
#  ('Shreyas Shipping', 213, 9.99, 19.35, 831.68, 302.4, 36.36, '06/03/2021'),
#  ('Indo Rama Synth', 52.85, 9.99, 4.8, 332.4, 212, 63.78, '06/03/2021'),
#  ('Vascon Engineers', 19.85, 9.97, 1.8, 1822.69, 1315.05, 72.15, '06/03/2021'),
#  ('Dynacons Sys & Sol', 119.1, 9.97, 10.8, 119.74, 88.21, 73.67, '06/03/2021'),
#  ('Chaman Lal Setia Exp',
#   135.65,
#   9.97,
#   12.3,
#   398.51,
#   273.29,
#   68.58,
#   '06/03/2021'),
#  ('Salona Cotspin', 126.35, 9.97, 11.45, 18.23, 10.52, 57.74, '06/03/2021'),
#  ('Ganesh Housing Corp',
#   79.1,
#   9.94,
#   7.15,
#   113.02,
#   109.45,
#   96.84,
#   '06/03/2021'),
#  ('Prozone Intu Propert',
#   38.25,
#   9.91,
#   3.45,
#   1841.54,
#   1566.75,
#   85.08,
#   '06/03/2021'),
#  ('DB Intnl.StockBroker', 19.1, 9.77, 1.7, 16.62, 13.83, 83.21, '06/03/2021'),
#  ('Pearl Polymers', 17, 9.68, 1.5, 150.38, 97.97, 65.14, '06/03/2021'),
#  ('Ducon Infra.', 8.5, 9.68, 0.75, 433.66, 325.07, 74.96, '06/03/2021'),
#  ('Adani Total Gas',
#   1579.85,
#   9.67,
#   139.25,
#   2772.39,
#   1110.24,
#   40.05,
#   '06/03/2021'),
#  ('BLS Internatl.Serv',
#   126.4,
#   9.63,
#   11.1,
#   5705.36,
#   1426.93,
#   25.01,
#   '06/03/2021'),
#  ('GP Petroleums', 58.8, 9.5, 5.1, 1138.15, 438.77, 38.55, '06/03/2021'),
#  ('Tainwala Chem&Plast.', 78.6, 9.47, 6.8, 50.27, 34.61, 68.85, '06/03/2021'),
#  ('Suzlon Energy', 6.45, 9.32, 0.55, 173915.13, 64040.56, 36.82, '06/03/2021'),
#  ('Gufic Biosciences',
#   192.65,
#   9.27,
#   16.35,
#   1151.35,
#   461.97,
#   40.12,
#   '06/03/2021'),
#  ('Adani Enterprises',
#   1546.75,
#   9.21,
#   130.5,
#   24541.95,
#   1839.34,
#   7.49,
#   '06/03/2021'),
#  ('Dolat Investment', 74.1, 9.13, 6.2, 1225.64, 572.64, 46.72, '06/03/2021'),
#  ('Easy Trip Planners',
#   362.7,
#   9.12,
#   30.3,
#   4801.91,
#   1294.11,
#   26.95,
#   '06/03/2021'),
#  ('Gokaldas Exports', 136.35, 8.95, 11.2, 879.1, 522.55, 59.44, '06/03/2021'),
#  ('CentralBank of India',
#   20.2,
#   8.89,
#   1.65,
#   31060.14,
#   11695.1,
#   37.65,
#   '06/03/2021'),
#  ('Pennar Industries',
#   25.95,
#   8.81,
#   2.1,
#   5569.98,
#   3161.72,
#   56.76,
#   '06/03/2021'),
#  ('Bank of Maharashtra',
#   25.7,
#   8.67,
#   2.05,
#   23388.05,
#   8106.84,
#   34.66,
#   '06/03/2021'),
#  ('Indostar Capital Fin',
#   371.2,
#   8.67,
#   29.6,
#   1462.95,
#   349.19,
#   23.87,
#   '06/03/2021'),
#  ('Electrotherm India',
#   129.6,
#   8.59,
#   10.25,
#   117.74,
#   51.36,
#   43.62,
#   '06/03/2021'),
#  ('Hinduja Global Soln.',
#   1952.7,
#   8.47,
#   152.4,
#   234.21,
#   136.44,
#   58.25,
#   '06/03/2021'),
#  ('Vidhi Specialty Food',
#   217.05,
#   8.44,
#   16.9,
#   712.84,
#   307.68,
#   43.16,
#   '06/03/2021'),
#  ('Vesuvius India', 1087.7, 8.36, 83.95, 140.34, 54.32, 38.71, '06/03/2021'),
#  ('Kirloskar Brothers',
#   420.55,
#   8.31,
#   32.25,
#   425.62,
#   211.98,
#   49.81,
#   '06/03/2021'),
#  ('Century Extrusions',
#   7.25,
#   8.21,
#   0.55,
#   1355.63,
#   764.37,
#   56.38,
#   '06/03/2021'),
#  ('Federal-Mogul Goetze',
#   332.8,
#   8.16,
#   25.1,
#   2285.95,
#   710.02,
#   31.06,
#   '06/03/2021'),
#  ('Muthoot Finance', 1414.9, 8.1, 106, 7848.35, 1445.04, 18.41, '06/03/2021'),
#  ('TCI Express', 1531.8, 8.04, 114, 180.46, 59.4, 32.91, '06/03/2021'),
#  ('Welspun India', 94.3, 8.02, 7, 6615.2, 2711.47, 40.99, '06/03/2021'),
#  ('Mangalam Drugs&Org.',
#   135.5,
#   8.01,
#   10.05,
#   362.86,
#   194.12,
#   53.5,
#   '06/03/2021'),
#  ('Kamat Hotels (India)',
#   51.25,
#   8.01,
#   3.8,
#   870.4,
#   366.13,
#   42.06,
#   '06/03/2021'),
#  ('Raj TV Network', 39.9, 7.98, 2.95, 88.63, 29.44, 33.22, '06/03/2021'),
#  ('Uniphos Enterprises', 118.35, 7.79, 8.55, 54.14, 37.7, 69.63, '06/03/2021'),
#  ('Zota Health Care', 162.75, 7.78, 11.75, 96.18, 70.88, 73.69, '06/03/2021'),
#  ('Excel Industries', 1082.4, 7.77, 78.05, 195.28, 64.53, 33.04, '06/03/2021'),
#  ('GNA  Axles', 446.85, 7.55, 31.35, 812.99, 184.25, 22.66, '06/03/2021'),
#  ('Maheshwari Logistics',
#   111.95,
#   7.39,
#   7.7,
#   97.03,
#   39.75,
#   40.96,
#   '06/03/2021'),
#  ('RKEC Projects', 83.85, 7.36, 5.75, 92.57, 55.26, 59.7, '06/03/2021'),
#  ('Triveni Turbine', 115.4, 7.35, 7.9, 4183.03, 1032.9, 24.69, '06/03/2021'),
#  ('Tilaknagar Inds', 37.25, 7.19, 2.5, 1249.74, 635.3, 50.83, '06/03/2021'),
#  ('Kokuyo Camlin', 63.5, 7.17, 4.25, 953.36, 645.04, 67.66, '06/03/2021'),
#  ('Fineotex Chemical', 91.85, 7.11, 6.1, 2279.95, 913.66, 40.07, '06/03/2021'),
#  ('Intense Tech', 67.8, 7.11, 4.5, 354.85, 238.87, 67.32, '06/03/2021'),
#  ('Murudeshwar Ceramics',
#   25.8,
#   7.05,
#   1.7,
#   356.32,
#   182.31,
#   51.16,
#   '06/03/2021'),
#  ('Malu Paper Mills', 31.9, 7.05, 2.1, 689.39, 283.2, 41.08, '06/03/2021'),
#  ('Alkali Metals', 64.75, 7.02, 4.25, 290, 111.17, 38.34, '06/03/2021'),
#  ('JMC Projects (India)',
#   111.6,
#   6.95,
#   7.25,
#   517.7,
#   235.58,
#   45.5,
#   '06/03/2021'),
#  ('Solar Industries', 1598, 6.9, 103.2, 308.04, 53.35, 17.32, '06/03/2021'),
#  ('Cigniti Technologies',
#   454.7,
#   6.9,
#   29.35,
#   465.89,
#   277.99,
#   59.67,
#   '06/03/2021'),
#  ('Bombay Dyeing Mfg.', 82.7, 6.85, 5.3, 3827.85, 1431.46, 37.4, '06/03/2021'),
#  ('KEI Industries', 666.2, 6.8, 42.4, 875.68, 201.02, 22.96, '06/03/2021'),
#  ('Varroc Engineering',
#   436.25,
#   6.79,
#   27.75,
#   366.75,
#   155.76,
#   42.47,
#   '06/03/2021'),
#  ('Sarda Energy&Mineral',
#   537.9,
#   6.68,
#   33.7,
#   175.01,
#   95.3,
#   54.45,
#   '06/03/2021'),
#  ('Worth Peripherals', 65.7, 6.66, 4.1, 39.71, 29.3, 73.8, '06/03/2021'),
#  ('Pitti Engineering', 109.05, 6.65, 6.8, 2673.5, 1085.9, 40.62, '06/03/2021'),
#  ('Kingfa Science', 965.85, 6.62, 60, 20.71, 11.35, 54.83, '06/03/2021'),
#  ('Jubilant Ingrevia', 502, 6.6, 31.1, 1436.17, 563.58, 39.24, '06/03/2021'),
#  ('Nagreeka Exports', 25.1, 6.36, 1.5, 68.45, 37.43, 54.69, '06/03/2021'),
#  ('Dhunseri Ventures',
#   187.55,
#   6.35,
#   11.2,
#   354.73,
#   198.59,
#   55.98,
#   '06/03/2021'),
#  ('Asian Granito India',
#   199.05,
#   6.3,
#   11.8,
#   949.17,
#   404.87,
#   42.65,
#   '06/03/2021'),
#  ('Ambika Cotton Mills',
#   1216.8,
#   6.24,
#   71.5,
#   170.47,
#   82.63,
#   48.48,
#   '06/03/2021'),
#  ('Shree DigvijayCement',
#   80.45,
#   6.2,
#   4.7,
#   1713.17,
#   745.79,
#   43.53,
#   '06/03/2021'),
#  ('Menon Bearings', 67.05, 6.18, 3.9, 130.53, 70.1, 53.71, '06/03/2021'),
#  ('Chalet Hotels', 183.9, 6.15, 10.65, 1821.29, 497.61, 27.32, '06/03/2021'),
#  ('GOCL Corporation', 231.95, 6.13, 13.4, 45.54, 25.14, 55.2, '06/03/2021'),
#  ('Emmbi Industries', 98.5, 6.09, 5.65, 59.79, 35, 58.54, '06/03/2021'),
#  ('Lambodhara Textiles', 72, 6.04, 4.1, 140.1, 65.04, 46.42, '06/03/2021'),
#  ('The Anup Engineering',
#   888.25,
#   6,
#   50.25,
#   618.63,
#   151.71,
#   24.52,
#   '06/03/2021'),
#  ('Indoco Remedies', 396.55, 5.94, 22.25, 702.92, 168.88, 24.03, '06/03/2021'),
#  ('SKM Egg Products', 80.25, 5.94, 4.5, 3195.41, 745.8, 23.34, '06/03/2021'),
#  ('Siyaram Silk Mills',
#   303.6,
#   5.91,
#   16.95,
#   691.39,
#   269.83,
#   39.03,
#   '06/03/2021'),
#  ('Shreyans Inds', 103, 5.91, 5.75, 193.74, 108.66, 56.09, '06/03/2021'),
#  ('IDFC First Bank',
#   60.95,
#   5.91,
#   3.4,
#   76400.65,
#   27830.29,
#   36.43,
#   '06/03/2021'),
#  ('Phillips CarbonBlack',
#   223.7,
#   5.82,
#   12.3,
#   1853.35,
#   917.18,
#   49.49,
#   '06/03/2021'),
#  ('Heritage Foods', 370.65, 5.81, 20.35, 3266.81, 1048.71, 32.1, '06/03/2021'),
#  ('Heranba Industries',
#   772.9,
#   5.79,
#   42.3,
#   1051.52,
#   431.9,
#   41.07,
#   '06/03/2021'),
#  ('Shilpa Medicare',
#   522.75,
#   5.78,
#   28.55,
#   1326.34,
#   350.07,
#   26.39,
#   '06/03/2021'),
#  ('Kirloskar Industries',
#   1897.7,
#   5.75,
#   103.25,
#   52.28,
#   27.15,
#   51.94,
#   '06/03/2021'),
#  ('IFB Industries', 1132.9, 5.75, 61.6, 395.17, 112.65, 28.51, '06/03/2021'),
#  ('Dishman Carbogen Amc',
#   206.15,
#   5.75,
#   11.2,
#   1900.05,
#   711.71,
#   37.46,
#   '06/03/2021'),
#  ('Moksh Ornaments', 70.95, 5.74, 3.85, 138.23, 82.21, 59.47, '06/03/2021'),
#  ('Elecon Engg.', 120.1, 5.72, 6.5, 3083.67, 1299.22, 42.13, '06/03/2021'),
#  ('Hind Oil Exploration',
#   106.2,
#   5.67,
#   5.7,
#   4798.79,
#   1422.22,
#   29.64,
#   '06/03/2021'),
#  ('PNB', 44, 5.64, 2.35, 397167.13, 89029.18, 22.42, '06/03/2021'),
#  ('Sterling and Wilson',
#   233.35,
#   5.64,
#   12.45,
#   3802.24,
#   1162.42,
#   30.57,
#   '06/03/2021'),
#  ('La Opala R G', 280.35, 5.63, 14.95, 779.49, 336.27, 43.14, '06/03/2021'),
#  ('Indo Count Inds', 152.3, 5.62, 8.1, 482.77, 192.25, 39.82, '06/03/2021'),
#  ('HT Media', 26.35, 5.61, 1.4, 405.58, 286.06, 70.53, '06/03/2021'),
#  ('Shree Rama News', 18.85, 5.6, 1, 415.96, 245.66, 59.06, '06/03/2021'),
#  ('Punjab & Sind Bank',
#   20.85,
#   5.57,
#   1.1,
#   3093.57,
#   1010.76,
#   32.67,
#   '06/03/2021'),
#  ('Raymond', 385.65, 5.44, 19.9, 2411.28, 627.82, 26.04, '06/03/2021'),
#  ('Himatsingka Seide', 170.4, 5.38, 8.7, 394.34, 210.95, 53.49, '06/03/2021'),
#  ('EmkayGlobal Finl.Ser',
#   79.35,
#   5.38,
#   4.05,
#   265.19,
#   115.78,
#   43.66,
#   '06/03/2021'),
#  ('Dollar Industries',
#   334.35,
#   5.37,
#   17.05,
#   897.45,
#   274.71,
#   30.61,
#   '06/03/2021'),
#  ('Indian Bank', 143.25, 5.29, 7.2, 4958.25, 1524.13, 30.74, '06/03/2021'),
#  ('Aegis Logistics', 374.6, 5.27, 18.75, 1803.14, 641.52, 35.58, '06/03/2021'),
#  ('Happiest Minds Tech.',
#   888.1,
#   5.23,
#   44.1,
#   3877.85,
#   817.34,
#   21.08,
#   '06/03/2021'),
#  ('Jagsonpal Pharma',
#   128.15,
#   5.21,
#   6.35,
#   3211.57,
#   769.38,
#   23.96,
#   '06/03/2021'),
#  ('Ginni Filaments', 29.35, 5.2, 1.45, 260.05, 130.64, 50.24, '06/03/2021'),
#  ('Ramkrishna Forgings',
#   648.05,
#   5.14,
#   31.7,
#   276.18,
#   78.38,
#   28.38,
#   '06/03/2021'),
#  ('Indian Overseas Bank',
#   17.5,
#   5.11,
#   0.85,
#   26001.87,
#   8051.29,
#   30.96,
#   '06/03/2021'),
#  ('Gateway Distriparks',
#   296.65,
#   5.05,
#   14.25,
#   227.84,
#   143.8,
#   63.11,
#   '06/03/2021'),
#  ('DIC India', 432.25, 5, 20.6, 31.13, 16.52, 53.06, '06/03/2021'),
#  ('Goa Carbon', 342.3, 5, 16.3, 41.01, 30.47, 74.3, '06/03/2021'),
#  ('Reliance Home Financ',
#   3.15,
#   5,
#   0.15,
#   3469.22,
#   1337.35,
#   38.55,
#   '06/03/2021'),
#  ('JSW Ispat Special', 58.8, 5, 2.8, 5122.19, 2993.79, 58.45, '06/03/2021'),
#  ('Vishnu Chemicals', 394.85, 5, 18.8, 46.33, 32.58, 70.33, '06/03/2021'),
#  ('Tejas Networks', 181.75, 5, 8.65, 661.5, 384.38, 58.11, '06/03/2021'),
#  ('TVS Electronics', 150.25, 5, 7.15, 116.81, 59.63, 51.05, '06/03/2021'),
#  ('Hikal', 401.55, 4.99, 19.1, 547.83, 287.56, 52.49, '06/03/2021'),
#  ('Almondz Global Sec', 43.1, 4.99, 2.05, 31.64, 27.23, 86.08, '06/03/2021'),
#  ('KIOCL', 267.05, 4.99, 12.7, 175.17, 102.39, 58.45, '06/03/2021'),
#  ('Brooks Laboratories', 99.9, 4.99, 4.75, 25.94, 16.56, 63.86, '06/03/2021'),
#  ('Den Networks', 52.6, 4.99, 2.5, 10210.99, 3970.23, 38.88, '06/03/2021'),
#  ('AYM Syntex', 71.55, 4.99, 3.4, 110.56, 94.39, 85.37, '06/03/2021'),
#  ('Nahar Spinning Mills',
#   156.8,
#   4.99,
#   7.45,
#   246.2,
#   205.51,
#   83.47,
#   '06/03/2021'),
#  ('Kopran', 188.55, 4.98, 8.95, 418.66, 240.06, 57.34, '06/03/2021'),
#  ('Supreme Engineering', 40.05, 4.98, 1.9, 148.2, 110.62, 74.64, '06/03/2021'),
#  ('Reliance Infra', 63.4, 4.97, 3, 6889.95, 4005.12, 58.13, '06/03/2021'),
#  ('Magma Fincorp', 150.05, 4.97, 7.1, 497.3, 497.3, 100, '06/03/2021'),
#  ('HOV Services', 53.9, 4.97, 2.55, 17.83, 12.36, 69.33, '06/03/2021'),
#  ('Allied Digital Serv.',
#   65.55,
#   4.96,
#   3.1,
#   987.92,
#   493.76,
#   49.98,
#   '06/03/2021'),
#  ('Shiva Mills', 71.9, 4.96, 3.4, 28.08, 28.08, 100, '06/03/2021'),
#  ('Refex Industries', 143.85, 4.96, 6.8, 184.72, 85.99, 46.55, '06/03/2021'),
#  ('Precot', 173.7, 4.95, 8.2, 42.55, 38.6, 90.7, '06/03/2021'),
#  ('Aban Offshore', 37.1, 4.95, 1.75, 177.4, 145.94, 82.27, '06/03/2021'),
#  ('Nava Bharat Ventures',
#   90.2,
#   4.94,
#   4.25,
#   954.71,
#   385.06,
#   40.33,
#   '06/03/2021'),
#  ('Nahar Ind.Enterprise',
#   65.8,
#   4.94,
#   3.1,
#   159.31,
#   137.71,
#   86.44,
#   '06/03/2021'),
#  ('Firstsource Solution',
#   146.5,
#   4.94,
#   6.9,
#   5133.68,
#   1486.98,
#   28.97,
#   '06/03/2021'),
#  ('Morepen Laboratories',
#   56.3,
#   4.94,
#   2.65,
#   4168.08,
#   1863.05,
#   44.7,
#   '06/03/2021'),
#  ('Marathon NextgenReal', 61.7, 4.93, 2.9, 77.61, 62.69, 80.78, '06/03/2021'),
#  ('Digispice Technolog', 50, 4.93, 2.35, 593.69, 486.11, 81.88, '06/03/2021'),
#  ('Manaksia Steels', 27.7, 4.92, 1.3, 264.5, 234.39, 88.62, '06/03/2021'),
#  ('Bhagyanagar India', 52.4, 4.9, 2.45, 206.29, 94.95, 46.03, '06/03/2021'),
#  ('Tata Teleservice(Mah',
#   17.15,
#   4.89,
#   0.8,
#   13056.09,
#   7120.77,
#   54.54,
#   '06/03/2021'),
#  ('Delta Manufacturing', 36.45, 4.89, 1.7, 18.24, 16.31, 89.4, '06/03/2021'),
#  ('Future Enterprises', 9.65, 4.89, 0.45, 1724.05, 853.41, 49.5, '06/03/2021'),
#  ('Andhra Cements', 9.65, 4.89, 0.45, 207.68, 207.68, 100, '06/03/2021'),
#  ('CMI', 45.05, 4.89, 2.1, 33.31, 23.77, 71.36, '06/03/2021'),
#  ('MBL Infrastructures',
#   22.55,
#   4.88,
#   1.05,
#   155.98,
#   103.03,
#   66.05,
#   '06/03/2021'),
#  ('IZMO', 78.4, 4.88, 3.65, 152.48, 104.31, 68.41, '06/03/2021'),
#  ('Jindal Poly Films', 811.1, 4.87, 37.7, 202.55, 106.23, 52.44, '06/03/2021'),
#  ('Wheels India', 565.15, 4.87, 26.25, 133.03, 58.75, 44.16, '06/03/2021'),
#  ('Anant Raj', 60.3, 4.87, 2.8, 1133.06, 668.01, 58.96, '06/03/2021'),
#  ('Commercial Engineers',
#   20.5,
#   4.86,
#   0.95,
#   154.31,
#   118.59,
#   76.85,
#   '06/03/2021'),
#  ('Patel Integrated Log',
#   23.75,
#   4.86,
#   1.1,
#   164.13,
#   151.5,
#   92.31,
#   '06/03/2021'),
#  ('The Mandhana Retail', 15.15, 4.84, 0.7, 173.01, 110.8, 64.04, '06/03/2021'),
#  ('Gujarat Gas', 566.5, 4.83, 26.1, 13999.77, 1636.86, 11.69, '06/03/2021'),
#  ('Future Retail', 50, 4.82, 2.3, 5328.92, 2595.78, 48.71, '06/03/2021'),
#  ('Jain Irrigation Sys', 21.95, 4.77, 1, 1748.69, 1287.12, 73.6, '06/03/2021'),
#  ('Reliance Capital', 15.4, 4.76, 0.7, 11001.79, 4035.18, 36.68, '06/03/2021'),
#  ('Usha Martin Educatn.', 4.4, 4.76, 0.2, 167.63, 122.1, 72.84, '06/03/2021'),
#  ('GTL Infrastructure',
#   1.1,
#   4.76,
#   0.05,
#   46434.48,
#   26597.75,
#   57.28,
#   '06/03/2021'),
#  ('Diligent Media Corpn', 2.2, 4.76, 0.1, 112.39, 107.36, 95.53, '06/03/2021'),
#  ('Gayatri Highways', 1.1, 4.76, 0.05, 1586.86, 913.35, 57.56, '06/03/2021'),
#  ('Sastasundar Ventures',
#   218.05,
#   4.76,
#   9.9,
#   171.56,
#   131.74,
#   76.79,
#   '06/03/2021'),
#  ('GFL', 83.7, 4.76, 3.8, 672.89, 321.04, 47.71, '06/03/2021'),
#  ('RattanIndia Ent', 18.75, 4.75, 0.85, 160.78, 160.78, 100, '06/03/2021'),
#  ('MP Bharat Agro Prod', 87.15, 4.75, 3.95, 11.67, 10.14, 86.89, '06/03/2021'),
#  ('Parsvnath Developers',
#   11.05,
#   4.74,
#   0.5,
#   503.04,
#   405.34,
#   80.58,
#   '06/03/2021'),
#  ('SKIL Infrastructure', 3.35, 4.69, 0.15, 140.55, 125, 88.94, '06/03/2021'),
#  ('Sreeleathers', 173.35, 4.68, 7.75, 45.77, 24.43, 53.37, '06/03/2021'),
#  ('RBL Bank', 221.15, 4.66, 9.85, 15709.64, 6692.04, 42.6, '06/03/2021'),
#  ('CSB Bank', 319, 4.66, 14.2, 546.17, 174.13, 31.88, '06/03/2021'),
#  ('HCL Infosystems', 11.25, 4.65, 0.5, 1961.83, 902.52, 46, '06/03/2021'),
#  ('Speciality Restauran', 54, 4.65, 2.4, 151.15, 103.31, 68.35, '06/03/2021'),
#  ('GTL', 10.15, 4.64, 0.45, 209.19, 146.63, 70.09, '06/03/2021'),
#  ('Vikas WSP', 5.65, 4.63, 0.25, 479.41, 394.84, 82.36, '06/03/2021'),
#  ('Bharat Forge', 697.5, 4.63, 30.85, 3349.28, 993.04, 29.65, '06/03/2021'),
#  ('Bang Overseas', 32.8, 4.63, 1.45, 55.56, 34.61, 62.28, '06/03/2021'),
#  ('Reliance Power', 9.05, 4.62, 0.4, 87959.86, 34789.39, 39.55, '06/03/2021'),
#  ('Jump Networks', 7.95, 4.61, 0.35, 1032.48, 869.98, 84.26, '06/03/2021'),
#  ('Mohota Industries', 6.85, 4.58, 0.3, 67.54, 61.04, 90.38, '06/03/2021'),
#  ('Mohit Industries', 8, 4.58, 0.35, 14, 10.94, 78.1, '06/03/2021'),
#  ('Brightcom Group', 9.15, 4.57, 0.4, 4337.25, 2902.15, 66.91, '06/03/2021'),
#  ('Landmark PropertyDev', 2.3, 4.55, 0.1, 25.46, 16.83, 66.11, '06/03/2021'),
#  ('Eros Internatl.Media',
#   30.05,
#   4.52,
#   1.3,
#   977.97,
#   456.43,
#   46.67,
#   '06/03/2021'),
#  ('Vaswani Industries', 13.9, 4.51, 0.6, 19.12, 18.07, 94.48, '06/03/2021'),
#  ('Prism Johnson', 129.95, 4.5, 5.6, 359.34, 209.02, 58.17, '06/03/2021'),
#  ('Mayur Uniquoters', 470.45, 4.5, 20.25, 157.23, 98.4, 62.58, '06/03/2021'),
#  ('Everest Industries', 391.7, 4.48, 16.8, 129.4, 64.85, 50.12, '06/03/2021'),
#  ('Lux Industries', 3145.4, 4.46, 134.2, 202.64, 65.61, 32.38, '06/03/2021'),
#  ('Dhanlaxmi Bank', 15.35, 4.42, 0.65, 1545.41, 947.52, 61.31, '06/03/2021'),
#  ('PTC India', 91.3, 4.4, 3.85, 1579.71, 889.62, 56.32, '06/03/2021'),
#  ('RPSG Ventures', 431.8, 4.4, 18.2, 54.66, 28.88, 52.84, '06/03/2021'),
#  ('Mahindra Holi.&Resor',
#   261.1,
#   4.38,
#   10.95,
#   664.74,
#   242.87,
#   36.54,
#   '06/03/2021'),
#  ('Kuantum Papers', 69.25, 4.37, 2.9, 200.23, 48.44, 24.19, '06/03/2021'),
#  ('MTAR Technologies',
#   1012.3,
#   4.34,
#   42.15,
#   265.89,
#   103.07,
#   38.76,
#   '06/03/2021'),
#  ('Ahluwalia Contract(I',
#   321.35,
#   4.33,
#   13.35,
#   97.26,
#   46.49,
#   47.8,
#   '06/03/2021'),
#  ('Wockhardt', 647.55, 4.33, 26.9, 1857.64, 553.67, 29.8, '06/03/2021'),
#  ('Godawari Power & Isp',
#   964,
#   4.28,
#   39.6,
#   241.91,
#   108.01,
#   44.65,
#   '06/03/2021'),
#  ('Nagarjuna Fertilizer',
#   9.75,
#   4.28,
#   0.4,
#   1221.92,
#   822.81,
#   67.34,
#   '06/03/2021'),
#  ('Future Lifestyle', 61, 4.27, 2.5, 372.98, 134.46, 36.05, '06/03/2021'),
#  ('Deepak Fert & Petro',
#   298.35,
#   4.26,
#   12.2,
#   589.36,
#   317.49,
#   53.87,
#   '06/03/2021'),
#  ('Kirloskar Ferrous', 242.6, 4.25, 9.9, 171.94, 102.72, 59.74, '06/03/2021'),
#  ('Hathway Cable & Data',
#   25.75,
#   4.25,
#   1.05,
#   10002.94,
#   4115.95,
#   41.15,
#   '06/03/2021'),
#  ('Simplex Infrastruct.',
#   35.65,
#   4.24,
#   1.45,
#   353.79,
#   233.33,
#   65.95,
#   '06/03/2021'),
#  ('Chennai Petrol. Corp',
#   134.4,
#   4.23,
#   5.45,
#   1804.29,
#   657.76,
#   36.46,
#   '06/03/2021'),
#  ('Pricol', 82.9, 4.21, 3.35, 1349.52, 633.34, 46.93, '06/03/2021'),
#  ('Jindal Saw', 112.65, 4.21, 4.55, 9170.22, 2136.25, 23.3, '06/03/2021'),
#  ('IFCI', 12.45, 4.18, 0.5, 5142.3, 2841.45, 55.26, '06/03/2021'),
#  ('Ortin Laboratories', 27.5, 4.17, 1.1, 28.15, 17.32, 61.54, '06/03/2021'),
#  ('Jaypee Infratech', 2.5, 4.17, 0.1, 374.54, 374.54, 100, '06/03/2021'),
#  ('Prajay Engg.Syndicat', 12.5, 4.17, 0.5, 931.35, 466.1, 50.05, '06/03/2021'),
#  ('CCL Products (India)',
#   359.3,
#   4.16,
#   14.35,
#   455.37,
#   152.55,
#   33.5,
#   '06/03/2021'),
#  ('Tera Software', 46.55, 4.14, 1.85, 73.78, 41.01, 55.58, '06/03/2021'),
#  ('Crest Ventures', 103.95, 4.11, 4.1, 96.51, 41.47, 42.97, '06/03/2021'),
#  ('Shree RamaMulti-Tech',
#   16.5,
#   4.1,
#   0.65,
#   205.55,
#   135.57,
#   65.96,
#   '06/03/2021'),
#  ('Vipul', 29.2, 4.1, 1.15, 26.28, 18, 68.5, '06/03/2021'),
#  ('MRPL', 52.25, 4.08, 2.05, 10027.18, 2231.22, 22.25, '06/03/2021'),
#  ('Anik Industries', 17.95, 4.06, 0.7, 183.42, 131.76, 71.84, '06/03/2021'),
#  ('Asahi India Glass', 324.7, 4.05, 12.65, 112.67, 66.16, 58.71, '06/03/2021'),
#  ('Kalyani Steels', 371.05, 4.05, 14.45, 109.61, 43.52, 39.71, '06/03/2021'),
#  ('Paramount Communicat', 11.65, 4.02, 0.45, 743.35, 386.52, 52, '06/03/2021'),
#  ('Reliance Comm', 2.6, 4, 0.1, 13527.24, 7201.79, 53.24, '06/03/2021'),
#  ('JP Power Ventures', 3.9, 4, 0.15, 83207.19, 40036.23, 48.12, '06/03/2021'),
#  ('Emami', 527.75, 3.99, 20.25, 938.21, 522.69, 55.71, '06/03/2021'),
#  ('Guj. Alkalies & Chem',
#   413.1,
#   3.99,
#   15.85,
#   1018.06,
#   331.53,
#   32.56,
#   '06/03/2021'),
#  ('LG Balakrishnan&Bros',
#   326.05,
#   3.99,
#   12.5,
#   156.69,
#   89.19,
#   56.92,
#   '06/03/2021'),
#  ('Delta Corp', 175.65, 3.97, 6.7, 5016.27, 1093.54, 21.8, '06/03/2021'),
#  ('Sunteck Realty', 289.5, 3.95, 11, 988.29, 256.68, 25.97, '06/03/2021'),
#  ('Selan Exploratn Tech',
#   149.45,
#   3.93,
#   5.65,
#   454.91,
#   152.46,
#   33.51,
#   '06/03/2021'),
#  ('Repco Home Finance',
#   369.65,
#   3.92,
#   13.95,
#   475.64,
#   292.53,
#   61.5,
#   '06/03/2021'),
#  ('Adani Transmission',
#   1558.25,
#   3.92,
#   58.8,
#   1602.91,
#   797.97,
#   49.78,
#   '06/03/2021'),
#  ('Jayant Agro-Organics',
#   196.6,
#   3.91,
#   7.4,
#   406.21,
#   164.72,
#   40.55,
#   '06/03/2021'),
#  ('Ganges Securities', 73.1, 3.91, 2.75, 39.27, 26.04, 66.32, '06/03/2021'),
#  ('SpencerS Retail', 75.85, 3.9, 2.85, 502.03, 239.29, 47.66, '06/03/2021'),
#  ('Praj Industries', 339.5, 3.89, 12.7, 2836.09, 1294.77, 45.65, '06/03/2021'),
#  ('Munjal Showa', 153.75, 3.89, 5.75, 97.72, 48.66, 49.79, '06/03/2021'),
#  ('Kitex Garments', 113.75, 3.88, 4.25, 418.27, 124.57, 29.78, '06/03/2021'),
#  ('Max Ventures & Ind', 71.1, 3.87, 2.65, 291.07, 175.41, 60.26, '06/03/2021'),
#  ('JSW Energy', 130.85, 3.85, 4.85, 24131.6, 5329.61, 22.09, '06/03/2021'),
#  ('IDBI', 39.2, 3.84, 1.45, 19277.38, 7250.32, 37.61, '06/03/2021'),
#  ('HG Infra Engineering',
#   399.45,
#   3.82,
#   14.7,
#   251.23,
#   101.5,
#   40.4,
#   '06/03/2021'),
#  ('Kalpataru PowerTrans',
#   430.95,
#   3.82,
#   15.85,
#   465.11,
#   176.56,
#   37.96,
#   '06/03/2021'),
#  ('Omax Autos', 46.45, 3.8, 1.7, 36.88, 19.5, 52.88, '06/03/2021'),
#  ('Star Paper Mills', 145.15, 3.79, 5.3, 1327.15, 450.06, 33.91, '06/03/2021'),
#  ('Power Mech Projects',
#   626.25,
#   3.78,
#   22.8,
#   119.41,
#   95.9,
#   80.31,
#   '06/03/2021'),
#  ('Poddar Hsg.&Devlop.', 187.15, 3.71, 6.7, 31.83, 12, 37.7, '06/03/2021'),
#  ('HFCL', 45.05, 3.68, 1.6, 16519.13, 5170.19, 31.3, '06/03/2021'),
#  ('Steel Strips Wheels', 765, 3.68, 27.15, 48.41, 25.59, 52.86, '06/03/2021'),
#  ('Apollo Tyres', 229.95, 3.67, 8.15, 7324.47, 2191.97, 29.93, '06/03/2021'),
#  ('Sanghi Industries', 48.1, 3.66, 1.7, 1024.55, 526.25, 51.36, '06/03/2021'),
#  ('Future Enter.-B-DVR', 12.75, 3.66, 0.45, 54.38, 25.5, 46.9, '06/03/2021'),
#  ('Elgi Rubber Co.', 35.65, 3.63, 1.25, 55.86, 33.91, 60.71, '06/03/2021'),
#  ('Lemon Tree Hotels',
#   42.85,
#   3.63,
#   1.5,
#   4232.96,
#   1863.02,
#   44.01,
#   '06/03/2021'),
#  ('De Nora India', 349.25, 3.6, 12.15, 24.05, 12.65, 52.61, '06/03/2021'),
#  ('Aditya Birla Capital',
#   122.9,
#   3.58,
#   4.25,
#   3212.57,
#   1228.77,
#   38.25,
#   '06/03/2021'),
#  ('Bhandari Hosiery Exp', 2.9, 3.57, 0.1, 372.87, 224.99, 60.34, '06/03/2021'),
#  ('Ujaas Energy', 2.9, 3.57, 0.1, 2789.36, 2110.59, 75.67, '06/03/2021'),
#  ('RSWM', 249.7, 3.57, 8.6, 133.08, 90.56, 68.05, '06/03/2021'),
#  ('Sadbhav Infra. Proj',
#   21.8,
#   3.56,
#   0.75,
#   245.69,
#   116.43,
#   47.39,
#   '06/03/2021'),
#  ('Praxis Home Retail', 45.2, 3.55, 1.55, 42.19, 27.04, 64.09, '06/03/2021'),
#  ('Premier Polyfilm', 49.7, 3.54, 1.7, 34.56, 22.92, 66.33, '06/03/2021'),
#  ('Fairchem Organics', 932.45, 3.54, 31.85, 25.48, 17.71, 69.48, '06/03/2021'),
#  ('Vodafone Idea', 8.8, 3.53, 0.3, 160917.78, 49165.74, 30.55, '06/03/2021'),
#  ('Donear Inds', 36.7, 3.53, 1.25, 130.88, 52.09, 39.8, '06/03/2021'),
#  ('Deep Energy Res.', 41.15, 3.52, 1.4, 151.91, 60.38, 39.74, '06/03/2021'),
#  ('VA Tech Wabag', 272.7, 3.49, 9.2, 437.29, 190.97, 43.67, '06/03/2021'),
#  ('Bedmutha Industries', 23.75, 3.49, 0.8, 18.22, 13.32, 73.11, '06/03/2021'),
#  ('TV Today Network', 305.8, 3.47, 10.25, 143.38, 88.98, 62.06, '06/03/2021'),
#  ('Linde India', 1625.3, 3.46, 54.35, 115.94, 47.29, 40.78, '06/03/2021'),
#  ('NACL Industries', 53.95, 3.45, 1.8, 210.58, 127.93, 60.75, '06/03/2021'),
#  ('Cords Cable Inds', 54, 3.45, 1.8, 305.01, 134.12, 43.97, '06/03/2021'),
#  ('HLV', 7.55, 3.42, 0.25, 462.99, 353.28, 76.3, '06/03/2021'),
#  ('Future MarketNetwork',
#   15.15,
#   3.41,
#   0.5,
#   156.48,
#   63.19,
#   40.38,
#   '06/03/2021'),
#  ('Housing & Urban Dev.',
#   50,
#   3.41,
#   1.65,
#   5506.22,
#   2188.16,
#   39.74,
#   '06/03/2021'),
#  ('Sumit Woods', 12.15, 3.4, 0.4, 103.44, 72.54, 70.13, '06/03/2021'),
#  ('Olectra Greentech', 176.75, 3.39, 5.8, 352.89, 177.96, 50.43, '06/03/2021'),
#  ('Kalyan Jewell.India',
#   70.25,
#   3.38,
#   2.3,
#   4229.69,
#   2182.86,
#   51.61,
#   '06/03/2021'),
#  ('Assoc Alcohols &Brew',
#   444.5,
#   3.38,
#   14.55,
#   98.85,
#   63.06,
#   63.79,
#   '06/03/2021'),
#  ('Glenmark Pharma', 614.8, 3.38, 20.1, 4039.93, 1162.7, 28.78, '06/03/2021'),
#  ('3I Infotech', 9.2, 3.37, 0.3, 39107.86, 16480.25, 42.14, '06/03/2021'),
#  ('Sree Rayal.Hi-Strent',
#   297.95,
#   3.35,
#   9.65,
#   23.79,
#   14.96,
#   62.88,
#   '06/03/2021'),
#  ('Shemaroo Entertain.',
#   132.8,
#   3.35,
#   4.3,
#   535.75,
#   236.73,
#   44.19,
#   '06/03/2021'),
#  ('Sundaram Multi Pap', 1.55, 3.33, 0.05, 563.95, 382.57, 67.84, '06/03/2021'),
#  ('Madras Fertilizers', 29.45, 3.33, 0.95, 167.48, 77.51, 46.28, '06/03/2021'),
#  ('Tembo Global Inds.', 173.65, 3.33, 5.6, 198.42, 34.94, 17.61, '06/03/2021'),
#  ('Aarti Drugs', 761.1, 3.33, 24.5, 2544.96, 526.17, 20.68, '06/03/2021'),
#  ('Welspun Enterprises',
#   111.85,
#   3.33,
#   3.6,
#   319.64,
#   174.76,
#   54.67,
#   '06/03/2021'),
#  ('Just Dial', 940.35, 3.32, 30.25, 5171.93, 662.22, 12.8, '06/03/2021'),
#  ('Tata Power', 108.1, 3.3, 3.45, 31238.62, 10380.95, 33.23, '06/03/2021'),
#  ('Future Supply Chain', 78.6, 3.29, 2.5, 188.49, 69.84, 37.05, '06/03/2021'),
#  ('KM Sugar Mills', 19.1, 3.24, 0.6, 789.01, 548.06, 69.46, '06/03/2021'),
#  ('EPL', 248.35, 3.22, 7.75, 939.78, 399.92, 42.55, '06/03/2021'),
#  ('Ramco Systems', 550.25, 3.21, 17.1, 154.95, 63.74, 41.14, '06/03/2021'),
#  ('Bharat Gears', 102.05, 3.19, 3.15, 58.03, 33.05, 56.96, '06/03/2021'),
#  ('Man InfraConstruct',
#   51.9,
#   3.18,
#   1.6,
#   2728.24,
#   1035.63,
#   37.96,
#   '06/03/2021'),
#  ('Polyplex Corporation',
#   1142.8,
#   3.17,
#   35.1,
#   186.16,
#   97.79,
#   52.53,
#   '06/03/2021'),
#  ('Shree Pushkar Chem', 194.4, 3.16, 5.95, 107.06, 37.21, 34.76, '06/03/2021'),
#  ('Golden Tobacco', 47.4, 3.16, 1.45, 18.79, 15.3, 81.45, '06/03/2021'),
#  ('Dixon Technologies',
#   4236.85,
#   3.15,
#   129.45,
#   438.23,
#   196.98,
#   44.95,
#   '06/03/2021'),
#  ('Lupin', 1247.25, 3.15, 38.05, 7160.45, 1687.01, 23.56, '06/03/2021'),
#  ('Uttam Galva Steels', 8.2, 3.14, 0.25, 500.96, 265.65, 53.03, '06/03/2021'),
#  ('AJR Infra and Toll', 1.65, 3.12, 0.05, 519.27, 519.27, 100, '06/03/2021'),
#  ('S Chand And Co', 97.65, 3.12, 2.95, 53.93, 36.48, 67.64, '06/03/2021'),
#  ('Energy Development', 10.05, 3.08, 0.3, 43.11, 34.6, 80.26, '06/03/2021'),
#  ('NCC', 80.6, 3.07, 2.4, 4108.67, 1826.59, 44.46, '06/03/2021'),
#  ('Confidence Petroleum',
#   62.5,
#   3.05,
#   1.85,
#   1197.41,
#   512.41,
#   42.79,
#   '06/03/2021'),
#  ('Guj. Inds.  Power', 82.9, 3.05, 2.45, 1462.42, 515.5, 35.25, '06/03/2021'),
#  ('Chembond Chemicals', 201.5, 3.04, 5.95, 48.41, 25.03, 51.7, '06/03/2021'),
#  ('Ruchi Soya Inds', 1084.15, 3.04, 32, 63.02, 35.41, 56.18, '06/03/2021'),
#  ('Orient Bell', 303.25, 3.02, 8.9, 115.08, 57.13, 49.64, '06/03/2021'),
#  ('Cineline India', 42.65, 3.02, 1.25, 175.77, 66.95, 38.09, '06/03/2021'),
#  ('Punjab Chem. & Corp', 1136.3, 3.02, 33.3, 19.38, 11.5, 59.35, '06/03/2021'),
#  ('Albert David', 467.5, 3.02, 13.7, 48.24, 27.04, 56.06, '06/03/2021'),
#  ('Jagran Prakashan', 58.05, 3.02, 1.7, 480.67, 284.24, 59.13, '06/03/2021'),
#  ('Kothari Petrochem', 39.45, 3, 1.15, 155.93, 80.92, 51.89, '06/03/2021'),
#  ('Royal Orchid Hotels', 82.6, 2.99, 2.4, 120.84, 62.05, 51.34, '06/03/2021'),
#  ('Tarmat', 63.7, 2.99, 1.85, 400.1, 160.41, 40.09, '06/03/2021'),
#  ('Kanoria Chem. & Inds',
#   125.75,
#   2.99,
#   3.65,
#   34.24,
#   24.7,
#   72.13,
#   '06/03/2021'),
#  ('Arvind Fashions', 148.2, 2.99, 4.3, 554.91, 304.58, 54.89, '06/03/2021'),
#  ('Canara Bank', 163.8, 2.99, 4.75, 23879.44, 4896.96, 20.51, '06/03/2021'),
#  ('BC Power', 3.45, 2.99, 0.1, 288.88, 218.95, 75.79, '06/03/2021'),
#  ('LCC Infotech', 1.75, 2.94, 0.05, 49.47, 49.47, 100, '06/03/2021'),
#  ('RattanIndia Power', 3.5, 2.94, 0.1, 13151.41, 5910.98, 44.95, '06/03/2021'),
#  ('Vertoz Advertising', 232, 2.93, 6.6, 432.79, 112, 25.88, '06/03/2021'),
#  ('Bandhan Bank', 311.7, 2.92, 8.85, 8317.03, 4637.77, 55.76, '06/03/2021'),
#  ('Hi-Tech Gears', 241.3, 2.9, 6.8, 29.42, 15.2, 51.65, '06/03/2021'),
#  ('Nahar Capital &Finl.',
#   133.35,
#   2.89,
#   3.75,
#   50.23,
#   26.66,
#   53.08,
#   '06/03/2021'),
#  ('Gallantt Metal', 59.1, 2.87, 1.65, 73.27, 30.33, 41.4, '06/03/2021'),
#  ('Dewan Hsg Fin. Corp.',
#   17.95,
#   2.87,
#   0.5,
#   1985.93,
#   1201.01,
#   60.48,
#   '06/03/2021'),
#  ('DCM Financial Serv.', 1.8, 2.86, 0.05, 111.16, 90.91, 81.79, '06/03/2021'),
#  ('Bank Of India', 78.35, 2.82, 2.15, 8624.52, 2116.45, 24.54, '06/03/2021'),
#  ('Tata Motors - DVR',
#   147.85,
#   2.82,
#   4.05,
#   2228.24,
#   1019.94,
#   45.77,
#   '06/03/2021'),
#  ('PNC Infratech', 258.2, 2.81, 7.05, 402.77, 219.67, 54.54, '06/03/2021'),
#  ('Jai Balaji Inds', 47.75, 2.8, 1.3, 46.66, 39.07, 83.74, '06/03/2021'),
#  ('HSIL', 233.35, 2.8, 6.35, 262.22, 103.05, 39.3, '06/03/2021'),
#  ('ISGEC Heavy Engg.', 571.55, 2.79, 15.5, 62.07, 41.48, 66.82, '06/03/2021'),
#  ('Future Consumer', 7.4, 2.78, 0.2, 26039.61, 8887.12, 34.13, '06/03/2021'),
#  ('Time Technoplast', 85.2, 2.77, 2.3, 1284.56, 593.38, 46.19, '06/03/2021'),
#  ('Xchanging Solutions', 72.3, 2.77, 1.95, 411.23, 236.04, 57.4, '06/03/2021'),
#  ('RS Software (India)', 27.95, 2.76, 0.75, 62.99, 46.17, 73.3, '06/03/2021'),
#  ('GATI', 123.15, 2.75, 3.3, 2498.34, 565.74, 22.64, '06/03/2021'),
#  ('Shoppers Stop', 229.8, 2.75, 6.15, 221.83, 110.22, 49.69, '06/03/2021'),
#  ('Route Mobile', 1719.15, 2.75, 46, 1079.92, 172.86, 16.01, '06/03/2021'),
#  ('Newgen Software Tech',
#   414.6,
#   2.74,
#   11.05,
#   122.74,
#   63.6,
#   51.82,
#   '06/03/2021'),
#  ('Indian Metal & Ferro',
#   455.15,
#   2.73,
#   12.1,
#   67.04,
#   38.56,
#   57.51,
#   '06/03/2021'),
#  ('STEL Holdings', 90.5, 2.72, 2.4, 31.14, 15.36, 49.34, '06/03/2021'),
#  ('Balmer Lawrie & Co',
#   137.65,
#   2.72,
#   3.65,
#   523.57,
#   202.76,
#   38.73,
#   '06/03/2021'),
#  ('GM Breweries', 438.65, 2.72, 11.6, 32.36, 20.37, 62.94, '06/03/2021'),
#  ('Oswal Greentech', 24.8, 2.69, 0.65, 494.01, 243.98, 49.39, '06/03/2021'),
#  ('Next Mediaworks', 5.75, 2.68, 0.15, 13.26, 10.73, 80.95, '06/03/2021'),
#  ('Pressman Advertising', 26.85, 2.68, 0.7, 120.5, 52.29, 43.39, '06/03/2021'),
#  ('Zee Media Corpn.', 9.6, 2.67, 0.25, 1548.45, 825.47, 53.31, '06/03/2021'),
#  ('UPL', 837.6, 2.67, 21.8, 7228.8, 1872.34, 25.9, '06/03/2021'),
#  ('Aksharchem (I)', 299.4, 2.66, 7.75, 27.49, 15.74, 57.27, '06/03/2021'),
#  ('GE Power India', 288.05, 2.66, 7.45, 216.77, 109.17, 50.36, '06/03/2021'),
#  ('Damodar Inds.', 34.95, 2.64, 0.9, 27.28, 20.83, 76.35, '06/03/2021'),
#  ('Precision Camshafts',
#   52.55,
#   2.64,
#   1.35,
#   227.66,
#   124.9,
#   54.86,
#   '06/03/2021'),
#  ('Nitin Spinners', 120.95, 2.63, 3.1, 333.4, 199.75, 59.91, '06/03/2021'),
#  ('Hind Rectifiers', 138.75, 2.63, 3.55, 26, 15.89, 61.1, '06/03/2021'),
#  ('Mangalore Chem &Fert',
#   84.2,
#   2.62,
#   2.15,
#   373.91,
#   184.46,
#   49.33,
#   '06/03/2021'),
#  ('Union Bank Of India',
#   35.25,
#   2.62,
#   0.9,
#   26505.58,
#   11663.64,
#   44,
#   '06/03/2021'),
#  ('Madhav Marbles&Gran.', 57, 2.61, 1.45, 38.53, 16.72, 43.4, '06/03/2021'),
#  ('Quick Heal Tech', 228.15, 2.61, 5.8, 614.84, 197.23, 32.08, '06/03/2021'),
#  ('Gland Pharma', 3160.1, 2.59, 79.85, 193.26, 92.3, 47.76, '06/03/2021'),
#  ('Vedanta', 275.2, 2.59, 6.95, 9303.22, 3812.29, 40.98, '06/03/2021'),
#  ('Engineers India', 85.3, 2.59, 2.15, 5396.32, 1578.37, 29.25, '06/03/2021'),
#  ('Ashiana Housing', 138.9, 2.58, 3.5, 80.48, 33.01, 41.02, '06/03/2021'),
#  ('Birla Corporation',
#   1248.3,
#   2.58,
#   31.35,
#   172.34,
#   89.45,
#   51.91,
#   '06/03/2021'),
#  ('Surya Roshni', 477.7, 2.57, 11.95, 72.68, 28.27, 38.9, '06/03/2021'),
#  ('Alps Inds', 2, 2.56, 0.05, 38.44, 32.65, 84.93, '06/03/2021'),
#  ('Lovable Lingerie', 136.45, 2.56, 3.4, 721.7, 175.79, 24.36, '06/03/2021'),
#  ('ICICI Prudential', 566.1, 2.55, 14.1, 2704.31, 798.51, 29.53, '06/03/2021'),
#  ('CRISIL', 2000.15, 2.55, 49.8, 136.1, 120.32, 88.4, '06/03/2021'),
#  ('MEP Infrastructure', 22.1, 2.55, 0.55, 331.5, 189.51, 57.17, '06/03/2021'),
#  ('GIC Housing Fin', 139.25, 2.54, 3.45, 1585.44, 507.7, 32.02, '06/03/2021'),
#  ('Brigade Enterprises',
#   266.55,
#   2.52,
#   6.55,
#   194.3,
#   97.61,
#   50.24,
#   '06/03/2021'),
#  ('Linc Pen & Plastics', 166.95, 2.52, 4.1, 24.05, 19.14, 79.58, '06/03/2021'),
#  ('Ind-Swift Lab.', 85.55, 2.52, 2.1, 137.19, 64.52, 47.03, '06/03/2021'),
#  ('Trigyn Technologies',
#   101.9,
#   2.52,
#   2.5,
#   269.08,
#   103.08,
#   38.31,
#   '06/03/2021'),
#  ('Gulf Oil Lubricant', 701.45, 2.5, 17.1, 117.67, 60.44, 51.36, '06/03/2021'),
#  ('IDFC', 57.5, 2.5, 1.4, 5928.26, 3476.85, 58.65, '06/03/2021'),
#  ('Balkrishna Inds.', 2229.4, 2.49, 54.1, 447.42, 156.51, 34.98, '06/03/2021'),
#  ('Piramal Enterprises',
#   1841.3,
#   2.47,
#   44.35,
#   928.45,
#   239.75,
#   25.82,
#   '06/03/2021'),
#  ('Coffee Day Enter.', 35.3, 2.47, 0.85, 1907.16, 984.71, 51.63, '06/03/2021'),
#  ('Maan Aluminium', 207.35, 2.45, 4.95, 58.58, 35.08, 59.88, '06/03/2021'),
#  ('SMC Global Sec.', 71.4, 2.44, 1.7, 470.9, 328.83, 69.83, '06/03/2021'),
#  ('Narayana Hrudayalay',
#   504.9,
#   2.43,
#   12,
#   8131.15,
#   974.98,
#   11.99,
#   '06/03/2021'),
#  ('HPCL', 288.4, 2.43, 6.85, 10905.11, 4545.79, 41.68, '06/03/2021'),
#  ('Datamatic Global Ser',
#   139.5,
#   2.42,
#   3.3,
#   220.87,
#   105.41,
#   47.72,
#   '06/03/2021'),
#  ('Oswal Agro Mills', 12.75, 2.41, 0.3, 280.41, 160.86, 57.36, '06/03/2021'),
#  ('TD Power Systems', 195.5, 2.41, 4.6, 21.87, 15.78, 72.13, '06/03/2021'),
#  ('Sun Pharma Adv. Res',
#   225.35,
#   2.41,
#   5.3,
#   1472.39,
#   355.93,
#   24.17,
#   '06/03/2021'),
#  ('Jindal Stainless', 93.65, 2.41, 2.2, 1083.72, 666.72, 61.52, '06/03/2021'),
#  ('Max India', 70.6, 2.39, 1.65, 329.22, 159.44, 48.43, '06/03/2021'),
#  ('RPP Infra Projects', 66.4, 2.39, 1.55, 251.56, 110.36, 43.87, '06/03/2021'),
#  ('Finolex Inds', 171.75, 2.38, 4, 485.8, 274.32, 56.47, '06/03/2021'),
#  ('Suven Pharma', 516.35, 2.37, 11.95, 374.6, 247.8, 66.15, '06/03/2021'),
#  ('Arvind', 79.95, 2.37, 1.85, 1284.97, 873.77, 68, '06/03/2021'),
#  ('Indiabulls Housing',
#   226.95,
#   2.37,
#   5.25,
#   11855.9,
#   3017.44,
#   25.45,
#   '06/03/2021'),
#  ('INEOS Styrolution', 1360.6, 2.37, 31.45, 60.27, 31.13, 51.66, '06/03/2021'),
#  ('Incredible Indu', 28.15, 2.36, 0.65, 73.58, 35.33, 48.01, '06/03/2021'),
#  ('India Power Corpn.', 13, 2.36, 0.3, 29.15, 23.32, 80, '06/03/2021'),
#  ('Lasa Supergenerics',
#   75.95,
#   2.36,
#   1.75,
#   614.18,
#   143.68,
#   23.39,
#   '06/03/2021'),
#  ('Apar Inds', 536.2, 2.34, 12.25, 91.67, 38.41, 41.9, '06/03/2021'),
#  ('SPL Industries', 43.8, 2.34, 1, 53.93, 26.29, 48.74, '06/03/2021'),
#  ('Sonata Software', 675.8, 2.33, 15.4, 154.44, 75.67, 48.99, '06/03/2021'),
#  ('Bank Of Baroda', 81.2, 2.33, 1.85, 51078.16, 10804.21, 21.15, '06/03/2021'),
#  ('Cybertech Sys. &Soft',
#   145.2,
#   2.33,
#   3.3,
#   214.04,
#   86.51,
#   40.42,
#   '06/03/2021'),
#  ('Prime Securities', 52.85, 2.32, 1.2, 57.01, 38.9, 68.24, '06/03/2021'),
#  ('Bharat Electronics',
#   150.35,
#   2.31,
#   3.4,
#   8247.58,
#   2933.96,
#   35.57,
#   '06/03/2021'),
#  ('Welspun Corp', 150.35, 2.31, 3.4, 2185.63, 1072.67, 49.08, '06/03/2021'),
#  ('Agri-Tech (India)', 44.3, 2.31, 1, 13.79, 10.76, 78, '06/03/2021'),
#  ('Bombay Rayon Fashion',
#   6.65,
#   2.31,
#   0.15,
#   1288.61,
#   974.59,
#   75.63,
#   '06/03/2021'),
#  ('Dynemic Products', 522.85, 2.3, 11.75, 70.26, 38.47, 54.76, '06/03/2021'),
#  ('Aptech', 210.9, 2.28, 4.7, 298.78, 111.45, 37.3, '06/03/2021'),
#  ('Banswara Syntex', 150.55, 2.28, 3.35, 172.28, 85.29, 49.51, '06/03/2021'),
#  ('20 Microns', 60.7, 2.27, 1.35, 374.55, 168.21, 44.91, '06/03/2021'),
#  ('Religare Enterprises',
#   115.05,
#   2.27,
#   2.55,
#   2338.02,
#   1115.87,
#   47.73,
#   '06/03/2021'),
#  ('Adani Green Energy',
#   1299.8,
#   2.26,
#   28.75,
#   1381.9,
#   683.29,
#   49.45,
#   '06/03/2021'),
#  ('Pudumjee Paper', 29.4, 2.26, 0.65, 485.11, 221.21, 45.6, '06/03/2021'),
#  ('Info Edge', 4527.6, 2.25, 99.8, 569.08, 265.67, 46.68, '06/03/2021'),
#  ('Usha Martin', 49.95, 2.25, 1.1, 1624.26, 860.11, 52.95, '06/03/2021'),
#  ('Orient Cement', 136.85, 2.24, 3, 1394.79, 893.77, 64.08, '06/03/2021'),
#  ('Privi Speciality Che',
#   1068.95,
#   2.23,
#   23.35,
#   15.42,
#   11.26,
#   72.98,
#   '06/03/2021'),
#  ('Ador Welding', 489.2, 2.23, 10.65, 181.15, 74, 40.85, '06/03/2021'),
#  ('Thomas Cook (India)',
#   62.6,
#   2.2,
#   1.35,
#   1743.46,
#   984.13,
#   56.45,
#   '06/03/2021'),
#  ('Muthoot Capital Serv',
#   411.65,
#   2.2,
#   8.85,
#   100.98,
#   31.15,
#   30.85,
#   '06/03/2021'),
#  ('JB Chem & Pharma', 1509.05, 2.19, 32.4, 203.9, 78.05, 38.28, '06/03/2021'),
#  ('Anjani Portland Cem.',
#   310.05,
#   2.19,
#   6.65,
#   107.8,
#   57.66,
#   53.49,
#   '06/03/2021'),
#  ('West Coast Paper', 233.35, 2.19, 5, 772.22, 365.58, 47.34, '06/03/2021'),
#  ('Nucleus Software Exp',
#   609.4,
#   2.19,
#   13.05,
#   90.27,
#   48.9,
#   54.17,
#   '06/03/2021'),
#  ('JK Tyres & Inds.', 131, 2.18, 2.8, 1485.54, 894.1, 60.19, '06/03/2021'),
#  ('PI Industries', 2670.5, 2.18, 56.9, 461.97, 273.42, 59.19, '06/03/2021'),
#  ('DCM', 35.2, 2.18, 0.75, 409.38, 190.05, 46.42, '06/03/2021'),
#  ('Godrej Properties',
#   1390.65,
#   2.17,
#   29.55,
#   808.85,
#   189.21,
#   23.39,
#   '06/03/2021'),
#  ('DCM Shriram', 706.5, 2.17, 15, 201.76, 60.6, 30.04, '06/03/2021'),
#  ('Federal Bank', 87.6, 2.16, 1.85, 15917.55, 4293.34, 26.97, '06/03/2021'),
#  ('Andhra Sugars', 418.2, 2.15, 8.8, 67.08, 34.97, 52.13, '06/03/2021'),
#  ('MTNL', 21.4, 2.15, 0.45, 4423.56, 1773.75, 40.1, '06/03/2021'),
#  ('Marico', 491, 2.14, 10.3, 3186.17, 1361.53, 42.73, '06/03/2021'),
#  ('Chola Invest & Fin.',
#   557.3,
#   2.14,
#   11.65,
#   3923.86,
#   1444.51,
#   36.81,
#   '06/03/2021'),
#  ('Hercules Hoists', 136.4, 2.13, 2.85, 152.4, 63.18, 41.46, '06/03/2021'),
#  ('Ambuja Cement', 331.1, 2.13, 6.9, 5346.77, 1649.15, 30.84, '06/03/2021'),
#  ('Kabra Extrus.technik', 193.45, 2.11, 4, 282.86, 87.39, 30.9, '06/03/2021'),
#  ('SH Kelkar & Co', 157.6, 2.11, 3.25, 377.55, 184.38, 48.84, '06/03/2021'),
#  ('Tata Steel', 1124.05, 2.1, 23.15, 12862.59, 4476.08, 34.8, '06/03/2021'),
#  ('GSS Infotech', 65.55, 2.1, 1.35, 83.15, 44.23, 53.2, '06/03/2021'),
#  ('Phoenix Mills', 807.1, 2.1, 16.6, 361.51, 146.54, 40.54, '06/03/2021'),
#  ('Oriental Hotels', 38.9, 2.1, 0.8, 241.32, 153.42, 63.58, '06/03/2021'),
#  ('AU Small Fin. Bank',
#   1009.8,
#   2.09,
#   20.7,
#   607.38,
#   226.35,
#   37.27,
#   '06/03/2021'),
#  ('Voltas', 1034.4, 2.09, 21.2, 1335.35, 388.11, 29.06, '06/03/2021'),
#  ('Asian Hotels (North)', 78.35, 2.08, 1.6, 47.87, 24.4, 50.97, '06/03/2021'),
#  ('L&T Finance Holdings',
#   93.7,
#   2.07,
#   1.9,
#   11946.98,
#   4679.06,
#   39.17,
#   '06/03/2021'),
#  ('Power Finance Corp',
#   121.6,
#   2.06,
#   2.45,
#   3923.88,
#   1588.62,
#   40.49,
#   '06/03/2021'),
#  ('VRL Logistics', 256, 2.05, 5.15, 219.24, 72.71, 33.16, '06/03/2021'),
#  ('Oriental Aromatics', 815.55, 2.05, 16.4, 31.65, 12.95, 40.91, '06/03/2021'),
#  ('Atlanta', 10.1, 2.02, 0.2, 40.65, 35.2, 86.59, '06/03/2021'),
#  ('Ashok Leyland', 124.1, 2.01, 2.45, 7679.49, 1962.38, 25.55, '06/03/2021'),
#  ('Srikalahasthi Pipes', 190.4, 2.01, 3.75, 121.9, 58.72, 48.17, '06/03/2021'),
#  ('Thirumalai Chemicals',
#   137.1,
#   2.01,
#   2.7,
#   1567.86,
#   543.2,
#   34.65,
#   '06/03/2021'),
#  ('Seshasayee Paper', 173.55, 2, 3.4, 74.88, 35.68, 47.65, '06/03/2021'),
#  ('South Indian Bank',
#   10.25,
#   1.99,
#   0.2,
#   31015.51,
#   8765.23,
#   28.26,
#   '06/03/2021'),
#  ('Tanla Platforms', 889.45, 1.98, 17.25, 538.59, 256.29, 47.59, '06/03/2021'),
#  ('JHS Svendgaard', 20.65, 1.98, 0.4, 290, 159.53, 55.01, '06/03/2021'),
#  ('Centrun Capital', 36.2, 1.97, 0.7, 798.58, 457.38, 57.27, '06/03/2021'),
#  ('REC', 148.3, 1.96, 2.85, 3419.56, 1882.19, 55.04, '06/03/2021'),
#  ('Kanpur Plastipack', 240.8, 1.95, 4.6, 32.38, 16.93, 52.3, '06/03/2021'),
#  ('The Ramco Cements', 968.8, 1.95, 18.5, 433.86, 149.84, 34.54, '06/03/2021'),
#  ('GMR Infrastructure',
#   26.2,
#   1.95,
#   0.5,
#   16363.45,
#   4024.36,
#   24.59,
#   '06/03/2021'),
#  ('LT Foods', 76.15, 1.94, 1.45, 3135.6, 914.08, 29.15, '06/03/2021'),
#  ('Venkys India', 2650.45, 1.94, 50.35, 708.2, 126.37, 17.84, '06/03/2021'),
#  ('DCM Nouvelle', 129.05, 1.94, 2.45, 118.14, 72.3, 61.2, '06/03/2021'),
#  ('Manappuram Finance',
#   163.8,
#   1.93,
#   3.1,
#   9153.41,
#   2487.81,
#   27.18,
#   '06/03/2021'),
#  ('Hindustan Media Vent', 87.4, 1.92, 1.65, 58.27, 29.82, 51.17, '06/03/2021'),
#  ('HBL Power Sys', 45.15, 1.92, 0.85, 1478.25, 571.68, 38.67, '06/03/2021'),
#  ('Glaxosmithkline Phar',
#   1524.35,
#   1.91,
#   28.6,
#   39.27,
#   19.62,
#   49.96,
#   '06/03/2021'),
#  ('Mcleod Russel', 34.65, 1.91, 0.65, 2353.65, 1370.13, 58.21, '06/03/2021'),
#  ('Navkar Corporation', 40.1, 1.91, 0.75, 947.32, 455.8, 48.11, '06/03/2021'),
#  ('Cyber Media (I)', 10.75, 1.9, 0.2, 17.53, 16.89, 96.34, '06/03/2021'),
#  ('UCO Bank', 13.45, 1.89, 0.25, 15857.08, 3838.89, 24.21, '06/03/2021'),
#  ('Autoline Inds', 38, 1.88, 0.7, 40.49, 30, 74.1, '06/03/2021'),
#  ('SBI Life Insuran', 984.4, 1.87, 18.1, 2488.6, 1124.36, 45.18, '06/03/2021'),
#  ('Orient Refractories',
#   312.75,
#   1.87,
#   5.75,
#   147.61,
#   65.26,
#   44.21,
#   '06/03/2021'),
#  ('Radico Khaitan', 628.4, 1.87, 11.55, 737.82, 178.48, 24.19, '06/03/2021'),
#  ('Zodiac Clothing Co', 103.95, 1.86, 1.9, 26.76, 14.91, 55.7, '06/03/2021'),
#  ('Cummins India', 794.35, 1.86, 14.5, 688.18, 173.99, 25.28, '06/03/2021'),
#  ('Magadh Sugar & Energ',
#   216.9,
#   1.85,
#   3.95,
#   182.13,
#   93.42,
#   51.3,
#   '06/03/2021'),
#  ('Prakash Pipes', 154.15, 1.85, 2.8, 194.65, 81.85, 42.05, '06/03/2021'),
#  ('Jain Irrigation(DVR)',
#   13.8,
#   1.85,
#   0.25,
#   146.49,
#   106.85,
#   72.94,
#   '06/03/2021'),
#  ('JBM Auto', 425.55, 1.84, 7.7, 28.08, 12.47, 44.43, '06/03/2021'),
#  ('DCB Bank', 103.4, 1.82, 1.85, 1645.13, 899.28, 54.66, '06/03/2021'),
#  ('Vimta Labs', 222.35, 1.81, 3.95, 94.68, 38.71, 40.89, '06/03/2021'),
#  ('KPIT Technologies', 239.5, 1.81, 4.25, 313.52, 161.09, 51.38, '06/03/2021'),
#  ('Mah & Mah Finl. Serv',
#   162.85,
#   1.78,
#   2.85,
#   5692.02,
#   1885.93,
#   33.13,
#   '06/03/2021'),
#  ('Indusind Bank', 1028, 1.78, 17.95, 4177.38, 1661.57, 39.78, '06/03/2021'),
#  ('Stove Kraft', 596.55, 1.77, 10.4, 201.38, 85.37, 42.39, '06/03/2021'),
#  ('Ajmera Realty&Infra',
#   149.15,
#   1.77,
#   2.6,
#   262.75,
#   106.96,
#   40.71,
#   '06/03/2021'),
#  ('Munjal Auto Inds', 63.15, 1.77, 1.1, 244.85, 105.76, 43.19, '06/03/2021'),
#  ('Wonderla Holidays', 210.2, 1.77, 3.65, 71.06, 45.37, 63.85, '06/03/2021'),
#  ('New India Assurance',
#   165.1,
#   1.76,
#   2.85,
#   860.54,
#   316.16,
#   36.74,
#   '06/03/2021'),
#  ('Goldiam Internatl.', 417.25, 1.76, 7.2, 59.08, 30.72, 52, '06/03/2021'),
#  ('Bhagyanagar Propert', 29, 1.75, 0.5, 13.27, 10.4, 78.41, '06/03/2021'),
#  ('Astron Paper & Board', 46.4, 1.75, 0.8, 146.53, 71.89, 49.07, '06/03/2021'),
#  ('Birlasoft', 316.7, 1.75, 5.45, 1622.92, 684.89, 42.2, '06/03/2021'),
#  ('Ausom Enterprises', 66.95, 1.75, 1.15, 17.81, 12.73, 71.49, '06/03/2021'),
#  ('5Paisa Capital', 352.6, 1.75, 6.05, 83.66, 43.09, 51.51, '06/03/2021'),
#  ('Alkem Laboratories',
#   3155.8,
#   1.74,
#   54.05,
#   568.06,
#   149.75,
#   26.36,
#   '06/03/2021'),
#  ('MOIL', 181.45, 1.74, 3.1, 749.85, 261.95, 34.93, '06/03/2021'),
#  ('SMS Pharmaceuticals', 164.1, 1.74, 2.8, 158.23, 52.35, 33.08, '06/03/2021'),
#  ('Rollatainers', 2.95, 1.72, 0.05, 51.67, 37.28, 72.15, '06/03/2021'),
#  ('Apex Frozen Foods',
#   281.6,
#   1.72,
#   4.75,
#   1134.66,
#   359.03,
#   31.64,
#   '06/03/2021'),
#  ('Cholamandalam Fin.',
#   656.45,
#   1.71,
#   11.05,
#   347.25,
#   143.1,
#   41.21,
#   '06/03/2021'),
#  ('Amber Enterprises',
#   2760.2,
#   1.71,
#   46.4,
#   138.05,
#   102.04,
#   73.92,
#   '06/03/2021'),
#  ('Noida Toll Bridge', 5.95, 1.71, 0.1, 136.66, 102.87, 75.28, '06/03/2021'),
#  ('J Kumar Infraproject',
#   184.55,
#   1.71,
#   3.1,
#   99.82,
#   45.15,
#   45.23,
#   '06/03/2021'),
#  ('Prakash Inds.', 80.45, 1.71, 1.35, 1505.09, 801.47, 53.25, '06/03/2021'),
#  ('VLS Finance', 122.3, 1.7, 2.05, 118.03, 65.45, 55.45, '06/03/2021'),
#  ('TV18 Broadcast', 41.9, 1.7, 0.7, 9092.95, 2778.78, 30.56, '06/03/2021'),
#  ('NBCC (India)', 47.9, 1.7, 0.8, 8125.34, 2825.77, 34.78, '06/03/2021'),
#  ('Vikas Lifecare', 3, 1.69, 0.05, 3804.82, 2592.84, 68.15, '06/03/2021'),
#  ('Bharat Road Network', 30.05, 1.69, 0.5, 50.95, 33.56, 65.87, '06/03/2021'),
#  ('BF Utilities', 312.55, 1.69, 5.2, 457.81, 142.34, 31.09, '06/03/2021'),
#  ('Valiant Organics', 1554.95, 1.69, 25.8, 35.36, 19.75, 55.84, '06/03/2021'),
#  ('Nahar Poly Films', 151.1, 1.68, 2.5, 96.94, 37.15, 38.32, '06/03/2021'),
#  ('HDFC Asset Mngt. Co',
#   3014.6,
#   1.68,
#   49.7,
#   369.06,
#   143.56,
#   38.9,
#   '06/03/2021'),
#  ('Havells India', 1046.7, 1.68, 17.25, 1365.92, 709.11, 51.91, '06/03/2021'),
#  ('Nectar Lifesciences',
#   30.4,
#   1.67,
#   0.5,
#   1030.36,
#   480.33,
#   46.62,
#   '06/03/2021'),
#  ('NESCO', 556.55, 1.67, 9.15, 58.79, 30.8, 52.39, '06/03/2021'),
#  ('Kaya', 301.2, 1.67, 4.95, 33.62, 18.25, 54.28, '06/03/2021'),
#  ('Adani Ports &Special',
#   811.5,
#   1.67,
#   13.3,
#   27748.93,
#   3597.69,
#   12.97,
#   '06/03/2021'),
#  ('JSW Steel', 706.05, 1.66, 11.55, 9653.11, 2859.09, 29.62, '06/03/2021'),
#  ('Neyveli Lignite', 61.15, 1.66, 1, 4974.2, 1751.28, 35.21, '06/03/2021'),
#  ('IMP Powers', 15.3, 1.66, 0.25, 12.83, 11.04, 86.07, '06/03/2021'),
#  ('Exide Inds', 193.15, 1.66, 3.15, 1926.69, 1056.54, 54.84, '06/03/2021'),
#  ('Rajshree Sugars&Chem', 21.5, 1.65, 0.35, 33.59, 25.53, 76.02, '06/03/2021'),
#  ('SJVN', 27.75, 1.65, 0.45, 2350.13, 916.82, 39.01, '06/03/2021'),
#  ('TTK Prestige', 8920, 1.65, 144.4, 48.88, 10.96, 22.43, '06/03/2021'),
#  ('Khaitan Chem & Fert.', 34, 1.64, 0.55, 230.53, 127.04, 55.11, '06/03/2021'),
#  ('Dilip Buildcon', 550.4, 1.64, 8.9, 402.04, 178.16, 44.32, '06/03/2021'),
#  ('Oricon Enterprises', 24.75, 1.64, 0.4, 387.8, 231.32, 59.65, '06/03/2021'),
#  ('Man Industries', 92.95, 1.64, 1.5, 341.47, 173.52, 50.82, '06/03/2021'),
#  ('Industl. Invst.Trust',
#   77.95,
#   1.63,
#   1.25,
#   39.23,
#   23.74,
#   60.51,
#   '06/03/2021'),
#  ('Geojit Finl. Service',
#   65.5,
#   1.63,
#   1.05,
#   354.64,
#   184.52,
#   52.03,
#   '06/03/2021'),
#  ('Guj. Ambuja Exports',
#   165.45,
#   1.63,
#   2.65,
#   309.62,
#   194.36,
#   62.77,
#   '06/03/2021'),
#  ('Craftsman Automation',
#   1777.65,
#   1.63,
#   28.45,
#   114.03,
#   38.29,
#   33.58,
#   '06/03/2021'),
#  ('Bodal Chemicals', 103.25, 1.62, 1.65, 603.93, 261.43, 43.29, '06/03/2021'),
#  ('Tourism Finance Corp',
#   65.9,
#   1.62,
#   1.05,
#   242.15,
#   130.86,
#   54.04,
#   '06/03/2021'),
#  ('Suprajit Engineering',
#   273.05,
#   1.62,
#   4.35,
#   180.65,
#   92.19,
#   51.03,
#   '06/03/2021'),
#  ('BHEL', 72.25, 1.62, 1.15, 48257.12, 8555.63, 17.73, '06/03/2021'),
#  ('Intellect Design', 758.15, 1.61, 12, 266.62, 124.75, 46.79, '06/03/2021'),
#  ('BASF India', 2499, 1.6, 39.4, 95.74, 46.16, 48.22, '06/03/2021'),
#  ('HDFC Life Insurance',
#   675.9,
#   1.6,
#   10.65,
#   4979.82,
#   3223.69,
#   64.74,
#   '06/03/2021'),
#  ('South West Pinnacle', 38.1, 1.6, 0.6, 30.83, 25.16, 81.61, '06/03/2021'),
#  ('Minda Corporation', 127.7, 1.59, 2, 1836.42, 645.71, 35.16, '06/03/2021'),
#  ('NOCIL', 205.55, 1.58, 3.2, 901.14, 338.86, 37.6, '06/03/2021'),
#  ('GNFC', 374.85, 1.57, 5.8, 455.69, 247.66, 54.35, '06/03/2021'),
#  ('Genus Paper & Boards',
#   9.75,
#   1.56,
#   0.15,
#   296.81,
#   183.31,
#   61.76,
#   '06/03/2021'),
# ...
#  ('KCP Sugar&Inds. Corp',
#   20.8,
#   0.73,
#   0.15,
#   345.6,
#   159.63,
#   46.19,
#   '06/03/2021'),
#  ('Alembic Pharma', 951.25, 0.73, 6.85, 216.94, 129.21, 59.56, '06/03/2021'),
#  ('Torrent Power', 435.6, 0.72, 3.1, 750.04, 191.28, 25.5, '06/03/2021'),
#  ('TN Newsprints', 147.7, 0.72, 1.05, 362.87, 146.04, 40.24, '06/03/2021'),
#  ('Yaarii Digital Integ',
#   112.7,
#   0.71,
#   0.8,
#   215.49,
#   113.31,
#   52.58,
#   '06/03/2021'),
#  ('Zensar Technologies', 283.85, 0.71, 2, 127.45, 68, 53.36, '06/03/2021'),
#  ('Avenue Supermarts', 3066.2, 0.7, 21.4, 236.97, 113.14, 47.74, '06/03/2021'),
#  ('Navneet Education', 86, 0.7, 0.6, 220.1, 166.07, 75.45, '06/03/2021'),
#  ('SREI Infra Fin', 7.2, 0.7, 0.05, 1291.95, 557.17, 43.13, '06/03/2021'),
#  ('GMDC', 72.35, 0.7, 0.5, 1334.33, 439.86, 32.97, '06/03/2021'),
#  ('National Aluminium',
#   72.85,
#   0.69,
#   0.5,
#   20263.59,
#   5534.04,
#   27.31,
#   '06/03/2021'),
#  ('Andhra Paper', 233.2, 0.69, 1.6, 49.82, 22.79, 45.74, '06/03/2021'),
#  ('Star Cement', 109.8, 0.69, 0.75, 305.92, 96.01, 31.38, '06/03/2021'),
#  ('Apollo Micro Systems',
#   110.35,
#   0.68,
#   0.75,
#   84.23,
#   49.78,
#   59.1,
#   '06/03/2021'),
#  ('Prince Pipes & Fitti',
#   716.15,
#   0.68,
#   4.85,
#   424.98,
#   213.89,
#   50.33,
#   '06/03/2021'),
#  ('Ipca Laboratories',
#   2079.7,
#   0.68,
#   14.05,
#   343.95,
#   155.68,
#   45.26,
#   '06/03/2021'),
#  ('Spandana Sphoorty', 570.8, 0.68, 3.85, 68.55, 47.57, 69.4, '06/03/2021'),
#  ('RCF', 81.8, 0.68, 0.55, 1761.24, 591.77, 33.6, '06/03/2021'),
#  ('GE T&D India', 134.9, 0.67, 0.9, 171.29, 60.25, 35.17, '06/03/2021'),
#  ('Som Distilleries', 45.05, 0.67, 0.3, 493.5, 307.51, 62.31, '06/03/2021'),
#  ('Dhanuka Agritech', 937.3, 0.67, 6.2, 158.26, 48.67, 30.75, '06/03/2021'),
#  ('Lincoln Pharma', 295.55, 0.66, 1.95, 120.88, 49.42, 40.88, '06/03/2021'),
#  ('Trejhara Solutions', 37.9, 0.66, 0.25, 33.59, 17.1, 50.9, '06/03/2021'),
#  ('Rossell India', 122.85, 0.66, 0.8, 109.98, 77.8, 70.74, '06/03/2021'),
#  ('Crompt.Greaves Cons.',
#   400.9,
#   0.65,
#   2.6,
#   719.96,
#   532.97,
#   74.03,
#   '06/03/2021'),
#  ('Bajaj Electricals', 1066.55, 0.65, 6.85, 71.49, 38.35, 53.64, '06/03/2021'),
#  ('TVS Motor', 616.65, 0.64, 3.95, 1687.31, 528.68, 31.33, '06/03/2021'),
#  ('DB Corp', 94.35, 0.64, 0.6, 270, 151.75, 56.21, '06/03/2021'),
#  ('Vardhman Textiles', 1278.5, 0.64, 8.1, 62.58, 32.29, 51.59, '06/03/2021'),
#  ('Orient Electric', 302.45, 0.63, 1.9, 352.8, 200.5, 56.83, '06/03/2021'),
#  ('Jay Shree Tea', 96.3, 0.63, 0.6, 442.86, 102.97, 23.25, '06/03/2021'),
#  ('Central Dep. Service',
#   971.35,
#   0.62,
#   6,
#   542.39,
#   228.81,
#   42.19,
#   '06/03/2021'),
#  ('Neogen Chemicals', 899.6, 0.62, 5.5, 107.93, 86.11, 79.78, '06/03/2021'),
#  ('Aditya Birla Fashion',
#   198.75,
#   0.61,
#   1.2,
#   4130.5,
#   1806.41,
#   43.73,
#   '06/03/2021'),
#  ('United Spirits', 616.1, 0.6, 3.7, 1091.08, 532.07, 48.77, '06/03/2021'),
#  ('Mishra Dhatu Nigam', 192.3, 0.6, 1.15, 205.19, 104.05, 50.71, '06/03/2021'),
#  ('Tribhovandas Bhimji', 75.65, 0.6, 0.45, 129.21, 52.78, 40.85, '06/03/2021'),
#  ('VIP Clothing', 16.9, 0.6, 0.1, 411.37, 296.28, 72.02, '06/03/2021'),
#  ('Biocon', 388.1, 0.58, 2.25, 2300.52, 932.21, 40.52, '06/03/2021'),
#  ('Equitas Small Fin.',
#   60.45,
#   0.58,
#   0.35,
#   442.87,
#   208.98,
#   47.19,
#   '06/03/2021'),
#  ('Jindal Steel & Power',
#   398.8,
#   0.58,
#   2.3,
#   6350.32,
#   1104.91,
#   17.4,
#   '06/03/2021'),
#  ('Himadri Speciality',
#   52.1,
#   0.58,
#   0.3,
#   6263.69,
#   1940.18,
#   30.98,
#   '06/03/2021'),
#  ('Sanco Industries', 8.7, 0.58, 0.05, 33.68, 29.05, 86.25, '06/03/2021'),
#  ('SAIL', 121.9, 0.58, 0.7, 37163.46, 10368.78, 27.9, '06/03/2021'),
#  ('Jyothy Labs', 156.9, 0.58, 0.9, 994.41, 508.74, 51.16, '06/03/2021'),
#  ('Parag Milk Foods', 140.4, 0.57, 0.8, 559.27, 227.25, 40.63, '06/03/2021'),
#  ('Aro Granite', 54.35, 0.56, 0.3, 84.22, 48.1, 57.12, '06/03/2021'),
#  ('PC Jeweller', 27.2, 0.55, 0.15, 1444.46, 649.35, 44.95, '06/03/2021'),
#  ('Igarashi Motors', 421.6, 0.55, 2.3, 136.17, 58.87, 43.23, '06/03/2021'),
#  ('Syngene Internation.',
#   587.35,
#   0.55,
#   3.2,
#   145.2,
#   66.78,
#   45.99,
#   '06/03/2021'),
#  ('Uflex', 447.65, 0.54, 2.4, 89.91, 27.34, 30.41, '06/03/2021'),
#  ('PG Electroplast', 413.55, 0.53, 2.2, 34.24, 24.98, 72.96, '06/03/2021'),
#  ('Aakash Exploration', 162.7, 0.53, 0.85, 67.6, 28.67, 42.41, '06/03/2021'),
#  ('Rupa & Co', 478.65, 0.53, 2.5, 3154.08, 1186.3, 37.61, '06/03/2021'),
#  ('Garden Reach Ship', 182.85, 0.52, 0.95, 178.65, 88.02, 49.27, '06/03/2021'),
#  ('Hindustan Aeron', 1037.05, 0.52, 5.35, 148.89, 50.78, 34.1, '06/03/2021'),
#  ('TT', 69.1, 0.51, 0.35, 119.08, 48.15, 40.44, '06/03/2021'),
#  ('BSL', 49.75, 0.51, 0.25, 47.46, 19.72, 41.56, '06/03/2021'),
#  ('Paisalo Digital', 622.45, 0.5, 3.1, 27.07, 13.58, 50.18, '06/03/2021'),
#  ('Oracle Finl. Service',
#   3528.3,
#   0.5,
#   17.5,
#   52.66,
#   27.82,
#   52.83,
#   '06/03/2021'),
#  ('Mrs.Bectors Foods', 414.1, 0.5, 2.05, 292.87, 119.97, 40.96, '06/03/2021'),
#  ('RPG Life Sciences', 444.9, 0.5, 2.2, 23.35, 11.26, 48.24, '06/03/2021'),
#  ('Panama Petrochem', 212.65, 0.5, 1.05, 222.63, 116.74, 52.44, '06/03/2021'),
#  ('Kesoram Industries', 81.05, 0.5, 0.4, 2011.2, 643.15, 31.98, '06/03/2021'),
#  ('Alok Inds', 20.5, 0.49, 0.1, 6888.36, 2935.12, 42.61, '06/03/2021'),
#  ('Superhouse', 144.6, 0.49, 0.7, 30.34, 17.9, 58.99, '06/03/2021'),
#  ('Bliss GVS Pharma', 107.1, 0.47, 0.5, 188.01, 88.77, 47.22, '06/03/2021'),
#  ('Ucal Fuel Sys.', 163.45, 0.46, 0.75, 39.97, 23.66, 59.21, '06/03/2021'),
#  ('JK Lakshmi Cement', 542.4, 0.45, 2.45, 395.45, 192.99, 48.8, '06/03/2021'),
#  ('Hind National Glass', 33.4, 0.45, 0.15, 100.73, 87.41, 86.77, '06/03/2021'),
#  ('Cyient', 814.3, 0.45, 3.65, 191.37, 127.88, 66.82, '06/03/2021'),
#  ('Eicher Motors', 2677.75, 0.45, 11.95, 659.43, 243.44, 36.92, '06/03/2021'),
#  ('Shiva Texyarn', 201.9, 0.45, 0.9, 44.29, 27.55, 62.2, '06/03/2021'),
#  ('Vishal Fabrics', 44.95, 0.45, 0.2, 70.59, 41.87, 59.32, '06/03/2021'),
#  ('Sandhar Tech', 238.9, 0.44, 1.05, 49.26, 30.7, 62.33, '06/03/2021'),
#  ('Windsor Machines', 34.2, 0.44, 0.15, 91.13, 54.12, 59.39, '06/03/2021'),
#  ('Advanced Enzyme', 414.75, 0.44, 1.8, 258.99, 113.59, 43.86, '06/03/2021'),
#  ('Kaveri Seed', 707.4, 0.43, 3.05, 397.86, 233.96, 58.8, '06/03/2021'),
#  ('ABB India', 1700.55, 0.43, 7.3, 314.71, 95.67, 30.4, '06/03/2021'),
#  ('Inventure Growth&Sec',
#   35.35,
#   0.43,
#   0.15,
#   192.14,
#   115.38,
#   60.05,
#   '06/03/2021'),
#  ('Modison Metals', 59.15, 0.42, 0.25, 123.97, 86.53, 69.8, '06/03/2021'),
#  ('Care Ratings', 575.45, 0.42, 2.4, 191.35, 88.18, 46.08, '06/03/2021'),
#  ('Bajaj Finance', 5808.65, 0.41, 23.85, 2013.19, 420.51, 20.89, '06/03/2021'),
#  ('Century Plyboards(I)',
#   403.7,
#   0.41,
#   1.65,
#   148.74,
#   79.2,
#   53.25,
#   '06/03/2021'),
#  ('Prestige Estate Proj',
#   273.05,
#   0.4,
#   1.1,
#   386.22,
#   230.4,
#   59.66,
#   '06/03/2021'),
#  ('Premier Explosives', 149.3, 0.4, 0.6, 22.63, 16.82, 74.34, '06/03/2021'),
#  ('Dr Lal Pathlabs', 2909.35, 0.4, 11.6, 196.53, 46.49, 23.66, '06/03/2021'),
#  ('Nitco', 25.3, 0.4, 0.1, 128.18, 55.89, 43.61, '06/03/2021'),
#  ('Greaves Cotton', 127.15, 0.39, 0.5, 438.61, 219.35, 50.01, '06/03/2021'),
#  ('Navin Fluorine Intl',
#   3212.6,
#   0.39,
#   12.6,
#   164.78,
#   58.83,
#   35.7,
#   '06/03/2021'),
#  ('Rites', 244.9, 0.39, 0.95, 371.29, 203.71, 54.87, '06/03/2021'),
#  ('Westlife Development',
#   491.35,
#   0.39,
#   1.9,
#   47.96,
#   23.11,
#   48.18,
#   '06/03/2021'),
#  ('Atul', 8603.05, 0.39, 33.2, 58.84, 49.18, 83.59, '06/03/2021'),
#  ('Securekloud Tech.', 81.05, 0.37, 0.3, 30.75, 19.67, 63.95, '06/03/2021'),
#  ('Action Const. Equip',
#   166.85,
#   0.36,
#   0.6,
#   357.45,
#   197.09,
#   55.14,
#   '06/03/2021'),
#  ('ITD Cementation', 83.55, 0.36, 0.3, 479.59, 243.42, 50.76, '06/03/2021'),
#  ('Sanghvi Movers', 169.4, 0.36, 0.6, 57.48, 41.45, 72.12, '06/03/2021'),
#  ('TARC', 28.3, 0.35, 0.1, 460.76, 307.58, 66.75, '06/03/2021'),
#  ('Graphite India', 750.05, 0.35, 2.65, 1013.66, 494.61, 48.79, '06/03/2021'),
#  ('MMTC', 58.15, 0.35, 0.2, 6765.48, 1354.94, 20.03, '06/03/2021'),
#  ('Patel Engineering',
#   14.75,
#   0.34,
#   0.05,
#   1551.27,
#   1067.92,
#   68.84,
#   '06/03/2021'),
#  ('Torrent Pharma', 2795, 0.34, 9.35, 276.58, 85.86, 31.04, '06/03/2021'),
#  ('Supreme Petrochem', 774.1, 0.33, 2.55, 146.61, 102.08, 69.63, '06/03/2021'),
#  ('Greenply Industries',
#   197.75,
#   0.33,
#   0.65,
#   305.34,
#   191.32,
#   62.66,
#   '06/03/2021'),
#  ('Talbros Auto Compont',
#   243.95,
#   0.33,
#   0.8,
#   71.12,
#   38.51,
#   54.14,
#   '06/03/2021'),
#  ('Blue Star', 818.55, 0.32, 2.65, 51.32, 25.96, 50.58, '06/03/2021'),
#  ('Indbank Merch. Bankg',
#   15.5,
#   0.32,
#   0.05,
#   308.97,
#   105.78,
#   34.23,
#   '06/03/2021'),
#  ('Hexa Tradex', 112.4, 0.31, 0.35, 74.75, 48.45, 64.81, '06/03/2021'),
#  ('Caplin Point Lab', 590.35, 0.31, 1.8, 106.67, 43.96, 41.21, '06/03/2021'),
#  ('Morarjee Textiles', 16.45, 0.3, 0.05, 21.05, 13.21, 62.74, '06/03/2021'),
#  ('Amara Raja Batteries',
#   741.35,
#   0.3,
#   2.25,
#   1584.22,
#   979.87,
#   61.85,
#   '06/03/2021'),
#  ('City Union Bank', 167.55, 0.3, 0.5, 1822.01, 905.7, 49.71, '06/03/2021'),
#  ('Libas Consumer Prod',
#   51.85,
#   0.29,
#   0.15,
#   379.41,
#   87.61,
#   23.09,
#   '06/03/2021'),
#  ('Rain Industries', 178.35, 0.28, 0.5, 1738.42, 631.65, 36.33, '06/03/2021'),
#  ('Techno Electric &Eng',
#   339.6,
#   0.28,
#   0.95,
#   303.82,
#   115.19,
#   37.91,
#   '06/03/2021'),
#  ('Mahanagar Gas', 1186.25, 0.28, 3.3, 452.42, 101.87, 22.52, '06/03/2021'),
#  ('Schneider Ele. Infra',
#   126.5,
#   0.28,
#   0.35,
#   600.44,
#   223.43,
#   37.21,
#   '06/03/2021'),
#  ('Computer Age Man', 2516.4, 0.27, 6.85, 115.24, 57.11, 49.56, '06/03/2021'),
#  ('Birla Cable', 75.45, 0.27, 0.2, 107.8, 55.64, 51.61, '06/03/2021'),
#  ('PSP Projects', 400.8, 0.26, 1.05, 76.82, 58.8, 76.55, '06/03/2021'),
#  ('Guj. Sidhee Cement', 39.7, 0.25, 0.1, 277.97, 95.21, 34.25, '06/03/2021'),
#  ('Omaxe', 80.8, 0.25, 0.2, 150.43, 84.45, 56.14, '06/03/2021'),
#  ('Network 18 Media Inv',
#   40.55,
#   0.25,
#   0.1,
#   883.03,
#   387.72,
#   43.91,
#   '06/03/2021'),
#  ('Subros', 330.05, 0.24, 0.8, 44.08, 20.51, 46.52, '06/03/2021'),
#  ('Unichem Lab', 330.1, 0.24, 0.8, 55.02, 33.69, 61.24, '06/03/2021'),
#  ('Kajaria Ceramics', 968.4, 0.24, 2.3, 91.2, 59.21, 64.92, '06/03/2021'),
#  ('General Insuranc', 197.2, 0.23, 0.45, 393.25, 160.17, 40.73, '06/03/2021'),
#  ('Tata Invest Corp', 1058.55, 0.22, 2.35, 30.1, 19.1, 63.45, '06/03/2021'),
#  ('National Fertilizers',
#   68.25,
#   0.22,
#   0.15,
#   1610.38,
#   430.15,
#   26.71,
#   '06/03/2021'),
#  ('Colgate Palmol. (I)',
#   1717.55,
#   0.22,
#   3.75,
#   320.4,
#   157.96,
#   49.3,
#   '06/03/2021'),
#  ('Natco Pharma', 1048.05, 0.22, 2.25, 306.39, 138.95, 45.35, '06/03/2021'),
#  ('IIFL Securities', 72.95, 0.21, 0.15, 441.11, 199.65, 45.26, '06/03/2021'),
#  ('Bata india', 1543.85, 0.2, 3.15, 445.13, 151.15, 33.96, '06/03/2021'),
#  ('Mahindra EPC Irrigat', 151.35, 0.2, 0.3, 97.44, 52.15, 53.52, '06/03/2021'),
#  ('NHPC', 25.8, 0.19, 0.05, 4707.52, 2558.91, 54.36, '06/03/2021'),
#  ('Somany Ceramics', 468.65, 0.19, 0.9, 37.66, 26.28, 69.8, '06/03/2021'),
#  ('Abbott India', 15988.3, 0.19, 30.15, 27.35, 23.49, 85.88, '06/03/2021'),
#  ('India Hume Pipe', 212.6, 0.19, 0.4, 103.86, 58.6, 56.42, '06/03/2021'),
#  ('Birla Tyres', 27.35, 0.18, 0.05, 249.58, 185.15, 74.18, '06/03/2021'),
#  ('Godrej Consumer Prod',
#   850.6,
#   0.18,
#   1.55,
#   2189.76,
#   1432.05,
#   65.4,
#   '06/03/2021'),
#  ('Orient Paper & Inds.',
#   27.45,
#   0.18,
#   0.05,
#   1913.77,
#   603.16,
#   31.52,
#   '06/03/2021'),
#  ('Seya Industries', 54.95, 0.18, 0.1, 21.78, 13.57, 62.31, '06/03/2021'),
#  ('Gabriel India', 117.25, 0.17, 0.2, 284.67, 131.51, 46.2, '06/03/2021'),
#  ('HIL', 4662.25, 0.16, 7.65, 42.41, 23.66, 55.79, '06/03/2021'),
#  ('Onmobile Global', 125.95, 0.16, 0.2, 1166.65, 495.96, 42.51, '06/03/2021'),
#  ('MSTC', 260.55, 0.13, 0.35, 228.59, 113.63, 49.71, '06/03/2021'),
#  ('Galaxy Surfactants', 2969.1, 0.13, 3.95, 23.66, 13.65, 57.68, '06/03/2021'),
#  ('Rallis India', 311, 0.13, 0.4, 472.58, 126.78, 26.83, '06/03/2021'),
#  ('ONGC', 117.75, 0.13, 0.15, 27162.99, 8472.56, 31.19, '06/03/2021'),
#  ('Mahindra CIE Auto.', 196.4, 0.13, 0.25, 147.33, 70.9, 48.12, '06/03/2021'),
#  ('IFGL Refractories', 354.85, 0.13, 0.45, 117.38, 54.46, 46.4, '06/03/2021'),
#  ('NRB Bearings', 118.85, 0.13, 0.15, 911.63, 541.91, 59.44, '06/03/2021'),
#  ('ITI', 120.65, 0.12, 0.15, 191.68, 78.03, 40.71, '06/03/2021'),
#  ('CL Educate', 87.05, 0.12, 0.1, 21.45, 10.17, 47.41, '06/03/2021'),
#  ('Jullundur Motor Agen', 45.75, 0.11, 0.05, 37.1, 22.51, 60.68, '06/03/2021'),
#  ('Aditya Birla Money', 46.45, 0.11, 0.05, 204.2, 66.32, 32.48, '06/03/2021'),
#  ('DP Wires', 148.2, 0.1, 0.15, 100.13, 59.82, 59.74, '06/03/2021'),
#  ('Shanthi Gears', 149.65, 0.1, 0.15, 21.73, 12.74, 58.66, '06/03/2021'),
#  ('Gallantt Ispat', 49.9, 0.1, 0.05, 28.68, 16.56, 57.73, '06/03/2021'),
#  ('Gravita India', 101.9, 0.1, 0.1, 110.64, 59.91, 54.15, '06/03/2021'),
#  ('Share India Sec.', 470.75, 0.1, 0.45, 39.16, 26.55, 67.8, '06/03/2021'),
#  ('E.I.D. Parry (I)', 416.15, 0.08, 0.35, 200.61, 86.28, 43.01, '06/03/2021'),
#  ('Jubilant Pharmova', 847.1, 0.08, 0.7, 226.14, 113.88, 50.36, '06/03/2021'),
#  ('Symphony', 1069.55, 0.07, 0.75, 77.5, 42.79, 55.21, '06/03/2021'),
#  ('Creative Peripherals', 85.5, 0.06, 0.05, 41.95, 22.44, 53.49, '06/03/2021'),
#  ('Mahamaya Steel Inds', 86.8, 0.06, 0.05, 15.43, 10.57, 68.52, '06/03/2021'),
#  ('Insecticides India', 544.9, 0.06, 0.3, 61.33, 42.17, 68.76, '06/03/2021'),
#  ('Railtel Corporation Of India Lt..',
#   127.25,
#   0.04,
#   0.05,
#   726.72,
#   355.05,
#   48.86,
#   '06/03/2021'),
#  ('Wipro', 543, 0.04, 0.2, 4713.57, 1490.53, 31.62, '06/03/2021'),
#  ('Panacea Biotec', 415.4, 0.02, 0.1, 292.36, 145.32, 49.7, '06/03/2021'),
#  ('Laxmi Organic Inds.',
#   223.7,
#   0.02,
#   0.05,
#   1524.54,
#   458.44,
#   30.07,
#   '06/03/2021'),
#  ('Hindustan Unilever',
#   2358.8,
#   0.02,
#   0.5,
#   1113.09,
#   726.34,
#   65.25,
#   '06/03/2021'),
#  ('ICICI Lombard Gen.',
#   1467.1,
#   0.02,
#   0.3,
#   705.99,
#   471.13,
#   66.73,
#   '06/03/2021'),
#  ('JK Cement', 2846.2, 0.02, 0.5, 46.77, 39.61, 84.69, '06/03/2021'),
#  ('Transport Corp.', 439.9, -7.97, -38.1, 810.3, 307.33, 37.93, '06/03/2021'),
#  ('Bannari Amman Spg',
#   78.35,
#   -7.5,
#   -6.35,
#   1181.08,
#   669.45,
#   56.68,
#   '06/03/2021'),
#  ('TCI Developers', 480.85, -6.7, -34.55, 89.85, 33.49, 37.27, '06/03/2021'),
#  ('UFO Moviez', 98.65, -6.23, -6.55, 2420.65, 759.63, 31.38, '06/03/2021'),
#  ('Signet Industries', 55.5, -5.45, -3.2, 466.56, 226.97, 48.65, '06/03/2021'),
#  ('Salasar Techno Engg.',
#   675.4,
#   -5.36,
#   -38.25,
#   266.62,
#   137.19,
#   51.46,
#   '06/03/2021'),
#  ('Visagar Polytex', 0.9, -5.26, -0.05, 411, 411, 100, '06/03/2021'),
#  ('Tips Inds.', 851.75, -5, -44.8, 40.06, 27.16, 67.8, '06/03/2021'),
#  ('Mcdowell Holdings',
#   50.55,
#   -4.98,
#   -2.65,
#   176.87,
#   140.89,
#   79.66,
#   '06/03/2021'),
#  ('Ambica Agarbathies',
#   23.95,
#   -4.96,
#   -1.25,
#   70.56,
#   59.48,
#   84.29,
#   '06/03/2021'),
#  ('GPT Infraprojects',
#   57.7,
#   -4.86,
#   -2.95,
#   283.33,
#   160.86,
#   56.77,
#   '06/03/2021'),
#  ('Responsive Inds', 148.7, -4.68, -7.3, 336.07, 84.16, 25.04, '06/03/2021'),
#  ('Venus Remedies', 303.15, -4.62, -14.7, 127.22, 91.11, 71.62, '06/03/2021'),
#  ('Imagicaaworld Enter',
#   7.25,
#   -4.61,
#   -0.35,
#   154.13,
#   91.56,
#   59.41,
#   '06/03/2021'),
#  ('Tijaria Polypipe', 7.35, -4.55, -0.35, 34.51, 28.39, 82.27, '06/03/2021'),
#  ('Shyam Century', 7.5, -4.46, -0.35, 358.63, 316.69, 88.31, '06/03/2021'),
#  ('Setubandhan Infra', 1.1, -4.35, -0.05, 260.05, 260.03, 99.99, '06/03/2021'),
#  ('Capri Global Capital',
#   524.35,
#   -4.28,
#   -23.45,
#   120.22,
#   37.45,
#   31.15,
#   '06/03/2021'),
#  ('SE Power', 6.75, -4.26, -0.3, 129.95, 96.22, 74.05, '06/03/2021'),
#  ('GSFC', 103.7, -4.03, -4.35, 5278.8, 2745.5, 52.01, '06/03/2021'),
#  ('Magnum Ventures', 6, -4, -0.25, 21.46, 21.41, 99.76, '06/03/2021'),
#  ('New Delhi Television',
#   67.1,
#   -3.94,
#   -2.75,
#   386.93,
#   196.2,
#   50.71,
#   '06/03/2021'),
#  ('Mercator', 1.25, -3.85, -0.05, 3804.53, 1973.22, 51.87, '06/03/2021'),
#  ('Madhucon Projects', 5, -3.85, -0.2, 96.41, 73.46, 76.2, '06/03/2021'),
#  ('PIL Italtca Lifest.',
#   11.6,
#   -3.73,
#   -0.45,
#   1899,
#   715.16,
#   37.66,
#   '06/03/2021'),
#  ('DFM Foods', 399, -3.69, -15.3, 659.44, 163.27, 24.76, '06/03/2021'),
#  ('Ruby Mills', 238.25, -3.64, -9, 42.4, 20.01, 47.2, '06/03/2021'),
#  ...]

# %%
df=ReadData().rExcel()
#     query1 = "delete from tblCurrentStockVolInfo"
#     # query2 = "create table tblCurrentStockVolInfo ([Stock Name] nvarchar(60) not null primary key,[Trade Vol] float,[Delivery Vol] float,[Delivery(%)] float,[LTP] float)"
query3 = "insert into staticStockInfoTable values ('{}','{}','{}',{})"

try:
    dbFile=r"C:\Users\DELL\Desktop\College.db"
    con=sqlite3.connect(dbFile)
    cursor = con.cursor()
    
    for i in range(0, len(df)):
        cursor.execute(query3.format(df.iloc[i,0], df.iloc[i,1],df.iloc[i,2],df.iloc[i,3]))
        con.commit()
finally:

    cursor.close()
    con.close()
    print('close')
# Out:
# close
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-75-73fc8345e93f> in <module>
#      10
#      11     for i in range(0, len(df)):
# ---> 12         cursor.execute(query3.format(df.iloc[i,0], df.iloc[i,1],df.iloc[i,2],df.iloc[i,3]))
#      13         con.commit()
#      14 finally:
#
# OperationalError: no such column: nan

# %%
import requests
import bs4
hdr = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36 Edg/90.0.818.56"}
url = "https://www.financialexpress.com/market/stock-market/nse-top-gainers/"
# df = []
#         for url in URL_lst:
resp = requests.get(url, headers=hdr)
soup = bs4.BeautifulSoup(resp.text, 'html.parser')
# table = soup.find(id='modality')
#             for tr in table.find_all('tr'):
#                 lst = []
#                 for td in tr.find_all('td'):
#                     lst.append(td.text)
#                 df.append(lst)
#         return df
